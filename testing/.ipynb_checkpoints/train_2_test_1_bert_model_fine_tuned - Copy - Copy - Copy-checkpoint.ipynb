# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from bnlp import BasicTokenizer
tokenizer = BasicTokenizer()
# Out:
# C:\Users\meera\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
def create_corpus(texts):
    corpus=[]

    for txt in texts:
        tokens = tokenizer.tokenize(txt)
        corpus.extend(tokens)

    return corpus

# %%
from collections import defaultdict
from collections import  Counter
from bnlp.corpus import stopwords
import matplotlib.font_manager as fm

def show_stop_words(corpus, length=20):
  dic = defaultdict(int)

  for word in corpus:
      if word in stopwords:
          dic[word]+=1

  top=sorted(dic.items(), key=lambda x:x[1],reverse=True)[:length]
  x,y=zip(*top)
  print(x)
  print(y)
  plt.figure(figsize=(10,5))
  plt.bar(x,y)
  plt.show()

# %%
from bnlp.corpus import stopwords, punctuations, digits
print(stopwords)
def filters(corpus):
    res = []
    for i in corpus:
        if i in stopwords:
            continue

        if i in punctuations + '‘' + '’':
            continue
        if i in digits:
            continue

        res.append(i)

    return res
# Out:
# ['অতএব', 'অথচ', 'অথবা', 'অনুযায়ী', 'অনেক', 'অনেকে', 'অনেকেই', 'অন্তত', 'অন্য', 'অবধি', 'অবশ্য', 'অর্থাত', 'আই', 'আগামী', 'আগে', 'আগেই', 'আছে', 'আজ', 'আদ্যভাগে', 'আপনার', 'আপনি', 'আবার', 'আমরা', 'আমাকে', 'আমাদের', 'আমার', 'আমি', 'আর', 'আরও', 'ই', 'ইত্যাদি', 'ইহা', 'উচিত', 'উত্তর', 'উনি', 'উপর', 'উপরে', 'এ', 'এঁদের', 'এঁরা', 'এই', 'একই', 'একটি', 'একবার', 'একে', 'এক্', 'এখন', 'এখনও', 'এখানে', 'এখানেই', 'এটা', 'এটাই', 'এটি', 'এত', 'এতটাই', 'এতে', 'এদের', 'এব', 'এবং', 'এবার', 'এমন', 'এমনকী', 'এমনি', 'এর', 'এরা', 'এল', 'এস', 'এসে', 'ঐ', 'ও', 'ওঁদের', 'ওঁর', 'ওঁরা', 'ওই', 'ওকে', 'ওখানে', 'ওদের', 'ওর', 'ওরা', 'কখনও', 'কত', 'কবে', 'কমনে', 'কয়েক', 'কয়েকটি', 'করছে', 'করছেন', 'করতে', 'করবে', 'করবেন', 'করলে', 'করলেন', 'করা', 'করাই', 'করায়', 'করার', 'করি', 'করিতে', 'করিয়া', 'করিয়ে', 'করে', 'করেই', 'করেছিলেন', 'করেছে', 'করেছেন', 'করেন', 'কাউকে', 'কাছ', 'কাছে', 'কাজ', 'কাজে', 'কারও', 'কারণ', 'কি', 'কিংবা', 'কিছু', 'কিছুই', 'কিন্তু', 'কী', 'কে', 'কেউ', 'কেউই', 'কেখা', 'কেন', 'কোটি', 'কোন', 'কোনও', 'কোনো', 'ক্ষেত্রে', 'কয়েক', 'খুব', 'গিয়ে', 'গিয়েছে', 'গিয়ে', 'গুলি', 'গেছে', 'গেল', 'গেলে', 'গোটা', 'চলে', 'চান', 'চায়', 'চার', 'চালু', 'চেয়ে', 'চেষ্টা', 'ছাড়া', 'ছাড়াও', 'ছিল', 'ছিলেন', 'জন', 'জনকে', 'জনের', 'জন্য', 'জন্যওজে', 'জানতে', 'জানা', 'জানানো', 'জানায়', 'জানিয়ে', 'জানিয়েছে', 'জে', 'জ্নজন', 'টি', 'ঠিক', 'তখন', 'তত', 'তথা', 'তবু', 'তবে', 'তা', 'তাঁকে', 'তাঁদের', 'তাঁর', 'তাঁরা', 'তাঁাহারা', 'তাই', 'তাও', 'তাকে', 'তাতে', 'তাদের', 'তার', 'তারপর', 'তারা', 'তারৈ', 'তাহলে', 'তাহা', 'তাহাতে', 'তাহার', 'তিনঐ', 'তিনি', 'তিনিও', 'তুমি', 'তুলে', 'তেমন', 'তো', 'তোমার', 'থাকবে', 'থাকবেন', 'থাকা', 'থাকায়', 'থাকে', 'থাকেন', 'থেকে', 'থেকেই', 'থেকেও', 'দিকে', 'দিতে', 'দিন', 'দিয়ে', 'দিয়েছে', 'দিয়েছেন', 'দিলেন', 'দু', 'দুই', 'দুটি', 'দুটো', 'দেওয়া', 'দেওয়ার', 'দেওয়া', 'দেখতে', 'দেখা', 'দেখে', 'দেন', 'দেয়', 'দ্বারা', 'ধরা', 'ধরে', 'ধামার', 'নতুন', 'নয়', 'না', 'নাই', 'নাকি', 'নাগাদ', 'নানা', 'নিজে', 'নিজেই', 'নিজেদের', 'নিজের', 'নিতে', 'নিয়ে', 'নিয়ে', 'নেই', 'নেওয়া', 'নেওয়ার', 'নেওয়া', 'নয়', 'পক্ষে', 'পর', 'পরে', 'পরেই', 'পরেও', 'পর্যন্ত', 'পাওয়া', 'পাচ', 'পারি', 'পারে', 'পারেন', 'পি', 'পেয়ে', 'পেয়্র্', 'প্রতি', 'প্রথম', 'প্রভৃতি', 'প্রযন্ত', 'প্রাথমিক', 'প্রায়', 'প্রায়', 'ফলে', 'ফিরে', 'ফের', 'বক্তব্য', 'বদলে', 'বন', 'বরং', 'বলতে', 'বলল', 'বললেন', 'বলা', 'বলে', 'বলেছেন', 'বলেন', 'বসে', 'বহু', 'বা', 'বাদে', 'বার', 'বি', 'বিনা', 'বিভিন্ন', 'বিশেষ', 'বিষয়টি', 'বেশ', 'বেশি', 'ব্যবহার', 'ব্যাপারে', 'ভাবে', 'ভাবেই', 'মতো', 'মতোই', 'মধ্যভাগে', 'মধ্যে', 'মধ্যেই', 'মধ্যেও', 'মনে', 'মাত্র', 'মাধ্যমে', 'মোট', 'মোটেই', 'যখন', 'যত', 'যতটা', 'যথেষ্ট', 'যদি', 'যদিও', 'যা', 'যাঁর', 'যাঁরা', 'যাওয়া', 'যাওয়ার', 'যাওয়া', 'যাকে', 'যাচ্ছে', 'যাতে', 'যাদের', 'যান', 'যাবে', 'যায়', 'যার', 'যারা', 'যিনি', 'যে', 'যেখানে', 'যেতে', 'যেন', 'যেমন', 'র', 'রকম', 'রয়েছে', 'রাখা', 'রেখে', 'লক্ষ', 'শুধু', 'শুরু', 'সঙ্গে', 'সঙ্গেও', 'সব', 'সবার', 'সমস্ত', 'সম্প্রতি', 'সহ', 'সহিত', 'সাধারণ', 'সামনে', 'সি', 'সুতরাং', 'সে', 'সেই', 'সেখান', 'সেখানে', 'সেটা', 'সেটাই', 'সেটাও', 'সেটি', 'স্পষ্ট', 'স্বয়ং', 'হইতে', 'হইবে', 'হইয়া', 'হওয়া', 'হওয়ায়', 'হওয়ার', 'হচ্ছে', 'হত', 'হতে', 'হতেই', 'হন', 'হবে', 'হবেন', 'হয়', 'হয়তো', 'হয়নি', 'হয়ে', 'হয়েই', 'হয়েছিল', 'হয়েছে', 'হয়েছেন', 'হল', 'হলে', 'হলেই', 'হলেও', 'হলো', 'হাজার', 'হিসাবে', 'হৈলে', 'হোক', 'হয়']
# C:\Users\meera\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
def get_top_words(corpus):
    dic = defaultdict(int)

    for word in corpus:
        dic[word] +=1
    top = sorted(dic.items(), key=lambda x:x[1],reverse=True)
    x,y=zip(*top)
    return x, y

# %% [markdown]
# # Imports

# %%
import pandas as pd
train_set = pd.read_csv("./train_csv_data/train_set_2.csv")
test_set = pd.read_csv("test_set_2.csv")
validate_set = pd.read_csv("test_set_1.csv")

# %%
import time
from transformers import AutoModel, BertTokenizerFast
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.optim import AdamW
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from tqdm.notebook import tqdm
from transformers import BertModel, BertTokenizer, BertForSequenceClassification

# %%
# train_set.drop(columns = ["Unnamed: 0"])
test_set.drop(columns = ["Unnamed: 0"])
validate_set.drop(columns = ["Unnamed: 0"])
# Out:
#                                                    text  label
# 0     কোরিয়ার ইনছন এয়ারপোর্টের মত শাহজালাল এয়ারপোর্ট...      0
# 1                                            বাহ!সুন্দর      0
# 2     ভাই এতদিন আপনার সবকিছুই সাপোর্ট করে গেছি কিন্ত...      1
# 3     অমানুষের বাচ্ছা গুলু কে চাকরি নট করে দেনকি এমন...      2
# 4     কী আর বলব? কিছুই বলার নাই শুধু আপনাদের মত কয়টা...      0
# ...                                                 ...    ...
# 1027                         শুধু পকেট ভারি করার ধান্দা      1
# 1028  এই সালা বড় একটা মাদার চোদ ভালবাসা দিবস আনছে এই...      2
# 1029                আপনাদের ওপর আল্লাহর রহমত বর্ষিত হোক      0
# 1030  অপরাধ কারী এবং অপরাধী কে প্রশ্রয় দানকারী দুজন...      3
# 1031  যখন সরষেতে থাকে ভুত >>>><<<<< তখন বক্তা থাকে এ...      4
#
# [1032 rows x 2 columns]

# %%
train_list = train_set.values.tolist()

# %%
# print(x)
p = ['একটা','হয়ে','কথা','মানুষ','এক','দিয়ে','সাথে','যায়','হয়েছে',
     'মত','টা','একজন','বড়','বাংলাদেশ','সময়','মানুষের','সবাই','ভিডিও',
     'টাকা','দেশের','একটু','লাগে','মন','দেশে','আল্লাহ','গুলো','বছর','বাংলাদেশের',
     'এসব','বাবা','ছবি','জানি','আসে','দেখি','আরো','পড়ে','চোখ',
     'মাঝে','কারণে','উঠে','ছাড়া','এখনো','এভাবে','কমেন্ট','আজকে','দিলে','—','যাওয়ার',
     'সোমবার','ক্যাম্পাসে','কিনা','জাতীয়','গতকাল','পড়তে','আমিন','শব্দ','হয়ত','করবো',
     'ইচ্ছা','কিনা','এলো','ঈদ','ঢাকার','চলছে','অনুষ্ঠান','ভাইয়ের','বৃষ্টি','আসার','তাদেরকে','রইল',
     'আমিও','ফেসবুক','দিয়েছেন','পরিবেশ','এইরকম','নেওয়ার','আব্বু','দক্ষিণ','সাদা',
     'অনুষ্ঠিত','দিব','উঠছে','এতটা','করল','নাম্বার','সমাজে','বিয়েতে','লাগল','মো','চট্টগ্রামের',
     'শরীরে','রাজধানী','করলেও','মেয়ের','প্রথমে','পূরণ','লাইক','আপুর','পারো','ম্যাচের',
     'মানায়','নিকট','দেহ','পারতাম','পারতো','পত্রিকা','পারভেজ','আলম','ছাত্রীকে','অামি',
     'বাচ্চারা','এমনই','হলুদ','মানবতা','পুরোপুরি','হয়তবা','বাতাস', 'হও', 'কাহিনী','ফেরার',
     'ছয়', 'মিয়ার', 'আসেনা','বাস্তব', 'অর্জন', 'বৃদ্ধ', 'মতন', 'খেলতে', 'বানাতে', 'লাগিয়ে',
     'ছবিও', 'মাংস', 'মেঝেতে','আমিই','দেখেছিলাম','রং','ভাবেননি','দিন','ছবি','কিন্তু','শুরু','অথচ',
     'রাতে','যারা','মনে','এখনে','মানুষ','আমাকে','কথা','গেছে','শুরু','আমিও','করে','পুরো','আমাদের',
     'দিলো','সেই','যে','তবে','টা','তার ','এই ','হচ্ছে ','ছিল ','অনেক ','খুবি ','এর ','বলেন ','পেলে',
     'বয়সের', 'কে', 'হয়','হয়ে'
     ]
n=set(p)
print(len(n))
# Out:
# 165

# %%
for i in range(len(train_list)):
    for j in n:
        if " "+j+" " in train_list[i][0]:
            train_list[i][0]=train_list[i][0].replace(j,"")
        elif j+" " in train_list[i][0]:
            train_list[i][0]=train_list[i][0].replace(j,"")
        elif " "+j in train_list[i][0]:
            train_list[i][0]=train_list[i][0].replace(j,"")
        else:
            continue

# %%
train_set = pd.DataFrame(train_list, columns = ['text', 'label'])

# %% [markdown]
# # Optoimizing dataset

# %%
class makeDataset(Dataset):
    def __init__(self, data, max_length=100):
        self.data = data
        
        self.config = {
            "max_length": max_length,
            "padding": "max_length",
            "return_tensors": "pt",
            "truncation": True,
            "add_special_tokens": True
        }

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        value = self.data.iloc[idx]
        return value['text'], value['label']

# %% [markdown]
# # Training data 2 testing data 2 final testing data 1

# %%
training_data = makeDataset(train_set)
train_dataloader = DataLoader(training_data, batch_size=16, shuffle=True)

# %%
test_data = makeDataset(test_set)
test_dataloader = DataLoader(test_data, batch_size=16, shuffle=True)

# %%
final_test_data = makeDataset(validate_set)
final_test_dataloader = DataLoader(final_test_data, batch_size=16, shuffle=True)

# %%
class newEmotionBert(nn.Module):

    def __init__(self, bert):
        super(newEmotionBert, self).__init__()

        self.bert = bert
        
        # dropout layer
        self.dropout = nn.Dropout(0.2)

        # relu activation function
#         self.relu = nn.ReLU()

#         dense layer 1
        self.fc1 = nn.Linear(768, 5)

        # dense layer 2 (Output layer)
#         self.fc2 = nn.Linear(328, 5)  
        self.softmax = nn.LogSoftmax(dim=1)
#         self.init_weights()
#     def init_weights(self):
#         initrange = .5
#         self.embedding.weight.data.uniform_(-initrange, initrange)
#         self.fc1.weight.data.uniform_(-initrange, initrange)
#         self.fc1.bias.data.zero_()
#         self.fc2.weight.data.uniform_(-initrange, initrange)
#         self.fc2.bias.data.zero_()

    # define the forward pass
    def forward(self, input_ids, token_type_ids, attention_mask):
        # pass the inputs to the model
        out = self.bert(input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)
        
        x = self.fc1(out[1])
#         x = self.relu(x)
#         # output layer
        x = self.dropout(x)
#         x = self.fc2(self.dropout(x))
        
        x = self.softmax(x)
        return x

# %%
bert_model_name = "sagorsarker/bangla-bert-base"
bert = BertModel.from_pretrained(bert_model_name)
tokenizer = BertTokenizer.from_pretrained(bert_model_name)
# Out:
# Some weights of the model checkpoint at sagorsarker/bangla-bert-base were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = newEmotionBert(bert)
model.to(device);

# %%
from torch.optim.lr_scheduler import StepLR

optimizer = AdamW(model.parameters(), lr=1e-5)
criterion = nn.NLLLoss()
scheduler = StepLR(optimizer, step_size=2, gamma=0.1)

# %%
from time import sleep
def train(model, dataloader, optimizer, criterion, config):
    model.train()  # prep model for training
    train_loss = 0
    for batch in dataloader:
        text, labels = batch

        model.zero_grad()

        inputs = tokenizer.batch_encode_plus(
            text, **config
        )
        input_ids = inputs['input_ids'].to(device)
        token_type_ids = inputs['token_type_ids'].to(device)
        attention_mask = inputs['attention_mask'].to(device)
        labels = labels.to(device)

        # move things to model
        logs = model(token_type_ids=token_type_ids, input_ids=input_ids, attention_mask=attention_mask)

        loss = criterion(logs, labels)
        train_loss += loss.item() * input_ids.size(0)
        loss.backward()

        # clip the the gradients to 1.0. It helps in preventing the exploding gradient problem
        nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()

    return train_loss

# %%
def evaluate(model, dataloader, criterion, config):
    total = 0
    correct = 0
    valid_loss = 0.0

    model.eval()  # prep model for evaluation
    for batch in dataloader:
        text, labels = batch
        inputs = tokenizer.batch_encode_plus(
            text, **config
        )
        input_ids = inputs['input_ids'].to(device)
        token_type_ids = inputs['token_type_ids'].to(device)
        attention_mask = inputs['attention_mask'].to(device)
        labels = labels.to(device)

        # move things to model
        output = model(token_type_ids=token_type_ids, input_ids=input_ids, attention_mask=attention_mask)

        loss_p = criterion(output, labels)
        # update running validation loss
        valid_loss += loss_p.item() * input_ids.size(0)
        # calculate accuracy
        proba = torch.exp(output)
        top_p, top_class = proba.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        # accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

        _, predicted = torch.max(output.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    return total, correct, valid_loss

# %%
epochs = 5
tokenizer_config = {
    "max_length": 100,
    "padding": "max_length",
    "return_tensors": "pt",
    "truncation": True,
    "add_special_tokens": True
}

# %%
train_loss_data, valid_loss_data = [], []
valid_loss_min = np.Inf
since = time.time()
best_loss = np.inf

for epoch in range(epochs):
    print("Epoch: {}/{}".format(epoch + 1, epochs))
    # monitor training loss
    train_loss = 0.0
    valid_loss = 0.0
    total = 0
    correct = 0
    e_since = time.time()

    # Train Model
    train_loss += train(model, train_dataloader, optimizer, criterion, tokenizer_config)

    # Now Evaluate
    out = evaluate(model, test_dataloader, criterion, tokenizer_config)

    total += out[0]
    correct += out[1]
    valid_loss += out[2]

    scheduler.step()

    # print training/validation statistics
    # calculate average loss over an epoch
    train_loss = train_loss / len(train_dataloader.dataset)
    valid_loss = valid_loss / len(test_dataloader.dataset)

    # calculate train loss and running loss
    train_loss_data.append(train_loss * 100)
    valid_loss_data.append(valid_loss * 100)
    
    if valid_loss < best_loss:
        best_loss = valid_loss
        torch.save(model.state_dict(), "new_emotion_model.pth")

    print("\tTrain loss:{:.6f}..".format(train_loss),
          "\tValid Loss:{:.6f}..".format(valid_loss),
          "\tAccuracy: {:.4f}".format(correct / total * 100))

time_elapsed = time.time() - since
print('Training completed in {:.0f}m {:.0f}s'.format(
    time_elapsed // 60, time_elapsed % 60))
# Out:
# Epoch: 1/5
# 	Train loss:1.419773.. 	Valid Loss:1.112482.. 	Accuracy: 55.0988
# Epoch: 2/5
# 	Train loss:1.138917.. 	Valid Loss:0.945284.. 	Accuracy: 64.2688
# Epoch: 3/5
# 	Train loss:0.946607.. 	Valid Loss:0.910589.. 	Accuracy: 65.2174
# Epoch: 4/5
# 	Train loss:0.916803.. 	Valid Loss:0.896102.. 	Accuracy: 65.0593
# Epoch: 5/5
# 	Train loss:0.882481.. 	Valid Loss:0.890529.. 	Accuracy: 65.6917
# Training completed in 9m 35s

# %%
model.load_state_dict(torch.load("./new_emotion_model.pth", map_location = device))
# Out:
# <All keys matched successfully>

# %%
all_preds = []
all_labels = []

for batch in final_test_dataloader:
    text, labels = batch
    inputs = tokenizer.batch_encode_plus(
        text, **tokenizer_config
    )
    input_ids = inputs['input_ids'].to(device)
    token_type_ids = inputs['token_type_ids'].to(device)
    attention_mask = inputs['attention_mask'].to(device)
    labels = labels.to(device)

    # move things to model
    output = model(token_type_ids=token_type_ids, input_ids=input_ids, attention_mask=attention_mask)
    preds = output.detach().cpu().numpy()
    preds = np.argmax(preds, axis = 1)
    all_preds.extend(preds)
    all_labels.extend(labels.cpu().numpy())

# %%
correct = 0
for i in range(len(all_labels)):
    if all_labels[i]==all_preds[i]:
        correct+=1
print(correct)
# Out:
# 464

# %%
print(f"accuracy: {correct/len(all_labels)*100}")
# Out:
# accuracy: 44.96124031007752

# %%
print(bert.embeddings.word_embeddings.weight[101])
# Out:
# tensor([ 4.7776e-03, -6.2272e-03,  1.0204e-02,  3.5245e-03,  2.2380e-02,
#         -2.3848e-03, -6.9320e-03, -5.1919e-02, -1.8723e-02, -1.1741e-02,
#          2.5536e-02, -2.9591e-02,  2.7458e-03,  2.5562e-02, -1.2320e-02,
#         -6.3829e-03,  2.8421e-03, -4.1395e-02,  1.2272e-02, -6.6399e-02,
#         -2.7089e-02,  1.1260e-02, -5.2913e-03,  6.9129e-03, -4.8358e-04,
#          2.2213e-03, -5.2888e-02,  1.5030e-02,  1.3721e-02,  1.3283e-02,
#          4.2959e-04,  1.4695e-02, -7.5240e-02, -5.5764e-03, -5.6503e-02,
#          1.2316e-02,  2.9154e-02, -2.6337e-02, -1.6936e-02, -2.4660e-02,
#          1.3200e-02, -3.5153e-02, -2.1085e-02, -1.5550e-02,  6.9879e-03,
#          2.2485e-02,  2.2915e-02,  1.3987e-02,  8.4947e-03,  1.4443e-02,
#          1.3316e-02, -2.9813e-02, -2.0112e-02, -2.6620e-02,  4.7600e-02,
#          1.6576e-02,  1.4967e-02,  8.3584e-05,  9.1415e-03,  1.2812e-01,
#          3.4819e-02, -4.5977e-02,  3.7331e-02, -1.7041e-02,  2.5941e-02,
#         -2.5490e-02,  3.6186e-02, -5.5241e-02,  8.6530e-03, -4.2151e-02,
#          2.7344e-03, -7.4022e-02, -1.9113e-03,  2.7002e-02, -4.3357e-02,
#          1.2363e-01, -1.5236e-02, -3.7752e-02,  1.6990e-02, -1.1607e-02,
#         -2.9883e-02, -2.1415e-02, -2.6520e-03,  2.3545e-02,  2.8744e-02,
#         -2.3658e-02, -1.5832e-02, -3.5759e-02, -3.8882e-02, -2.6410e-02,
#         -5.1146e-02,  1.4649e-02, -1.2413e-02,  1.7028e-02,  2.2908e-02,
#          2.2438e-02,  1.9554e-02,  2.3388e-02,  1.5895e-01,  2.7008e-02,
#          8.5279e-03,  1.3466e-02, -3.4186e-03], device='cuda:0',
#        grad_fn=<SelectBackward0>)

# %%
print(bert.embeddings.word_embeddings.weight)
# Out:
# Parameter containing:
# tensor([[ 0.0135, -0.0630,  0.0409,  ...,  0.0157,  0.0392,  0.0274],
#         [-0.0087, -0.0241,  0.0309,  ...,  0.0091,  0.0086,  0.0314],
#         [-0.0079, -0.0322,  0.0313,  ...,  0.0383,  0.0139,  0.0233],
#         ...,
#         [ 0.0087, -0.0369,  0.0547,  ...,  0.0150, -0.0134,  0.0221],
#         [-0.0048, -0.0426,  0.0420,  ...,  0.0130,  0.0257,  0.0361],
#         [-0.0249, -0.0520,  0.0290,  ...,  0.0178,  0.0014,  0.0266]],
#        device='cuda:0', requires_grad=True)

# %%
in_correct = []
for i in range(len(all_labels)):
    if all_labels[i]!=all_preds[i]:
        in_correct.append(train_set["text"][i])
print(in_correct)
# Out:
# ['এই বয়সে নাতি নাতনিদের সঙ্গে আনন্দে মেতে থাকার  তা নয় এ বুড়ো  ভীমরতি', 'তোমার শহরের কোণে উ মায়া জমায় কি  আমি  ভাবি  তোমা ফেরানো যাবে কি ', 'আমি গত সপ্তাহের কত  পড়ছি তা দেখে আমি চম উঠতে  করি আমি নিশ্চিত অসুস্থ কিছু নার্ভাস বোধ করি', 'স্কুলে ঠিক সময়ে পৌঁছতে না পারার ভয়   কতশত ভয় নিয়েই তো আমরা বড় হই ', 'দায়িত্বে অবহেলা ডাক্তারদের শাস্তি মূলক ব্যবস্থা গ্রহণ করুন  এরকম ছোট  নিয়ে ডাক্তারি পেশায় আসা উচিত হয়নি ', 'টিক টক পাগলের   না   \nকিন্তূ তোমার  শুনে   \n হাসতে হাসতে পাগল ে যাবে   ', 'বাঁধন খুলে দিতেই নগ্ন আতঙ্কভরা ে সার্জনের দি তাকিয়েছিল রোগী  অবিশ্বাস  মিনতি  আতঙ্ক মিলেমিশে াকার দুে', 'হঠাৎ কালো রঙের  প্রাইভেট কার সাদিয়ার সা এসে দাঁড়ালো সে গাড়িতে উঠতে যাবে এ  গাড়ির ভেতরে কী নো  দেখে ভড় গেলো ', 'ভাইয়া  বাংলা জয়পুরে থাকি অামার এলাকায় করনার জন্য সব বন্ধ এ ওভাবি লোক অাছে  ওসহায় অার তাদের দেখলে খুব কস্ট    না খেয়ে মারা জাবে', 'সোয়া আটটায় রোয়া হলের সা থে লা ফেরত   চাঁদের আলোয় বুঝতে পারলাম  র প্রতি মায়া চলে আসলো বোধ    মায়া বাড়া  ো  হায় ', 'অধিকাংশ ভৌতিক সিনেমা দেখলে   শুধুমাত্র বীভৎস সব চেহারা কিংবা রক্তভরা মুখ য়ে দর্শক ভয় দেখানোটাই বুঝি পরিচালর মাত্র আগ্রহ ', 'দিদি  পুরা পাগল ে   ভারতে পাগলা গারত না থা বাংলা পাঠিয়ে দেও ভাল চিকিৎসা হবে ', 'শীশির ভেজা দুর্বা ঘাসে  শীশির কনা বলছে হেসে  বিদায় নিয়েছে হিমাল রাত  জানাই তোমাদের সুপ্রভাত ', 'জাতিগতভাবে   চোর বা পকেটমার পিটায়ে মাইরা ফেলার সংস্কৃতি   নারী অপরাধীরে উনার অপরাধের শাস্তি পাওয়ার পরেও ধর্ষণের  ই আকাংক্ষা  উনারে সম্মিলিতভাবে বেশ্যা বানানোর ই প্রকল্প  তা থিকা আপনারা দয়া কইরা বাইর হইয়া সুস্থ হন  দয়া কইরা সুস্থ হন  দয়া কইরা সুস্থ হন ', 'সরকার বলার পরই যদি সব মানতে   তাহলে বিবেক কই রাখলেন  বিবেক বিবেচনাবোধ বলতে কিছু  আছ তো', 'কোন  ঠেলা দেয় পরীক্ষায় কারণ জাতির গুরুদের তো হাত য়  য়ে ছাড়বো দাড়াও  ভয়ে ো কিছু স্পষ্ট জোর  বলতেছে না', 'কৃষ্ণকাঠি এলাকার জ্বরের রোগী সুখী আক্     প্রচণ্ড জ্বরের  দাঁড়াতেই পারছি না  ভাবছিলাম হাসপাতাল থে চিকিৎসা পাব   ডাক্জ্বরের রোগী দেখতে ভয় পাচ্ছেন  ', 'কাজের কাজ কিছুই  না', 'অনেক পর ভাইদের  দেখা       আড্ডা  মজা পেলাম ', 'নোবেল মানষিক ভারসাম্যহীন ে  তা পাবনায় পাঠানো হোক', 'হিংসা ও ঘৃণা দূরে সরিয়ে সাম্প্রদায়িক সম্প্রীতির হাত বাড়িয়ে দেয়ার আহ্বান জানান তারকারা ', 'মসৃন হোক জাগোর পথ চলা সুযোগ  অংশিদা র য়ার আশা আছে ', 'শিশুটি  আর দশ বাঁচবে   শেষ ক্রিকেটের ই   পাঁচ ের ছোট্ট শিশু স্ল্যার ওয়াকার  কোনো  পৃথিবীর মায়া ত্যাগ  চিরতরে চলে তে পারে ক্যান্সার আক্রান্ত শিশুটি ', 'পুশ ব্যাক আপনারে    চুপ থাকেন  ', 'তাদের  ব্যারিড  তাদের তল্লাশি চৌকি তাদের বর্ণবাদী দেয়াল সব টপ আমি আমার মাতৃভূমিতে ফিরে যাবই  আমি আরবের কালো মেয়ে আর আমরা আসছি যাবতীয় ক্রোধের সিঁড়ি বেয়ে ', ' কিছু অবশ্যই বাইরের  লোকরা সে জানতে পারছেনা ননা তারা সে পাশে না সামান্য কিছুই তাদের কাছে পৌঁছে তাই বললাম', 'সকালের উৎসাহ রাত বাড়ার    মিইয়ে গেলো  আপাত সাহসী শিপ্রার এত  বাড়িতে  দুটো বাচ্চা নিয়ে রাত কানো বেশ ভয়েরই  হলো ', 'বেঁচে থাকো বোন হাজার   মায়ের হৃদয় জুড়ে ', 'বল্টু বুঝে গেল মহা বিপদে ছে সে  এখনই চিতা তা ঘাড় মট খাবে  এখন  প্রাণ যাবে ', 'দায়িত্বে থাকা নার্স ইলা সিকদার ব্যবস্থাপত্র লেখার  শুনে রাগ   কক্ষ থে চলে যান  চিকিৎসক দেখাতে না পেরে হতাশ ে চলে যাচ্ছেন রোগীরা ', 'গাজা খুরি  ওরে ভিসা ছে     ', 'তুই ছাত্রলীগ তাই তুই স না সালাম ডান হাত দিতে   তোরা  বাংলা লোক না তোরা ইন্ডিয়ান দালাল  বাংলা লোক ভাবে  কয়', 'আমি হলাম আকাশ  কষ্ট আমার মেঘ  জোস্না আমার আবেগ   আমার কান্না  রোদ আমার হাসি  কি ে বুঝবে  বন্ধু তোমায় আমি কত ভালোবাসি  ', ' বিষাক্ত   যুগে যুগে  আছে থাকবে \nএই বিষাক্ত আগাছা  এরিয়ে চলাই উত্তম', 'সে বন্ধুরা আড্ডা দিচ্ছি  হাসছি   হঠাৎ  আমি বললাম  অনেকতো আনন্দ হলো এখন চলো আমরা  যার দুঃখ  শেয়ার করি  উ পাত্তাই  না  তখন  হলো  বেদনা আসলে লজ্জাস্থানের ো  ও লুকিয়ে রাখতে  ', 'ভালবাসা দাওনি ঠিক আছে অন্তত  দাওয়াত দিয়ো   অনেক ভালো্দ খাই না', 'এরদোগান কার বিরুদ্ধে হুংকার ে ইজরাইল দ্রুত সুস্থ হোক ফিলিস্তিনে নির্যাতন  করুক তাহলে আমরা খলিফা এরদোয়ানের হুংকার শুনতে পাবো  ', 'ো স্বপ্ন নিয়ে পোলট্রি খামার  ছিলেন গাজীপুরের আব্দুর রউফ স্বপন  কয়েক ের মধ্ লাভের মুখও দেখতে  ন তিনি   ফিডের অতিরিক্ত দাম  মুরগির নানা অসুখ বিসুখে প্রয়োজনীয় প্রতিষেধর অভাব  ো উত্পাদনকারীদের সঙ্গে অসম প্রতিযোগিতাসহ বিভিন্ন  থম  স্বপ্ন', ' হইল  কুত্তামারা মেকাপভরা মুখের ঢং দেখব নাকি কি বলতেছে তা শুনব  এ নিয়া ভাবতে ভাবতে আমার ডিপ্রেশনে  অবস্থা া  ' ...

777], [778], [779], [780], [781], [783], [787], [793], [794], [795], [796], [798], [799], [800], [801], [802], [803], [804], [806], [807], [808], [810], [811], [812], [813], [814], [815], [816], [818], [819], [822], [823], [826], [827], [829], [831], [834], [837], [838], [840], [841], [842], [843], [849], [850], [851], [852], [855], [856], [858], [860], [862], [863], [866], [867], [871], [874], [875], [876], [877], [878], [879], [881], [882], [884], [886], [887], [888], [891], [892], [893], [894], [895], [897], [899], [901], [902], [904], [905], [906], [908], [910], [912], [914], [915], [916], [918], [919], [923], [928], [931], [934], [935], [936], [943], [944], [946], [953], [958], [959], [960], [961], [962], [963], [964], [967], [968], [969], [971], [972], [973], [975], [977], [978], [979], [980], [981], [986], [987], [988], [991], [992], [993], [995], [999], [1001], [1003], [1004], [1007], [1008], [1011], [1018], [1020], [1021], [1022], [1023], [1024], [1025], [1026], [1027], [1030], [1031]]

# %%
for i in range(len(all_labels)):
    if all_labels[i]!=all_preds[i]:
        print(f"{all_labels[i]} and {all_preds[i]}")
# Out:
# 3 and 2
# 1 and 2
# 1 and 0
# 2 and 1
# 1 and 0
# 0 and 3
# 0 and 1
# 3 and 1
# 1 and 3
# 2 and 3
# 2 and 1
# 2 and 1
# 0 and 3
# 0 and 1
# 1 and 0
# 3 and 0
# 2 and 3
# 2 and 0
# 1 and 3
# 2 and 3
# 2 and 3
# 0 and 3
# 2 and 3
# 0 and 1
# 2 and 0
# 1 and 2
# 3 and 0
# 1 and 3
# 4 and 1
# 2 and 1
# 1 and 2
# 0 and 3
# 1 and 3
# 2 and 3
# 0 and 3
# 0 and 2
# 0 and 4
# 2 and 4
# 1 and 3
# 2 and 3
# 3 and 2
# 0 and 1
# 1 and 0
# 2 and 1
# 0 and 1
# 0 and 1
# 1 and 3
# 0 and 2
# 1 and 3
# 2 and 0
# 2 and 1
# 1 and 2
# 4 and 0
# 0 and 3
# 1 and 3
# 1 and 2
# 3 and 2
# 2 and 3
# 4 and 3
# 2 and 1
# 1 and 2
# 2 and 0
# 2 and 0
# 2 and 3
# 4 and 2
# 4 and 2
# 3 and 1
# 2 and 1
# 0 and 1
# 2 and 3
# 1 and 3
# 2 and 1
# 3 and 2
# 3 and 0
# 0 and 3
# 4 and 3
# 1 and 3
# 4 and 3
# 2 and 0
# 3 and 0
# 2 and 1
# 1 and 0
# 1 and 2
# 2 and 0
# 3 and 1
# 2 and 3
# 0 and 3
# 2 and 3
# 1 and 3
# 0 and 3
# 1 and 0
# 4 and 1
# 2 and 4
# 1 and 3
# 1 and 2
# 2 and 3
# 0 and 3
# 4 and 1
# 0 and 3
# 2 and 0
# 2 and 1
# 2 and 3
# 3 and 0
# 2 and 3
# 2 and 3
# 1 and 3
# 3 and 1
# 2 and 3
# 2 and 0
# 0 and 1
# 2 and 3
# 1 and 3
# 1 and 3
# 0 and 1
# 1 and 2
# 2 and 3
# 2 and 3
# 0 and 1
# 2 and 3
# 2 and 3
# 4 and 3
# 2 and 1
# 2 and 0
# 0 and 1
# 3 and 2
# 4 and 3
# 0 and 1
# 1 and 0
# 2 and 3
# 3 and 0
# 2 and 0
# 2 and 3
# 1 and 3
# 2 and 3
# 2 and 0
# 0 and 1
# 2 and 1
# 2 and 3
# 1 and 3
# 1 and 3
# 3 and 0
# 1 and 0
# 4 and 1
# 1 and 0
# 0 and 3
# 2 and 3
# 1 and 3
# 2 and 1
# 2 and 3
# 0 and 2
# 0 and 2
# 3 and 1
# 1 and 0
# 3 and 0
# 0 and 3
# 1 and 3
# 2 and 0
# 3 and 0
# 2 and 1
# 3 and 1
# 1 and 0
# 0 and 1
# 2 and 3
# 1 and 2
# 1 and 4
# 4 and 2
# 3 and 0
# 1 and 0
# 2 and 1
# 2 and 3
# 0 and 1
# 1 and 2
# 1 and 4
# 4 and 1
# 1 and 3
# 0 and 1
# 0 and 3
# 4 and 0
# 4 and 1
# 1 and 2
# 3 and 0
# 0 and 1
# 1 and 3
# 3 and 0
# 2 and 3
# 2 and 3
# 2 and 0
# 3 and 0

# %%
wrong = []
for i in position:
    wrong.append(validate_set["text"][i[0]])

# %%
print(wrong)
# Out:
# ['বাহ!সুন্দর', 'অমানুষের বাচ্ছা গুলু কে চাকরি নট করে দেনকি এমন সাহস আন্দলোন করেশালা চুরের দলএগুলুরে পিটায় চামড়া তুলে নিতে হবেজনতার হাতে ছেড়ে দিন এসব চোর গুলুকে', 'ওই মসতিক দের শাস্তি ভয়াবহ মৃত্যু যুবলীগ মালেশিয়া', 'স্যার একদম বড় চোরের গলায় হাত wow great', 'তোমি কোন সংবিদানের কতা বলতেচপৃথিবীতে সব ছাইতে বড় সংবিদান তো আল কোরআন।', 'ওদের মাথা টা এভাবে কাটা উচিতওরা তো মায়ের পেটে জম্ম হয়নি', 'ইমরান ভাই আপনি কি রাজনীতি বিরোধী দল হয়ার চেষ্টা করছেন ? অপোরাধি যেই হবে তাকেই শাস্তি পেতে হবে ', 'শুয়ারের বাচ্ছা imran', 'পুলিশ যে জনগণের বন্ধু এইটা আরেকবার প্রমাণ হইলো', 'যে এই কাজ করেছে সে একটা শুয়রের বাচ্চা', 'বাবুল দোস্ত মনে কষ্ট নিছ নাইমরাইন্না এমন কোন বিচারক না যে সে পাশে থাকলে বিচার পাবিবিচার পেতে হলে অামাদের সম্মিলিতভাবে প্রতিবাদ জানাতে হবেভুল হলে মাফ করিস', 'ঠিক', 'যারা সাংবাদিকতা করেন তাদের বয়স ৮০বছর হলে তারা যেকোনো অপরাধ করতে পারবেন সরকার তাদেরসেই ক্ষমতা দিয়ে দিলেই হয়!!', 'ধন্যবাদ দিয়ে ছোট করবো না  তবে এতটুকু বলতে পারি আপনাদের হাত দিয়ে এগিয়ে যাবে বাংলাদেশ  আপনাদের উজ্জ্বল ভবিষ্যত কামনা করছি ', 'দন্যবাদ বংলাদেশ পুলিশ', 'এদেশে শরকার শুদুনিজেদে টা বোজে', 'লুচ্চা সাংবাদিক', 'ইমরান ভাই আপনার কথায় সম্মতি দিলাম।। আমার বিবেচনায় এদেশের কয়েকটা বিপদজনক শ্রেণির কথা বলি- ১. হুজুর শ্রেণী ২. নাস্তিক শ্রেণী ৩. নারীবাদী ৪. রাজনৈতিক নেতা ৫. পুলিশ।।', 'খুব ভাল কাজ করেছে ', 'জাতীর নাতি তোমার উপর ক্ষ্যাপেছে তোমার যে আর রক্ষা নাই তারাতারি ভাগো এ দেশ থেকে', 'তনু হত্যার বিচার চাই হিন্দু মরলে খবর নাই........', 'দিন বদলের অপেক্ষায় 😃😃😃', 'আমার বয়স এখন ১২ বছর জাতীয় পরিচয় প্এ', 'হঠাৎ করা বিম্পির উপ্রে তোর দরদ উথলাই উঠলো কেরে ইমরান? খালেদার লগে বিয়া ঠিক হইছে নাকি তোর? 😎', 'ইসলাম বিদ্বেষী চ্যানেল একাত্তর টিভি এদেশে নিষিদ্ধ করা উচিৎ', 'ইউসুফ স্যার আমি দেশ এ আসলে আপনাকে আর একবার সালাম করতে আসব', 'হমন্দির পুতেগো গণধর্ষণ (ধোলাই) কইরা মাইরা লাওন দরকার', 'ঐ নিরাপত্তা প্রধানই সকল চুরির হোতা ওনাকে যথাযথ আইনি প্রক্রিয়ায় এনে বিচার করা হোক আশাকরি অন্যায়ের কাছে নতি শিকার করবেন না', 'এটা চলমান থাকুক আমরা তাই চাই।', 'ওকে', 'তুই তো একটা নাসতিক', 'শালারা কাফের মোনাফেক জারজ তাদের সাথে কথা বলাও পাপ', 'আপনার সাথে আমি এক মত', 'রাষ্টের সম্পদ অন্যের হাতে তুলে দেওয়া যদি দেশদ্রোহিতা হয় তাহলে রাষ্টের জনগনের ফিঙ্গার প্রিন্ট বিদেশি কোম্পানির হাতে তুলে দেওয়া কেন দেশদ্রোহিতা হবেনা ? আমি আমার ফিঙ্গার প্রিন্ট কোনো বিদেশি কোম্পানির হাতে তুলে দিব না এতে যদি সিম নষ্ট হয়ে যায় যাক তবুও দেশকে পাকিস্তান বানাতে সাহায্য করব না ! প্রয়োজন হলে সরকারের কাছে সম্পুর্ন উলঙ্গ হয়ে বডি প্রিন্ট দিতে রাজি আছি কিন্তু ফিঙ্গার প্রিন্ট দিয়ে সিম রেজিষ্টেশন করব না ! আমার একটাই দাবি বায়োমেটিক উপায়ে ফিঙ্গার প্রিন্ট দিয়ে সিম রেজিষ্টেশন বন্ধ করুন !', "চমৎকার দেশ। সবচেয়ে ভালো লেগেছে আইল্যান্ড না থাকার পরও কেউ গাড়ি নিয়ে রংসাইডে ঢুকে পড়ছে না রঙ সাইডে। বাংলাদেশের মানুষ হইলে অনেক পরিষ্কার পরিচ্ছন্ন। বাংলাদেশের এমন কোন দর্শনীয় স্থান নাই যেখানে ময়লার স্তুপ নাই। থাকবে না কেন ডাস্টবিনই তো নাই। ডাস্টবিন থাক্লেও সেগুলো ইউজ করার মানসিকতা আমাদের নাই। সবশেষে আমাদের দেশের মানুষের সামগ্রিক চিন্তাই চেতনাই নাই এই ব্যাপারে। যত যাই বলেন না কেন বাংলাদেশের পর্যটন শিল্প বুম করার একমাত্র বাধা হচ্ছে ' সাধারন মানুষের মানসিক অবস্থা' এর পরিবর্তন। নাহলে কোনদিন পরিবর্তন আসবে না।", 'আজ দুইটার সময় দেখলাম!', 'ইসলাম বিদ্বেষী চ্যানেল একাত্তর টিভি এদেশে নিষিদ্ধ করা উচিৎ', 'হা হা হা', 'একজন মুসলিম কখনো অন্য ধর্ম পালনে ব্যাঘাত করে না', 'আমারা যারা ছাএতারা কি স্টক করে মারা যাবো নাকি', 'ইমরান ভাই আমরা হিনদু বলে কি মানুষ নাভাই এটার বিচার চাই', 'এরা পেছনে লাগবেই ভাই ফালতু মানুষের তো অভাব নাই পৃথিবীতে আপনারা চালিয়ে যান :)', 'Yousuf Kazi পৃথিবীতে এখনও আপনার মত কিছু মানুষ আছে বলেপৃথিবীটা এখনও এত সুন্দর।ধর্মের থেকে মানুষ বড়সত্যি আপনাকে ধন্যবাদ দিয়ে আর ছোট করব না।', 'আপনার সাথে আমি একমত', 'আপনারা কি ছিঁড়তেছেন?', 'অসাদারন অনেক ভাল লাগলো', "'আমি একমত", 'আমরাও প্রত্যা\u200cশি। হয়\u200cতো বিন্দু থে\u200cকেই সিন্দু! এ সাইদ ভাইরাই আশার আ\u200cলো দেখা\u200cবে যারা এত\u200cদিন চুপ ছিল। কিন্তু আর কত? নুরু তারই ফ\u200cলে একট\u200cু আ\u200cগে গেল জে\u200cলে!', 'আরে এ তো জানুআরের কাজ????', 'অভিনন্দন পুলিশ এবং গণমাধ্যম (ফেসবুক)-কে। শিশুটির জন্য দোয়া রইলো শিশুটি সত্যিই সৌভাগ্যবান।', 'কই প্রতিবাদ করতে তো দেখিনা সনাতনপ্রেমী হলে গণজাগরণ মঞ্চে এর প্রতিবাদ করে দেখান ফেইসবুকে নয়', 'আমি আশ ...

# %%
# train_set = pd.DataFrame(train_list, columns = ['a','text', 'label'])
val = create_corpus(wrong)
val_filtered = filters(val)
x, y = get_top_words(val_filtered)

# %%
print(x)
# Out:
# ('##া', '##য', '[UNK]', '##ে', '##র', '##যে', '##যা', '##ার', '##ই', '##ন', 'তে', 'হয', '##ের', '##স', '##ান', '##চ', 'ব', '##ত', '##ি', '##াদ', '##যার', 'ভাই', '##ছে', '##ষ', 'পরত', 'মান', 'ভাল', '##ষট', '##ছ', '##দ', '##যব', 'দে', 'স', '##দের', 'ইমরান', '##ী', 'চে', '##তে', 'দি', '##ট', 'সাথে', 'কথা', '##তি', 'পলিশ', '##লাহ', 'আল', '##কে', 'ধন', '##ল', 'শ', 'নি', 'অন', '##তা', '##তিক', 'একটা', '##ক', '##ঙ', '##ড', 'আপনাদের', 'ম', 'ধরম', '##ায', 'মত', '##না', 'সরকার', '##িয', 'খ', 'ত', 'পরি', 'কিনত', '##টা', 'দ', 'জ', '##ম', '##বে', '##ধ', '##যন', '##িব', '##রা', 'হে', '##াক', 'পে', '##রে', '##ও', 'এগ', 'সত', 'গর', '##ব', 'বাচ', 'ভ', 'বড', 'কষ', 'বিচার', 'অা', 'দেশ', 'ইসলাম', 'এক', 'দেও', '##যি', 'অস', '##াগ', '##ষের', 'মস', '##ামা', 'টিভি', 'হ', '##ভ', '##শ', 'টাকা', 'টা', 'হিন', '##তত', 'দরকার', 'দেশের', 'বিমান', 'মা', 'বির', 'বাংলাদেশ', 'বে', 'নির', 'দর', 'অব', '##ছেন', 'নয', '##গে', '##ছা', '##াধ', '##ষা', 'আপনারা', 'মন', 'দেশে', '##ছি', 'শাস', 'মাথা', 'চাই', 'আপনাকে', 'সকল', '##গলে', 'সবাই', '##ণ', 'পরম', 'সম', '##তার', 'মে', 'করন', '##তব', '##াল', '##তরী', 'গে', '##াট', 'রা', '##াম', 'পড', 'চিনত', '##থা', 'সময', 'বিষ', '##কত', '##জ', 'শফিক', '##ানে', 'রক', '##যান', 'একা', 'চর', 'সরকারের', '##লিম', '##বক', 'ছাত', '##দা', 'মক', 'মর', '##থ', '##াকে', 'করম', 'ভল', 'কর', 'আন', '##চা', 'শর', '##াজ', '##পে', '##াপ', '##নট', 'সিম', 'বাংলাদেশের', '##ষক', '##প', 'একজন', 'একমত', '##টর', 'ষ', 'লে', '##ষে', '##তর', '##মা', 'সন', '##এ', 'তলে', 'ছে', 'বনধ', 'সাংবাদিক', 'ক', '##ির', 'আশা', 'শালা', '##দরে', '##পর', '##াই', '##নদ', '##টি', '##ঞ', 'মধ', '##লে', 'শে', '##কতি', '##দে', '##দর', 'চা', 'হও', 'হাতে', 'এসব', '##শি', '##ারা', '##াস', 'ছা', 'পন', 'ফর', '##ডের', '##েশ', 'তম', '##টে', '##েট', 'জামাত', '##বা', '##নীতি', 'কারে', '##জিন', 'খন', 'পরব', '##িত', 'গলে', 'পাবে', '##কষ', 'টক', '##কাশ', 'জানে', '##েন', 'কার', 'সংখ', 'বাংলা', 'বিশ', 'রেহমান', '##ধি', '##াণ', 'থাকলে', 'করছি', '##দেশ', 'এদেশে', '##েক', 'বছর', '##ষী', '##ধর', '##ালা', '##ধান', '##ানা', '##গ', 'আছি', '##ডি', 'হা', 'অভিন', '##যম', 'কই', 'আইন', '##াথা', '##পের', '##তিতে', 'আঘাত', 'জানি', '##জিস', '##াতে', 'বর', 'য', 'খারাপ', '##খ', '##ঠান', 'অপরাধী', 'নাম', '##ধে', 'পাও', 'খা', 'ধর', 'রিমান', '##কর', 'ছবি', '##িক', 'কমে', 'আছেন', 'পা', '##বন', 'সাহস', '##ডা', '##ারের', 'অপ', 'পাশে', 'অপরাধ', '##যত', 'প', 'বিদ', 'চ', 'সালাম', 'পত', 'থাক', 'জনগনের', 'ফি', '##গার', 'বাধা', 'কখন', 'চালি', 'একট', 'জান', 'ফেস', 'শিশ', 'বরজ', 'শক', 'ইসলামের', '##থম', 'এইচ', 'মানে', 'লেখা', '##ভব', '##রি', 'নিব', 'রাখতে', '##ফত', '##তরা', 'বললে', '##পত', '##ষন', 'মাত', '##সা', 'পাবেন', 'ঘে', '##লমান', 'দা', '##ডী', '##নে', 'নিচ', 'ি', 'হট', '##বেন', '##রী', 'বিএনপি', 'ইন', 'কানন', 'সনদ', 'চাকরি', '##গল', '##ডে', 'একদম', '##কার', '##দন', 'বদলের', 'উচিৎ', '##ফ', 'আসলে', '##মন', '##ষণ', 'কাফের', 'করব', 'গা', 'যাই', '##টার', '##াদা', 'লাগলে', 'নর', 'দেখি', 'একদিন', 'পার', 'আসন', 'শেষ', '##তির', 'যেভাবে', 'বলার', 'ফ', 'মিথ', 'আসে', 'অর', '##াবা', '##ধা', 'খে', 'হযেছে', '##ধন', 'বাচা', 'বাংলাদেশে', 'মার', '##িল', 'পলাশ', '##খলা', 'মনের', '##িমা', 'ছাগ', 'বিপ', '##কির', 'নে', 'গি', '##সে', 'লাগে', 'উপ', '##লা', '##ঘ', 'হউক', 'পারলে', 'করত', 'নামে', 'কিভাবে', 'বক', 'কারী', '##পেক', '##যাক', 'আমিন', 'জনম', '##হার', '##ঝা', 'বল', 'দিবে', '##িধ', 'উন', 'ইতিহাস', '##উন', 'মাল', '##াবাস', 'দল', '##লীগ', 'হাত', '##ানের', '##নি', '##যর', 'কামনা', 'দন', 'ল', '##কট', '##ষি', '##দির', 'ধে', '##ফেক', 'পাপ', 'ন', '##তান', 'লেগেছে', '##ছন', '##শন', 'সাম', '##পারে', 'মারা', 'সাইদ', '##চে', 'সেদিন', 'সমান', '##েছে', '##খে', 'যম', 'আয', 'শান', 'ভাইকে', 'হায', '##েরা', '##জন', 'চম', 'ভাং', 'সরাসরি', 'ফে', 'অবশ', 'জনগন', '##ভাব', 'কারনে', 'সাল', 'আব', 'বলছি', '##নের', 'শরদ', 'পলি', '##েও', 'পথে', '##রক', 'ড', 'উনার', '##ারদের', 'মখ', 'মি', '##ইল', 'ধরনের', 'কাজের', '##ীর', 'টার', 'খান', 'পালন', '##শে', '##ভাবে', 'নিজ', 'আগের', 'বজ', 'হই', '##লেন', '##াকার', 'তদ', '##ভে', 'তথ', '##বর', 'পরশ', 'কমি', 'মহা', 'ফাসি', 'কারন', '##পক', 'রাস', 'দেখছি', 'বদ', '##তন', '##হ', '##িন', 'দাদা', 'আঙ', 'ছাপ', '##সম', 'মতে', 'কাজটা' ...

# %%
len(x)
# Out:
# 2429

# %%
df1 = pd.DataFrame({"text":["আমি অন্ধকারকে ভয় পাই"],"label":[-1]})

# %%
final_test_data = makeDataset(df1)
final_test_dataloader = DataLoader(final_test_data, batch_size=16, shuffle=True)

# %%
all_preds = []
# all_labels = []

for batch in final_test_dataloader:
    text, _ = batch
    inputs = tokenizer.batch_encode_plus(
        text, **tokenizer_config
    )
    input_ids = inputs['input_ids'].to(device)
    token_type_ids = inputs['token_type_ids'].to(device)
    attention_mask = inputs['attention_mask'].to(device)
    labels = labels.to(device)

    # move things to model
    output = model(token_type_ids=token_type_ids, input_ids=input_ids, attention_mask=attention_mask)
    preds = output.detach().cpu().numpy()
    preds = np.argmax(preds, axis = 1)
    all_preds.extend(preds)
#     all_labels.extend(labels.cpu().numpy())

# %%
print(all_preds)
# Out:
# [4]
