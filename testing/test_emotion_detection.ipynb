# %% [markdown]
# # Text Emotion Detection

# %% [markdown]
# **importing essentials**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
import torch.nn.functional as fnc

# %% [markdown]
# **load dataset #1**

# %%
training_data1 = pd.read_excel("all_data/training_DS1.xlsx")
print(training_data1.groupby("reaction").apply(list))
print(f"shape = {training_data1.shape}")
print(f"dtype = {training_data1.dtypes}")
print(f"value count = \n{training_data1['reaction'].value_counts()}")

training_list = training_data1.values.tolist()
print("\n")
testing_data1 = pd.read_excel("all_data/testing_DS1.xlsx")
print(testing_data1.groupby("reaction").apply(list))
print(f"shape = {testing_data1.shape}")
print(f"dtype = {testing_data1.dtypes}")
print(f"value count = \n{testing_data1['reaction'].value_counts()}")

testing_list = training_data1.values.tolist()
# Out:
# reaction
# angry      [text, reaction]
# disgust    [text, reaction]
# fear       [text, reaction]
# happy      [text, reaction]
# sad        [text, reaction]
# dtype: object
# shape = (3096, 2)
# dtype = text        object
# reaction    object
# dtype: object
# value count =
# happy      1086
# sad         721
# angry       720
# disgust     357
# fear        212
# Name: reaction, dtype: int64
#
#
# reaction
# angry      [text, reaction]
# disgust    [text, reaction]
# fear       [text, reaction]
# happy      [text, reaction]
# sad        [text, reaction]
# dtype: object
# shape = (1032, 2)
# dtype = text        object
# reaction    object
# dtype: object
# value count =
# happy      351
# angry      269
# sad        224
# disgust    112
# fear        76
# Name: reaction, dtype: int64

# %% [markdown]
# **load dataset #2**

# %%
training_data2 = pd.read_excel("all_data/training_DS2.xlsx")
print(training_data2.groupby("reaction").apply(list))
print(f"shape = {training_data2.shape}")
print(f"dtype = {training_data2.dtypes}")
print(f"value count = \n{training_data2['reaction'].value_counts()}")

training_list = training_data2.values.tolist()
print("\n")
testing_data2 = pd.read_excel("all_data/testing_DS2.xlsx")
print(testing_data2.groupby("reaction").apply(list))
print(f"shape = {testing_data2.shape}")
print(f"dtype = {testing_data2.dtypes}")
print(f"value count = \n{testing_data2['reaction'].value_counts()}")

testing_list = training_data2.values.tolist()
# Out:
# reaction
# angry      [text, reaction]
# disgust    [text, reaction]
# fear       [text, reaction]
# happy      [text, reaction]
# sad        [text, reaction]
# dtype: object
# shape = (3720, 2)
# dtype = text        object
# reaction    object
# dtype: object
# value count =
# happy      883
# sad        810
# disgust    799
# angry      629
# fear       599
# Name: reaction, dtype: int64
#
#
# reaction
# angry      [text, reaction]
# disgust    [text, reaction]
# fear       [text, reaction]
# happy      [text, reaction]
# sad        [text, reaction]
# dtype: object
# shape = (1265, 2)
# dtype = text        object
# reaction    object
# dtype: object
# value count =
# happy      311
# disgust    289
# sad        275
# angry      208
# fear       182
# Name: reaction, dtype: int64

# %% [markdown]
# **data setting**

# %%
def clean_text(text):
    text = str(text)
    print(text)
    if "," in text:
        return str(text.replace(",",""))
    if "." in text:
        return str(text.replace(".",""))
    if "।" in text:
        return str(text.replace("।",""))
    if "|" in text:
        return str(text.replace("|",""))
    return str(text)
#     return "".join(char for char in text if char not in punchuation)

# %% [markdown]
# **emotion scoring**

# %%
def get_emotion(emotion):
    if emotion == "happy":
        return 0
    elif emotion == "sad":
        return 1
    elif emotion == "angry":
        return 2
    elif emotion == "disgust":
        return 3
    elif emotion == "fear":
        return 4

# %% [markdown]
# **ds1**

# %%
print(training_data1)
print("\n")
print(testing_data1)
# Out:
#                                                    text reaction
# 0     অপরাদি যে হোক, যে কোন বয়সের হোক না কেন, বিচারে...    happy
# 1     হাইরে মূর্খ বাঙালি। ডিজিটাল শব্দের অর্থ না বুঝ...     fear
# 2               নিশ্চিন্তে ভেঙে যাও, কেউ বলার নেই......     fear
# 3                        কেয়ামতের মাঠে তোমাদের ছাড়া নট।     fear
# 4     জনাব ইউসুফ এর মত কেউ অসহায় মানুষদের পাশে থাকলে...    happy
# ...                                                 ...      ...
# 3091                                            ধন্যবাদ    happy
# 3092  এগুলো মানব রচিত , বেদায়াত । ১লা বৈশাখ থেকে মুস...     fear
# 3093  আপনি সঠিক ও সৎ পথে রয়েছেন, বিজয় সব সময় সততার হ...    happy
# 3094                                 স্যালুট ইউ স্যার "    happy
# 3095                                               রাইট    happy
#
# [3096 rows x 2 columns]
#
#
#                                                    text reaction
# 0     কোরিয়ার ইনছন এয়ারপোর্টের মত শাহজালাল এয়ারপোর্ট...    happy
# 1                                           বাহ!সুন্দর।    happy
# 2     ভাই এতদিন আপনার সবকিছুই সাপোর্ট করে গেছি কিন্ত...      sad
# 3     অমানুষের বাচ্ছা গুলু কে চাকরি নট করে দেন,,কি এ...    angry
# 4     কী আর বলব? কিছুই বলার নাই। শুধু আপনাদের মত কয়ট...    happy
# ...                                                 ...      ...
# 1027                   শুধু পকেট ভারি করার ধান্দা......      sad
# 1028  এই সালা বড় একটা মাদার চোদ ভালবাসা দিবস আনছে এই...    angry
# 1029               আপনাদের ওপর আল্লাহর রহমত বর্ষিত হোক।    happy
# 1030  অপরাধ কারী এবং অপরাধী কে প্রশ্রয় দানকারী দুজন...  disgust
# 1031  যখন সরষেতে থাকে ভুত >>>><<<<< তখন বক্তা থাকে এ...     fear
#
# [1032 rows x 2 columns]

# %% [markdown]
# **ds2**

# %%
print(training_data2)
print("\n")
print(testing_data2)
# Out:
#                                                    text reaction
# 0     মামা ভয়ে ভয়ে লুকিং গ্লাসের কাপড় সরিয়ে দিয়...     fear
# 1     এই বয়সে নাতি নাতনিদের সঙ্গে আনন্দে মেতে থাকার ...  disgust
# 2                         আপু আপনাকে খুব সুন্দর লাগছে      happy
# 3     তোমার শহরের কোণে কেউ মায়া জমায় কি  আমি এখনো ভা...      sad
# 4     এর মাথা পুরোটাই নষ্ট  পশ্চিম বঙ্গবাসী একে ভোট ...    angry
# ...                                                 ...      ...
# 3715  আমি কষ্টের স্মৃতি নিয়ে করি বসবাস আমায় নিয়ে কখন...      sad
# 3716  আজ থেকে অফিসে এবং বাসায় প্রথম আলো পত্রিকা  বাদ...    angry
# 3717  এই নোয়াখাইল্লা বাইনচুদেরে বেধে লেংটা করে রোদে ...    angry
# 3718  হিরু আলম জায়েদ খান  ওরা ও  নায়েক আর নোবেল ও এক...  disgust
# 3719  সত্যি সাকিব ভাই আজ আপনি আবার প্রমান করলেন কেন ...    happy
#
# [3720 rows x 2 columns]
#
#
#                                                    text reaction
# 0     রিমঝিম এই বৃষ্টিতে  ঈদ কাটাবো সৃষ্টিতে   খুশির...    happy
# 1     এরই মধ্যে আবার মেয়র সাহেব বললেন  ডেঙ্গুতে মানু...  disgust
# 2     আমি বয়স্ক ছিলাম আমি একাকী সময় কাটাতে পারার ম...     fear
# 3     আবার যখন ঐ দুধের বাচ্চারা আপেল কাটার ছুরি দিয়ে...      sad
# 4     আমি হাসিমুখে রুমে ঢুকে বলতে যেতেই আমার মুখের হ...     fear
# ...                                                 ...      ...
# 1260                              আজ ও মেয়েরা সস্তা মাল      sad
# 1261  গুরুতর পরিস্থিতিতে ভয় পাবেন এটাই স্বাভাবিক  কি...     fear
# 1262  সব শ্রেণি ও পেশার মানুষ সরকারের শুদ্ধি অভিযানক...  disgust
# 1263                 সরকারের বিবিন বাহিমনিই এক মাএ ভরসা     fear
# 1264  আমি ছিড়ে ফেলেছি ডায়রীর পাতা  যেখানে লিখা ছিলো...      sad
#
# [1265 rows x 2 columns]

# %% [markdown]
# **cleaning ds1**

# %%
training_data1["text"] = training_data1["text"].apply(clean_text)
training_data1["label"] = training_data1["reaction"].apply(get_emotion)
training_data1["num_of_words"] = training_data1["text"].apply(lambda x:len(str(x).split()))

print("\n split \n")

testing_data1["text"] = testing_data1["text"].apply(clean_text)
testing_data1["label"] = testing_data1["reaction"].apply(get_emotion)
testing_data1["num_of_words"] = testing_data1["text"].apply(lambda x:len(str(x).split()))
# Out:
# মামা ভয়ে ভয়ে লুকিং গ্লাসের কাপড় সরিয়ে দিয়ে দেখে বাচ্চাটি একটা রক্তাক্ত পা চিবাই চিবাই খাচ্ছে
# এই বয়সে নাতি নাতনিদের সঙ্গে আনন্দে মেতে থাকার কথা তা নয় এ বুড়ো বয়সের ভীমরতি
# আপু আপনাকে খুব সুন্দর লাগছে
# তোমার শহরের কোণে কেউ মায়া জমায় কি  আমি এখনো ভাবি সেই তোমাকে ফেরানো যাবে কি
# এর মাথা পুরোটাই নষ্ট  পশ্চিম বঙ্গবাসী একে ভোট দেয়   ছ্যা ছ্যা ছ্যা
# আমি গত সপ্তাহের কতটা মনে পড়ছি তা দেখে আমি চমকে উঠতে শুরু করি আমি নিশ্চিত অসুস্থ কিছুটা নার্ভাস বোধ করি
#  শেষ সময়ে এসে কিছু তিক্ত ঘটনা ঘটে গেলো কিন্তু এর জের ধরে নিজ নিজ ইগো নিয়ে যদি সবাই বসে থাকি তাহলে আজ থেকে অনেক বছর পর অবশ্যই পোড়াবে
# রবি আজিয়াটা লিমিটেডের দুই ব্র্যান্ড রবি ও এয়ারটেলের আয়োজনে বাংলাদেশে প্রথমবারের মতো অনুষ্ঠিত হলো আন্তর্জাতিক অনলাইন গেমিং প্রতিযোগিতা  আজিয়াটা গেম হিরো   প্রতি দলে  জন করে  দলের  জন প্রতিযোগী বাংলাদেশ পর্বের চূড়ান্ত পর্বে অংশগ্রহণ করেন  অংশগ্রহণকারী টি দল প্রায়  লাখ টাকার পুরস্কার জিতেছে
# একটা সেকেন্ডও স্কিপ করিনি পুরাই আগুন ছিলো লাভ ফ্রম বাংলাদেশ
# জাহালমের আটক থাকার ঘটনাকে ন্যাক্কারজনক বলে সমালোচনা করে বিএনপির সিনিয়র যুগ্ম মহাসচিব রুহুল কবির রিজভী বলেছেন  তার  জাহালম  দীর্ঘদিন কারাভোগের ঘটনায় দুদকের ভূমিকা নজীরবিহীনভাবে ন্যাক্কারজনক
# স্কুলে ঠিক সময়ে পৌঁছতে না পারার ভয়  এইরকম কতশত ভয় নিয়েই তো আমরা বড় হই
# দায়িত্বে অবহেলা ডাক্তারদের শাস্তি মূলক ব্যবস্থা গ্রহণ করুন  এরকম ছোট মন নিয়ে ডাক্তারি পেশায় আসা উচিত হয়নি
# টিক টক পাগলের কথা জানি না
# কিন্তূ তোমার কথা শুনে
# সবাই হাসতে হাসতে পাগল হয়ে যাবে
# বাঁধন খুলে দিতেই নগ্ন আতঙ্কভরা চোখে সার্জনের দিকে তাকিয়েছিল রোগী  অবিশ্বাস  মিনতি  আতঙ্ক মিলেমিশে একাকার দুচোখে
# হঠাৎ কালো রঙের একটা প্রাইভেট কার সাদিয়ার সামনে এসে দাঁড়ালো সে গাড়িতে উঠতে যাবে এমন সময় গাড়ির ভেতরে কী যেনো একটা দেখে ভড়কে গেলো
# ভাইয়া অামি বাংলাদেশের জয়পুরে থাকি অামার এলাকায় করনার জন্য সব বন্ধ এমন ওভাবি লোক অাছে যারা খুবি ওসহায় অার তাদের দেখলে খুব কস্ট লাগে মনে হয় না খেয়ে মারা জাবে
# ছাত্রীকে যৌন হয়রানির অভিযোগ ওঠা জাহাঙ্গীরনগর বিশ্ববিদ্যালয়ের  জাবি  সরকার ও রাজনীতি বিভাগের এক শিক্ষককে বিশ্ববিদ্যালয়ের সব একাডেমিক ও প্রশাসনিক কার্যক্রম থেকে বিরত থাকার নির্দেশ দিয়েছে বিশ্ববিদ্যালয় প্রশাসন
# সোয়া আটটায় রোকেয়া হলের সামনে থেকে একলা ফেরত আসার সময় চাঁদের আলোয় বুঝতে পারলাম  ক্যাম্পাসের প্রতি মায়া চলে আসলো বোধহয়   সেইযে মায়া বাড়া শুরু করলো  হায়
# অধিকাংশ ভৌতিক সিনেমা দেখলে মনে হয় শুধুমাত্র বীভৎস সব চেহারা কিংবা রক্তভরা মুখ দেখিয়ে দর্শককে ভয় দেখানোটাই বুঝি পরিচালকের একমাত্র আগ্রহ ছিল
# দিদি দেখি পুরা পাগল হয়ে গেছে  ভারতে পাগলা গারত না থাকে বাংলাদেশে পাঠিয়ে দেও ভাল চিকিৎসা হবে
# কেন সে এত হাইপার হচ্ছে  এবং সে কী প্রমাণ করার চেষ্টা করছে  স্পষ্টতই এই অফিসার  স্বাস্থ্যকর্মী  ব্যাংকাররা বা লকডাউনের এই মুহুর্তে এখনও ডিউটিতে থাকা কর্মকর্তারা আমাদের বিনোদন দেওয়ার জন্য এখানে নেই
# সরকারের পক্ষ থেকে জনসমাগম এড়িয়ে চলার কথা বলা হচ্ছে  ইতিমধ্যে স্কুল কলেজ বন্ধ ঘোষণা করা হয়েছে  কিন্তু জনসাধারণের মধ্যে এ নিয়ে খুব একটা সচেতনতা তৈরি হয়েছে বলে মনে হয় না  নইলে প্রার্থনার নামে বড় জনসমাবেশ করা বা সন্তানদের শিক্ষাপ্রতিষ্ঠান বন্ধের সুযোগে ভ্রমণের পরিকল্পনা করত না এত মানুষ
# ইতিহাসের যেসব ভয়ংকর দিনের কথা শুনেছি সেগুলো কি আমরা এবার দেখতে চলছি আল্লাহ্ একটু করুনা করুন  রক্ষা করুন সবাইকে
# আরো একটু সামনে এগিয়ে কেমন এক অপার্থিব শব্দ শুনতে পেলাম  সারা শরীরের পশম খাড়া হয়ে গেলো
# উপস্থাপক কে শুদ্ধ বাংলা বলতে শিখিয়ে পাঠান  বুড়ো বয়সে এত নেকা উচ্চারণ কেনো
# শীশির ভেজা দুর্বা ঘাসে  শীশির কনা বলছে হেসে  বিদায় নিয়েছে হিমাল রাত  জানাই তোমাদের সুপ্রভাত
# জাতিগতভাবে আমাদের যে চোর বা পকেটমার পিটায়ে মাইরা ফেলার সংস্কৃতি  একজন নারী অপরাধীরে উনার অপরাধের শাস্তি পাওয়ার পরেও ধর্ষণের আমাদের যেই আকাংক্ষা  উনারে সম্মিলিতভাবে বেশ্যা বানানোর যেই প্রকল্প  তা থিকা আপনারা দয়া কইরা বাইর হইয়া সুস্থ হন  দয়া কইরা সুস্থ হন  দয়া কইরা সুস্থ হন
# তারা ঠিকই ব্যাডমিন্টন খেলে  অথচ মানুষের প্রজেক্ট আইডিয়া দেখার টাইম নাই  আমাদের  এর টাইমে তাদের টাইম হয়
# সরকার বলার পরই যদি সব মানতে হয়  তাহলে বিবেকটা কই রাখলেন  বিবেক বিবেচনাবোধ বলতে কিছু একটা আছ তো
# কোন জানি ঠেলা দেয় পরীক্ষায় কারণ জাতির গুরুদের তো হাত একটায় যে দেখিয়ে ছাড়বো দাড়াও  এই ভয়ে হয়তো কিছু স্পষ্ট জোর দিয়ে বলতেছে না
# কৃষ্ণকাঠি এলাকার জ্বরের রোগী সুখী আক্তার    বলেন   প্রচণ্ড জ্বরের কারণে দাঁড়াতেই পারছি না  ভাবছিলাম হাসপাতাল থেকে চিকিৎসা পাব  কিন্তু ডাক্তার জ্বরের রোগী দেখতে ভয় পাচ্ছেন
#  সাহস
# বলে যতই নাম ডাক থাকুক  ভূতের
# ভয় তার বেজায়
# কাজের কাজ কিছুই হয় না
# আসলে ভাই দোষটা ওর না দোষটা হলো দেশি বেলুন কম্পানি গোলার হালারপুতেরা অতিরিক্ত মুনাফা লাভের আশায় পাতলা করে কন্ডম বানায় আর এগোলা ফুটো হয়ে ওর মতো দুই একটা সানি লিওন জন্ম নেয়   এদের বাবা মা নাই     কেউ কি দেখতে পায়না এদের কর্মকাণ্ড
# শুনে খুশি হলাম  আরো ভাইরাস ছড়িয়ে পরলে   আরো পিছানো হবে    আহা কি আনন্দ আকাশে বাতাসে
# এই হল বালকাতায় পাকি বির্যের অবৈধ বংশ এ জন্য দেখবেন পাকিদে
# অনেকদিন পর ভাইদের সাথে দেখা     ভাইয়ের সাথে আড্ডা দিয়ে অনেক মজা পেলাম
# নোবেল মানষিক ভারসাম্যহীন হয়ে গেছে তাকে পাবনায় পাঠানো হোক
# আমার বড়ভাইকে পছন্দ হয়নি ভালো কথা  কিন্তু যে ছেলে দেখতে গেছে তার ছোটভাই কে কিভাবে পছন্দ হয়  মেয়েটার কি লজ্জা শরম বলতে কিছুই নেই  পরিবারই বা কি শিক্ষা দিয়েছে মেয়েটাকে
# হিংসা ও ঘৃণাকে দূরে সরিয়ে সাম্প্রদায়িক সম্প্রীতির হাত বাড়িয়ে দেয়ার আহ্বান জানান এই তারকারা
# রহিম নৌকাটার পাশে তাঁকাতেই চমকে উঠে  তার শিরদাড়া দিয়ে যেন ভয়ের একটা শীতল স্রোত বয়ে যায়  নৌকার ঠিক গা ঘেসে একটা মরা লাশ ভেসে চলেছে
# এখানে একদিন আমি কৃকেট খেলেছি
# মসৃন হোক জাগোর পথ চলা সুযোগ পেলে অংশিদা র হওয়ার আশা আছে
# এখনো তার ভৌতিক কর্মকান্ড থেমে নেই  কেউ তার অনুমতি ছাড়া ছবি তুললে তাকে ভয়ানক পরিণতির মুখে পড়তে হয়
# ভয় আছড়ে ভয় পাছড়ে ভয় নিত্য ভয় সনাতন ভয়
# শিশুটি হয়ত আর দশদিন বাঁচবে  তবে শেষটা ক্রিকেটের সাথেই   পাঁচ বছরের ছোট্ট শিশু স্ল্যাটার ওয়াকার  যেকোনো দিন পৃথিবীর মায়া ত্যাগ করে চিরতরে চলে যেতে পারে ক্যান্সার আক্রান্ত শিশুটি
# পুশ ব্যাক আপনারে করবো   চুপ থাকেন
# তাদের সেই ব্যারিকেড  তাদের তল্লাশি চৌকি তাদের বর্ণবাদী দেয়াল সব টপকে আমি আমার মাতৃভূমিতে ফিরে যাবই  আমি আরবের কালো মেয়ে আর আমরা আসছি যাবতীয় ক্রোধের সিঁড়ি বেয়ে
# দেশে অনেক কিছু হচ্ছে অবশ্যই বাইরের দেশের লোকরা সেটা জানতে পারছেনা কেননা তারা সেটা পাশে না সামান্য কিছুই তাদের কাছে পৌঁছে তাই বললাম
# সকালের উৎসাহটা রাত বাড়ার সাথে সাথে কেমন মিইয়ে গেলো  আপাত সাহসী শিপ্রার এত বড় বাড়িতে  দুটো বাচ্চাকে নিয়ে রাত কাটানোটা বেশ ভয়েরই মনে হলো
# বেঁচে থাকো বোন হাজার বছর বাবা মায়ের হৃদয় জুড়ে
# তাইলে পাপন অটো চয়েজ এগ্লা ফাইজলামি পাকিস্তানে যায় নাই তাই নাটক বানাইতেছে মনে হয় ওগো বাপে পাপন্স আইয়া খেইলা দিব
# বল্টু বুঝে গেল মহা বিপদে পড়েছে সে  এখনই চিতা তাকে ঘাড় মটকে খাবে  এখন যে প্রাণটা যাবে
# পরিচালক একটা নাম্বার ওয়ান লুইচ্চা       নয়তো ভদ্রতা বজায় রেখে যে নাটক তৈরী হয়ে থাকে সেখানে কেন এত পোষাকের অভদ্রতা
# বাংলাদেশের সঙ্গে সম্পর্ককে  আরও উচ্চতায়  নিয়ে যাওয়ার অঙ্গীকার পুনর্ব্যক্ত করেছে ভারত  আজ শনিবার নয়াদিল্লিতে প্রধানমন্ত্রী শেখ হাসিনার সঙ্গে সাক্ষাৎ করে ভারতের পররাষ্ট্রমন্ত্রী এস জয়শঙ্কর এই অঙ্গীকার পুনর্ব্যক্ত করেন
# ঝুমুর আপুকে অনেক সুন্দর লাগে হাসিটা অনেক সুন্দর আপু
# দায়িত্বে থাকা নার্স ইলা সিকদার ব্যবস্থাপত্র লেখার কথা শুনে রাগ করে সেই কক্ষ থেকে চলে যান  চিকিৎসক দেখাতে না পেরে হতাশ হয়ে চলে যাচ্ছেন রোগীরা
# আজকে তোরা চুপ থাকস কারণ এইগুলা তোদের স্পর্শ করে নাই  আজকে তোদের কিছু যায় আসে না কারণ তোদের ঘরে আগুন লাগে নাই  কিন্তু বেশি দিন লাগবে না টের পাবি  তোরাও টের পাবি
# সে মিথ্যা বলে আসলো আর সে মিথ্যা এই জন্য বলেছে কজ নিজের দেশে সে সিকিউরড ফিল করছেনা সংখ্যালঘু হিসেবে সে অপেক্ষাকৃত দুর্বলের মধ্যে পরে তাই কেউ মেরে ফেলার আগে জানপ্রান বাঁচাতে মিথ্যে বলেছে
# আপনাকে চক বাজারের পুরানা সেন্ডেল গুলো দিয়ে ইচ্ছামতো বাইরাইলে আপনি ঠিক হবেন মিঃ ফাহমি
# হে খোদা আপনি কাফেরদের দংস করে দিন
# গাজা খুরি কথা ওরে ভিসা দিয়েছে কে দেশের
# তুই ছাত্রলীগ তাই তুই জানিস না সালাম ডান হাতদিয়ে দিতে হয়  তোরা যে বাংলাদেশের লোক না তোরা ইন্ডিয়ান এর দালাল এই কারণে বাংলাদেশের লোক এই ভাবে কথা কয়
#    আমি      বিষয়ে ট্রেনিং এর জন্য নির্বাচিত হয়েছি  এই ট্রেনিং বাংলাদেশে এই প্রথম এবং এতে নির্বাচিত প্রত্যেকের পেছনে সরকারের খরচ হবে এক লক্ষ দশ হাজার টাকা  বিদেশি এক এর মাধ্যমে নেয়া এ ট্রেনিং এ পরীক্ষার মাধ্যমে নির্বাচিত সেরা  জনকে এই মডিউলে প্রশিক্ষণের সুযোগ দেয়া হয়েছে
# হাসপাতালে নেওয়ার পর চিকিৎসকরাও ভাবেননি ওয়াটসন বাঁচবেন   দিন কোমায় ছিলেন  মাথায় টি অস্ত্রোপচার করতে হলো  জ্ঞান ফেরার পর আরও ছয় মাস কাটল ইনটেনসিভ কেয়ারে
# আমি হলাম আকাশ  কষ্ট আমার মেঘ  জোস্না আমার আবেগ  বৃষ্টি আমার কান্না  রোদ আমার হাসি  কি করলে বুঝবে  বন্ধু তোমায় আমি কত ভালোবাসি
# রাজধানীর জুরাইন  শ্যামপুর  ধোলাইপাড়  দনিয়াসহ আশপাশ এলাকায় খাবার পানির তীব্র সংকট  ওয়াসার পানিতে দুর্গন্ধ  রং ও কালচে পানির কল ছাড়লেই দুর্গন্ধসহ ফেনায় ভরে ওঠে পাত্র  ওয়াসার পানির এই চিত্র নগরীর  নম্বর ওয়ার্ডের রসুলবাগের ইদ্রিস মিয়ার  নম্বর বাড়ি থেকে নেওয়া ছবি
# সমাজে বিষাক্ত মানুষ গুলো যুগে যুগে ছিল  আছে থাকবে
# এই বিষাক্ত আগাছা গুলো এরিয়ে চলাই উত্তম
# সেদিন বন্ধুরা আড্ডা দিচ্ছি  হাসছি   হঠাৎ করে আমি বললাম  অনেকতো আনন্দ হলো এখন চলো আমরা যে যার দুঃখ গুলো শেয়ার করি  কেউ পাত্তাই দিলো না  তখন মনে হলো  বেদনা আসলে লজ্জাস্থানের মতো  ওগুলো লুকিয়ে রাখতে হয়
# ভালবাসা দাওনি ঠিক আছে অন্তত বিয়েতে দাওয়াতটা দিয়ো কেমন  অনেকদিন ভালোমন্দ খাই না
# এরদোগান কার বিরুদ্ধে হুংকার দিবে ইজরাইল দ্রুত সুস্থ হোক ফিলিস্তিনে নির্যাতন শুরু করুক তাহলে আমরা খলিফা এরদোয়ানের হুংকার শুনতে পাবো
# সৃষ্টি হবে অন্যরকম গল্প আজ আলোর নিচে সাজাবো আমি  অন্ধকারের সাজ  দেখে আবার আসেনা যেনো  তোমার চোখে পানি  হঠাত্‍ করে দেখবে তুমি হারিয়ে গেছি আমি
# বড়ো স্বপ্ন নিয়ে পোলট্রি খামার শুরু করেছিলেন গাজীপুরের আব্দুর রউফ স্বপন  কয়েক বছরের মধ্যে লাভের মুখও দেখতে শুরু করেন তিনি  কিন্তু ফিডের অতিরিক্ত দাম  মুরগির নানা অসুখ বিসুখে প্রয়োজনীয় প্রতিষেধকের অভাব  বড়ো উত্পাদনকারীদের সঙ্গে অসম প্রতিযোগিতাসহ বিভিন্ন কারণে থমকে যায় তার স্বপ্ন
# কথা হইল  এই কুত্তামারা মেকাপভরা মুখের ঢং দেখব নাকি কি বলতেছে তা শুনব  এ নিয়া ভাবতে ভাবতে আমার ডিপ্রেশনে যাওয়ার অবস্থা হয়া গেছে
#  স্মৃতি আছে এখানে—আছে তার সমস্ত ভয়াবহতা নিয়ে
# অত্যন্ত আশাব্যঞ্জক খবর হলো  এই প্রবণতা এখন কাটতে শুরু করেছে  বেসরকারি উদ্যোগে রাজধানীর কয়েকটি হাসপাতালে নারীর স্বাভাবিক প্রসবের হার বাড়ছে  দেখা গেছে  এ বছর এসব হাসপাতালে  জনের মধ্যে  জন গর্ভবতী মায়ের স্বাভাবিক প্রসব করানো হয়েছে
# বার্মা থেকে আসা ইয়াবা ঠেকাতে তৎপরতা নেই অথচ অসহায় রোহিঙ্গাদের ঠেকাতে এতো তৎপরতা
# আমাদের বাংলা ভাষা সারা বিশ্ব ছড়িয়ে যাবে একদিন জয় হোক বাংলার
# বাঙ্গালী বরাবরের মতোই অতি আবেগী আর কুসংস্কার প্রিয়
# ও মাবুদ দয়ার আল্লাহ দুনিয়ায় সমস্ত মানুষ কে এই মহামারি গজব থেকে বাচিয়ে দিন  সবাই কে সিরাতল মুস্তাকিমের রাস্তায় আসার তৌফিক দান করুন  আমিন
# আজকের এই মহান রাতেই কিছু মৃত মানুষ প্রাণ ফিরে পেয়ে কবর থেকে ওঠে আসবে  কারণ আগামীকাল যে নির্বাচন
#  সালে কুয়াকাটা সমুদ্রসৈকতকে পর্যটন কেন্দ্র ঘোষণার পর থেকে সেখানে পর্যটকদের সংখ্যা ক্রমাগত বেড়ে চলেছে  স্থানীয় হোটেল ও মোটেল ব্যবসায়ীদের মতে   সালে কুয়াকাটায়  লাখের কাছাকাছি পর্যটক গিয়েছিলেন  ঘূর্ণিঝড় বুলবুল ও চলতি মৌসুমে শীতের প্রকোপ বেড়ে যাওয়ায় গত বছর পর্যটক সংখ্যা কিছুটা কমেছিল  তবে সংশ্লিষ্টরা আশা করছেন  শীত কমে গেলে পর্যটকের সংখ্যা আবার বাড়বে
# যেদিন খুলনা দিয়ে চলে আসার সময় হয় দেখি ছোট বোন দরজা আটকাইয়া কাদে  সারাদিন কাদে  সকালে থেকে শুরু করে রাত অবধি কাদে
# মাশাল্লাহ অনেক সুন্দর লাগছে আপু আপনাকে
# বাল ফালাইয়া টাল দিয়ে দিবে
# গভীর রাতে একটুখানি জানলা দিয়ে গান শুনতে পেয়ে কনর্সাটে যাওয়ার আকুলতা হত  এমনকি টিকেট কেটে অনেক দূরে যেতাম তা দেখতে  আর এখন প্রতিনিয়ত এসব দেখার সুযোগ থেকেও যেতে ইচ্ছে হয় না
# আজকে রাতে শহর থেকে ক্যাম্পাসে ফিরার সময় মাতামুহুরি বাসে আমার একটা ব্যাগ ভুলে ফেলে এসেছি  ব্যাগটি  এর ছিলো ব্যাগে কিছু কাপড় এবং একটি খাতা ছিল  যদি কেউ পেয়ে থাকেন তাহলে জানানোর জন্যে অনুরোধ করা হলো
# আমাদের এখনে দেখলাম যারা সারাদিন মোমবাতি জ্বালানোর বিরোধীতা করলো অথচ রাত হতেই বাজি ফাটাতে আরম্ভ করলো এরা জানোয়ার ছাড়া  আর কিছু না
# প্রতীক আসল কথা না   কথা হচ্ছে মানুষ টা কে
# কোনোকিছুকে ভয় পাচ্ছি মনে হলে  প্রথম যেটা মনে হয়  এই ভয়টা আমাকে কাটাতেই হবে
# অস্ট্রেলিয়ার পূর্ব উপকূলীয় এলাকায় গত সেপ্টেম্বর থেকে দাবানলের আগুন জ্বলছে  দাবানলে এ পর্যন্ত  জনের মৃত্যুর পাশাপাশি ব্যাপক ক্ষয়ক্ষতি হয়েছে  প্রশান্ত মহাসাগরে পৌঁছে যাচ্ছে ভয়াবহ এই দাবানলের ধোঁয়া
# ইট আর সিমেন্ট এর দেয়ালে মানুষের এক চিলতে ভালোবাসা আমাদের বাঁচতে শেখায়  বাঁচাতে  শেখায়  আল্লাহর কাছে প্রার্থনা করি যেন সুখে থাকো  ভালো আর সুস্থ থাকো
# এক্সপেরিয়েন্স হয়েছে বেশ হয়েছে  এতো নেগেটিভ রিভিউ এর পর আপনারা যান বলে তারা খাবার এর মান ঠিক রাখে না
#
# ভাইরে ভাই  গাজা খেয়ে সিনেমা বানালেও এতো বাজে সিনেমা বানানো সম্ভব না  এরা আসলে কি খায়
# দিপুর ডাক্তার হবার জেদের শুরু তখন থেকেই  দীর্ঘশ্বাস ফেললো দিপু  ওর এখন মনে হচ্ছে ডাক্তার না হলেই মনে হয় ভালো হতো
# কিছু না হলে তর শরীরের উন্নতি হয়েছে অষ্টলিয়া গরুর মত
# ভালবাসা বুঝি শুধু কষ্ট দিতেই জানে  তোমাকে ছাড়া যে আমার নিশ্বাস নিতেও কষ্ট হয়
# বন্যার পানিতে ডুবে গেছে ইতালির ভেনিস শহরের অধিকাংশ স্থান  এখন পর্যন্ত দুজনের মৃত্যু হয়েছে বলে জানা গেছে  ভেনিসের মেয়র লুইগি ব্রুগনারোর দাবি  জলবায়ু পরিবর্তনের সরাসরি প্রভাবেই এই বন্যা
# বিষাদ ছুঁয়েছে আজ  মন ভালো নেই  মন ভালো নেই  ফাঁকা রাস্তা  শূন্য বারান্দা সারাদিন ডাকি সাড়া নেই  একবার ফিরেও চায় না কেউ পথ ভুলকরে চলে যায়  এদিকে আসে না আমি কি সহস্র সহস্র বর্ষ এভাবে তাকিয়ে থাকবো শূন্যতার দিকে
# তোমার মত আমিও এইরকম একটা স্ট্যাটাস দিব ভাবছিলাম কিন্তু সাহস পাইনাই
# আপনাদের কি পাকিস্তান আর বি এন পি ছারা কোন খবর নেই
# এইভাবে করতে করতে যখন হাসপাতাল থেকে আর একটু দূরে তখন সেই মানুষদের মধ্যে থেকে একজন এসে জানালায় ঘুষি মেরে গাড়ির কাচটা ভেঙে ফেলল  ড্রাইভারকে মারধোর করে ফেলে রাখলো রাস্তায়  আর আমাদের কাছ থেকে কেঁড়ে নিলো আমাদের বাবুটাকে  কেঁড়ে নিয়েই ছুড়ে দিলো সামনের একটা জলাশয়ে  সেই জলাশয় আমি কোনোদিন দেখিনি  পুরো পানি কালির মতো কালো
# কোন মুভির নাম জানোস না আবার কথা কস অল ভিডিও বানাস বলদ কোথাকার
# আমরা চাই রোহাঙ্গাদের কে বাংলাদেশে ডুকতে দেয়া হওক
# আমি আর বাবা এটা নিয়ে অনেক মজা নিচ্ছিলাম  যদিও ক্লাস শুরুর পরে বুঝতে পারি ব্যাপারটা সিরিয়াস খুব কারণ আমাদের ফার্স্ট ইয়ারে ক্যাম্পাসে ছেলে মেয়ে কথা বলা নিষিদ্ধ ছিলো  যেটা খুবই ফ্রাসট্রেটিং
# মেডিকেল এর ফাস্ট ইয়ার এ যখন কলেজের  তালায় হোস্টেল এ ছিলাম     আজ কতই না আমূল পরিবর্তন  ভালই ছিল সেই দিনগুলি বন্ধু
# পানি যেন বেশিদূর না গড়ায় তাই অলিম্পিয়াস একজন শিষ্যকে ঘুষ দিয়ে বিয়ের অনুষ্ঠানেই নিজের স্বামীকে খুন করালেন  অন্যদিকে সতীন ক্লিওপেট্রাকেও মেরে ফেললেন বিষ খাইয়ে
# খেলার মাঠের মেয়েটিকে ধরে রান্নাঘরে আটকে দেওয়ায় কোনো সমস্যা নেই  সমস্যা হলো মেয়েটি পড়ালেখা করে নিজের পায়ে দাড়ানোটা  এই সমাজে মেয়েদের কোনো স্বাধীনতা নেই  নেই নিজেকে আত্মপ্রকাশের সুযোগ  শুধু মুখেই বলি আছে নারী পুরুষ সমান অধিকার
# কেউ রান্না করতে ভয় পায়  কেউ আবার বেড়াল দেখলে কেঁপে ওঠে
# আরে মূর্খ বলদ আগে সঠিক ভাবে  গাধা  বানান শিখে আয় তারপর  গাঁদা  বইলা গালি দিস  আবাল কোথাকার
# সময় বদলে যায় জীবনের সঙ্গে জীবন বদলে যায় সম্পর্কের সাথে সময় বদলায় না আপনজনের সঙ্গে শুধু আপনজন বদলে যায় সময়ের সঙ্গে
#  সব মাছে গু খায় গাওরা মাছের দোষ হয়    শুধু মিডিয়া জগতে নয়  অন্য প্রতিষ্ঠান গুলোতে কি হয় না   অবশ্যই হয়   আমি  এ পা দিলাম  অভিজ্ঞতায় বাস্তব অর্জন কম নয়
# আমরা জিতলেও বাংলাদেশ হারলেও বাংলাদেশ
#  ডিয়ার বাংলাদেশ নাটকে ইনি অভিনয় করেছেন আমার তখন থেকেই এই আপুকে ভালো লাগে
# লোকটি আগের আমলের মণি ঋষিদের মতো লম্বা চুল  খালি গায়ে বসা  চোখ বন্ধ  তবে রমিজ সাহেব সবচেয়ে যেই
# জিনিসটা দেখে ভয় পেয়েছিলেন যে  ঐ বৃদ্ধ লোকের গা দিয়ে আলোর মতন বের হচ্ছে এবং আশ্চর্য এক মায়াবী গন্ধ পুরো ঘর জুড়ে
# ভুটানের   এত সুন্দর বাংলা বলতে পারে গর্বে বুকটা ভরে গেল
# গলা বাজিতে কাজ হবেনা দিদি
# কোথায় স্বাস্থ্যসেবার প্রতি ধন্যবাদ দিয়ে নিউজ করাবে আসছে এখন ব্লেইম গেইম খেলতে  গরুছাগল জীবনে মানুষ হবেনা
#   সেশনের মেডিকেলের ভর্তি পরীক্ষায় জঘন্যতম প্রশ্নফাঁসের শিকার এই ব্যাচটাই যখন প্রথমবারের মতো ভর্তিযুদ্ধে অংশগ্রহণ করে
# যদি খোদা সবাইকে একরকম বানাতে চাইতেন তাহলে তিনি সবার পায়ে ধনুর্বন্ধনী লাগিয়ে দিতেন
# এত বছর ক্ষমতায় থাকার পরেও দেশের এ অবস্থা  ধিক্কার জানাই সরকারের অব্যবস্থাপনাকে
# আপনার মত ভদ্র একজন মানুষের কাছ থেকে এই মনোভাবই  আশা করা যায়  আপনি অসামান্য একজন মানুষ  গায়ক  ইন্ডিয়া থেকে আপনার একজন গুণমুগ্ধ
# এইল লোকের নাটক ভালো লাগছে
# এরা রেঁধে এরাই খায় আমার কি লাভ  আমিতো ববিতার কম ছবি দেখি নাই  আগে জানলে ছবিও দেখতাম না টাকাও খরচ করতাম না ববিতাও এতো বড় পাহাড়ের চুড়ায় উঠতে পারতোনা
# অস্ট্রেলিয়ায় বিশ্বের অন্যতম ভয়ংকর বিষাক্ত ছত্রাকের সন্ধান মিলেছে  ফায়ার কোরাল নামের এই ছত্রাক দেখতে ভোজ্য মাশরুমের মতো  বৃহস্পতিবার এ তথ্য প্রকাশ করেছেন দেশটির জেমস কুক ইউনিভার্সিটির একদল গবেষক
# ওর ঘরে গিয়ে দেখি ওর ঘাড়ের মাংস অধেক নেই আর মেঝেতে রক্ত পড়ে আছে  শিবানি আর শিবানি নেই
# একটা জিনিস খুব ভাল্লাগে আমাদের বিশ্ববিদ্যালয়ের টা হলের টা আমাদের বিশ্ববিদ্যালের সাবেক ছাত্রদের নামে যারা কিনা মুক্তিযুদ্ধে প্রাণ দিয়ে গেছেন
# আমি তাদের কাছাকাছি থাকতে ভয় পেয়েছি এখনই আমার ব্লগ লেখা বন্ধ করা উচিত
# সে আমাকে বুকে জড়িয়ে কেবল বলেছিল   তুমি কেঁদে কী করবে  সারাদেশে তোমার বাবার মতো কত মানুষকে মেরেছে ওরা  সারা দেশটাই তো আজকে কাঁদছে
# বাইরে কেমন যেন একটা খসখস শব্দ হচ্ছে  তার মনে হচ্ছে কেউ যেন হেঁটে হেঁটে তার কাছেই আসছে  সে চোখ বন্ধ করে সমানে দোয়া পড়ে যাচ্ছে  এভাবেই সারাটা রাত প্রচণ্ড ভয়ে না ঘুমিয়ে কাটল সোমার
# আমি সিঙ্গেল রুমে থাকতাম   কিছুটা ভয় পেয়ে পাশের রুমের বড় ভাইকে ডেকে তুললাম
#  সালে অনুষ্ঠিত রিয়েলিটি শো  ফেয়ার অ্যান্ড হ্যান্ডসাম  প্রতিযোগিতার প্রথম রানারআপ রিয়াদ রায়হান হচ্ছেন কবরীর নতুন সিনেমার নায়ক
# শীতল সকালে মুন্সীগঞ্জ এর আলদী বাজারে মাঠা খেয়ে আসলাম
#
# এই সকালে কুয়াশা  শিশির অন্যরকম হয় সকালবেলা  খেজুররস  মাঠা  ছানা  দই  মুন্সিগঞ্জ এর আলাদী বাজার এলাকার হিন্দু ঘোসেরা এই পেশায় নিয়োজিত  যুগ যুগ ধরে এই মাঠার দোকান গুলো প্রাচীন ঐতিহ্যের একটি অংশ হয়ে আছে আলদী বাজার এলাকার লোকালয়ের মাঝে
# যে মসজিদ এতো গুরুত্বের তার নামাজিরা কতো গুরুত্বের  আসুন নিয়মিত নামাজ আদায় করি
# এমন করে এগিয়ে যাও বাংলাদেশ
# শিওর গাঁজা খেয়ে প্রশ্ন করছে    আর মেয়েগুলা আন্তর্জাতিক পর্যায়ে কমপিট করবে  তারা প্রেশার সিচুয়েশনে এইভাবে ঘাবড়ে গেল  তাদের গ্রুমিং করছে কোন ছাগলে   পুরা শো টাই ক্রিঞ্জ
# সবচেয়ে ভয়ংকর ব্যাপারটা হচ্ছে মৃত বাচ্চাটি সিটের উপর দাড়িয়ে তাদের দিকে মুচকি হাসছে এবং বাচ্চাটির চোখের মনি নেই
# ওরে শালার ফরমালিন গুগল ও বের হয়ে গেছে
# চুয়েটে  বছর থাকাকালীন কখনো দেখি নাই  এমনও হয়েছে যে হল গুলোকে সাউথ ও নর্থ হল নামেই অনেকে চিনে  আসল নাম অনেকে জানেই না
# পাকিস্তানে টেস্ট   তে  তাহলে পাকিস্তান সফর ও তো  মুজিব বর্ষের শ্রেষ্ঠ উপহারের তালিকায় থাকা উচিত
# পুলিশ বলেছে  হাতুড়ি দিয়ে মাথায় আঘাত করে মুন্নীকে  আর দুই শিশুকে শ্বাসরোধ করে হত্যা করা হয়েছে
#  জিহাদ ও খেলাফতের সিলসিলা বইটিকে নামের কারনে এক অনলাইন পরিবেশক তাদের ওয়েবসাইটে রাখেন নাই  দুইজন পাঠক বইটির কারনে পুলিশের হাতে হয়রানি হয়েছেন
# ইননানিললাহি ওয়া ইননা ইলাইহি রাজিওন আললা ওনাকে জাননাতের মেহমান হিসেবে মেনে নিন আমিন
# আমরা একটু আগে দেখলাম খুব ভাল লেগেছে
# নাজমা কি মারা গেছে নাকি তাকে মারা হয়েছে    হায়রে বাংলাদেশ    কেন যে এই বাংলাদেশে গজব পরেনা
# চাকায় একটা ব্রেক চিলো ঐ চুইচ টা পা দিয়ে চাপ দিলে হতো ঐ খানে যারা চিলো বলদ মার্কা তাই এমন হলো ঐখানে লোকগুলো দেখতেছে সবাই সহযোগিতা করলে এমন হতোনা সব শালারা ভিডিও করতেছে সব মাদারচোদ
# আপনি একবার কাচ্চি ভাইয়ে গিয়ে কাচ্চি খাদক খেয়েছিলেন তা দেখে আমরা গিয়েছিলাম কিন্তু সেখানেও আমাদেরকে আপনার চাইতে চাল ও মাংস পরিমাণের অনেক পার্থক্য ছিল  তাই এখন আর আপনাদের ব্লগ দেখে যাওয়ার চিন্তা করিনা কারন ওটা আপনাদের জন্যই ঠিক আছে
# করোনাভাইরাস ছড়িয়ে পড়ার আতঙ্কে যুক্তরাষ্ট্রের সান ফ্রান্সিসকোতে আগামী মার্চ মাসে অনুষ্ঠেয় মার্কেটিং সম্মেলন বাতিল করেছে ফেসবুক কর্তৃপক্ষ
# ভাই এটা কি আপনি গল্প লিখলেন আমার মনে আতঙ্ক শুরু হয়েছে আর এরকম গল্প পোস্ট করেননা প্লিজ  ভয় লাগে
# সে জানে যে  এরপর সে নিজেও মারা যাবে  তার মৃত্যু অতি সন্নিকটে  পরিবারের বাকি সদস্যদের মতো সেও হয়তো কোন এক দুর্ঘটনায়ই মারা যাবে  তার মৃত্যুও এবার কেউই ঠেকাতে পারবে না
# চুরির চুরি উল্টো সিনা জুরি  আবার সাংবাদিক কে তাদের দায়িত্ব শিক্ষাচ্ছে  বাটপারটাকে উচিৎ শিক্ষা দেয়া খুব জরুরী
# আমার চোখমুখ দেখে সম্ভবত কিছু একটা আচ করলো সে ভয়ে ভয়ে জিজ্ঞেস করলো কি হয়েছে স্যার  আমি কাঁপা গলায় বললাম রাসেল ফাসির মঞ্চের দিকে তাকিয়ে দেখো ত কিছু দেখতে পাচ্ছো
# পকি তোদের মা আর রেন্ডিয়া তোদের বাপ লগে নাকি অন্যের চরকায় তেল না দিয়ে নিজের চরকায় তেল দে নিজের দেশ নিয়ে মাথা ঘামা
# তোমার জন্য এই রোদেলা স্বপ্ন সকাল  তোমার জন্য হাসে অনরল স্নিগ্ধ বিকেল  ভালবাসা নিয়ে নিজে তুমি  ভালোবাসো সব সৃষ্টিকে
# জাতীয় অধ্যাপক ড  আনিসুজ্জামান বলেছেন   যারা প্রতিবন্ধী  তাদের প্রতি সমাজের একটা বিশেষ দায়িত্ব আছে  কিন্তু সেই দায়িত্ব সম্পর্কে আমরা খুব সচেতন নই  সচেতন হলে তাদের কল্যাণে অনেক প্রতিষ্ঠান ও সংগঠন গড়ে উঠত
# আজও কষ্ট পায় কিন্তু কিছু করতে পারেনা  তাই আজ আমরা আলাদা হয়েও হয়ত আলাদা নই
# দয়া কইরা আপনাদের এইসব অসৎ শিক্ষকদের  আপনাদের অসৎ গবেষক  আপনাদের অসৎ চিকিৎসক  আপনাদের অসৎ রাজনীতিবিদদের লাত্থি দিয়া ফালায়ে দেওয়া শিখেন
# লোকটা ভয়ে ভয়ে বলল মানে  মেয়েটা ভয়ংকর একটা হাসি দিয়ে বললমনে পড়ে আজ থেকে দশ বছর আগে রাস্তার পাশে একটা মেয়ের লাশ পড়ে থাকতে দেখেছিলেন
#  বাংলাদেশটা ভালো নেই     লাল সবুজের দেশটাতে সবুজ হারিয়ে শুধু রক্তের লাল রয়ে গেছে
# যে দেশে একজন করোনা  রোগীকে সামন্য আইসিউ দিতে পারেনা সে দেশে মানুষ কিভবে চিন্তা করবে যে হাসপাতল গুলোতে চিকিৎসা পাবে
# যতই প্রমান দেখাছ কাজ হবে না   আমরা সব ইতিহাস জানি তাই তোর এই বালের লিঙ্কে ঢুকে ফাদে পড়তে যাবো না
# শিল্পোদ্যোক্তারা সেটির বিরোধিতা করে বলেন  কাঁচামাল হিসেবে ব্যবহৃত শিল্প লবণের শুল্ক বাড়ালে শিল্পকারখানা ক্ষতিগ্রস্ত হবে  অন্য দিকে মিলমালিকেরা সোডিয়াম ক্লোরাইড আমদানির অনুমতি চান
#  সাল থেকে এ পর্যন্ত মানুষের নাগালে থাকা স্বাদু পানির সহজলভ্যতার পরিমাণ অর্ধেকে নেমে এসেছে  ফলে বিশ্ববাসী সুপেয় পানির ঘাটতির চাপে পড়েছে
# বিরোধের জের ধরে এই দুই গ্রুপের মধ্যে আগেও বেশ কয়েকবার বন্দুকযুদ্ধের ঘটনা ঘটেছে  সর্বশেষ গত  ডিসেম্বর ভোরে দুই বাহিনীর মধ্যে গোলাগুলিতে জোনাব আলীর ছেলে কায়সার গুরুতর আহত হন  পরে চিকিৎসাধীন অবস্থায় তিনি মারা যান
# আপনার ইংরেজি উচ্চারণ শুনলে ইংরেজি শেখার আগ্রহ বেরে য়ায়
# পরবর্তী ভিডিও র অপেক্ষায় রইলাম
# ছোট থেকেই শুনতে হতো আমি আপুর মতো না আমাদের বোন বলে মনে হয় না বিয়ের অনুষ্ঠানে অথবা ফটো ফ্রেমে পরিবারের সবার মাঝখানে নিজেকে খাপছাড়া লাগতো সবাই ঠাট্টা করে বাবা মাকে বলতো  ওকে দেখে বোঝা যায় না আপনাদের সন্তান   কথাটা গায়ে কাঁটার মতো লাগতো
# মাঝেমধ্যেই রাফিদের ভয়ংকর চিৎকারে আমার ঘুম ভেঙে যায়  কখনো তিন চারদিনের জন্য উধাও হয়ে যায়  কই চলে যায় কে জানে
# মাঝে মাঝে মনে হয় কান এর নিচে একটা চওর লাগাই দিই   অনেক অসহ্য লাগে মাঝে মাঝে তার উপর  একটা বেত নিয়ে মনের জোট ক্ষোভ আছে সব মিটাই নিই
# ব্যস্ত বগরীর ব্যস্ত পথগুলো এতোটা ফাঁকা হতে আর কখনও দেখিনি
# সবকিছু স্থবির  স্থির হয়ে আছে
# অজানা অচেনা প্রতিষেধকহীন এই ক্ষুদ্র অনুজীবের আড়ালে আঘাতে
# আমি খুব অনিশ্চিত বোধ করছি এবং আমি চাই না যে আপনি প্রেম করার জন্য চাপ অনুভব করবেন
# মমতা বলেন   এখনো দিল্লিতে মিলছে মানুষের মৃতদেহ  গতকালও চারটি মৃতদেহ মিলেছে  প্রতিদিন নালা খুলছে আর বের হচ্ছে মৃতদেহ  দিল্লি থেকে আজ বহু মানুষ প্রাণের ভয়ে পালিয়ে গেছে  এবার দিল্লির মানুষের পাশে দাঁড়াতে হবে
# ক্যাম্পাসে কিছু হেডম ওয়ালা কর্মচারী থাকে   এদের ভাব স্যারদের থেকেও বেশি  মনডা চায়        নিয়া এগুলারে  করি
# আমার কিছু বলতে ইচ্ছা করছিল না  তবু বললাম
#  বিগত   ইং তারিখে কতিপয় উশৃঙ্খল শিক্ষার্থী কর্তৃক আমার অফিস কক্ষের সামনে আমারসহ আরও কিছু শিক্ষকদের নাম ফলক ও জানালার কাচ ভাংচুর করা হয়  যা আমার গায়ে হাত তােলারই সমতুল্য
# স্বাধীনতার  বছর পরে একটা স্বাধীর রাষ্ট্রের কাছে এই চাওয়া গুলো কি খুব বেশী কিছু চাওয়া  মানুষ যদি নাই বাঁচে  প্রতি মুহুর্তে একটা ভীতির মধ্যে থাকে তবে কি হবে  সমূদ্রের মাঝখানে ব্রীজ বানিয়ে কিংবা আকাশ চুম্বি ভবন নির্মাণ করে
# জনগণের ভোটে নির্বাচিত এই সরকারের কোন জনদরদী নেতার কানে এ কথাগুলো পৌঁছাতে পারলেই ওদের আর কোন চিন্তার কোন কারণ থাকবে না
# বিদেশি শ্রমিকদের টাকা দিয়ে দেশ উন্নয়ন হচ্ছে আপনাদের টাকায় না
# শিক্ষকের হাত থেকে শাসনের বেতটি কেড়ে নেওয়ার কারণেই আজ প্রতিটা সমাজে তথা দেশে এতো বেশি বেয়াদবের জন্ম
# এই দানব রাষ্ট্রের সাথে অামাদের কোন যোগা যোগ থাকতে পারেনা
# সবগুলো রে জুতার মালা দিয়ে সংবর্ধনা  দেওয়া হোক
# যারা তাকে বিশ্বাস ঘাতক বলে এখন তারা আসলেই বোকা  কেননা তারা জানে না কুকুরের লেজ কখনও সোজা হয়না
# ছবি গুলা বেশি কিউট  অসংখ্য ধন্যবাদ এত সুন্দর আর কিউট ছবি দিয়ে উইশ করার জন্য
# আচমকা আমার গায়ের ওপর একটা শীতল হাতের ছোঁয়া পেয়ে আঁতকে উঠলাম ভয়ে  বুক ধুকধুক করে উঠল
# এতো ভালো একটা গান থাকতেও আমার বিয়েতে এই গানটা বাজানো হলো না
#
# আইজকাই ছোট ভাই গুলারে বাইন্ধা ট্রস ট্রস কইরা পিডামু
# বাস্তবতা এতই কঠিন যে কখনও কখনও বুকের ভিতর গড়ে তোলা বিন্দু বিন্দু ভালবাসাও অসহায় হয়ে পড়ে
# আমি চিৎকার করে আমার ওরনা দিয়ে ওর হাতটা বাধলাম আমার চিৎকার শুনে আশেপাশের সবাই ছুটে এসে আমদেরকে হাস্পাতাল এ নিয়ে যায়
# আমদানিনির্ভরতা ছেড়ে প্রমিক্সো উৎপাদকে পরিণত হওয়ার ফলেই এমনটা হয়েছে  আর মৌসুমী ইসলামের প্রমিক্সো হেলথ কেয়ার তো এখন বিদেশেও চিকিৎসা সরঞ্জাম এবং ফার্নিচার রপ্তানির স্বপ্নও দেখছে
# আমি বাবাকে জড়িয়ে ধরে চিৎকার করে কান্না করতে করতে বললাম বাবা আমার টাকা লাগবে না
# সব ধরণের পদক্ষেপ নেওয়া আছে   আর  সঠিক সময়ে সঠিক সিদ্ধান্ত নিয়েছি বলেই করোনা নিয়ন্ত্রণে রাখতে পেরেছি   ইউরোপ  আমেরিকা যেখানে হিমশিম খাচ্ছে   সেখানে বাংলাদেশে আমরা নিয়ন্ত্রণে রাখতে পেরেছি   কারণ সঠিক সময়ে সঠিক সিদ্ধান্ত   আর   আমরা করোনার চেয়ে শক্তিশালী   বাকি সব গুজব    এসব কথা শুনলে বা চিন্তা করলে ভাবি   আমরা কেমন মানুষ  অনেক আশ্চর্য লাগে
# একসময় সে বললঃ  তোমাদের মত এত কিছু কেউ জানতে চায়না  সবাই ছবি তুলে চলে যায়  তোমাদের আগ্রহ দেখে ভালো লাগল
# বুয়েটছাত্র আবরার হত্যাকাণ্ডে নানা ধরনের মন্তব্য আসছে সামাজিক যোগাযোগ মাধ্যমগুলোতে  এ হত্যাকাণ্ড নিয়ে নিজের ফেসবুক পেজে স্ট্যাটাস দিয়ে আলোচিত হয়েছেন ভারতীয় তরুণী তনুশ্রী রায়  কলকাতা নিবাসী যাদবপুর বিশ্ববিদ্যালয়ের ছাত্রী তনুশ্রী তার স্ট্যাটাসে লেখেন   যদিও আমি ভারতীয় তারপরও বাংলাদেশের প্রতি আমার আলাদা টান রয়েছে  কারণ আমার পূর্বপুরুষ বাংলাদেশের মানুষ ভালো থাকুক এটা আমি সব সময় চাই
# আনিসুল হক স্যারের অভাব পূরন হবার নয়
# পোস্টের কমেন্টবক্সে লকডাউনে ঘরে আটকে থাকা আমাদের মতো মানুষজন গিয়ে হাহুতাশ করছে  জীবনে জীবনে কত পার্থক্য
# মারুফ হেয়ার কাট জোশ ছিল এটা  রাকিব ভাই আপনি পুরুষ না  মহা পুরুষ ভাই মহাপুরুষ
#  নিরাপত্তাহীনতায় ভুগছেন  জানিয়ে থানায় পাঁচটি সাধারণ ডায়েরি  জিডি  করেছিলেন ব্যবসায়ী মো  ইয়াছিন আলী  আশঙ্কার কথা জানিয়ে আবেদন করেছিলেন পুলিশের কর্মকর্তাদের কাছেও  শেষমেশ তিনি খুন হয়েছেন  তাঁর লাশ পাওয়া গেছে রাজধানীর শেরেবাংলা নগর সরকারি বালিকা উচ্চবিদ্যালয়ের প্রধান ফটকে
# আমি তো সমাজ বহির্ভূত কোনো মানুষ না তবে কেনো আমি তোমাদের মতো করে চিন্তা করতে জানিনা খুব বেশি কিছু কি চেয়েছিলাম  খুব সরল একটা ভালোবাসা ছিলো আমার  অল্প দামের একটা শার্ট হলেও তো চলতো না হয় সারাদিনের ক্লান্তি শেষে তোমার হাতে করা একটু ডাল ভাত খেয়ে তোমার হাত ধরে একটু গল্প আর তোমার কালো কেশের ঘ্রানের আত্নতৃপ্তি এমন একটা সহজ জীবন চাওয়া কি পাপ বলেন  হ্যাঁ পাপ কারণ তোমার পাশের বাসার ছেলে জর্জ মেয়ে ডাক্তার
# চেহারার ঘা থেকে পুজ গড়িয়ে পড়ছিলো  ওর চোখ দুইটা জ্বলজ্বল করছিলো  এতো ভয়ংকর চেহারা কারো থাকতে পারে  জানা ছিলোনা
# বাইরের মানুষ বানানে ভুল করলে কত কি বলা হয়ে যায় আমাদের  এই যদি হয় নিজেদের গাড়ির অবস্থা তখন নিজেদের কি বলবো আমরা
# আপনি  পুলিশ  ফোন  দিয়ে  ওই দোকানের  লোকেশন  বলুন
# বোরকা না পড়লেই চলতো  বোরকার অপমান করার কি প্রয়োজন ছি
# আমি ও তোমাদের সাথে যেতে চাই  ওদের কঠিন শাস্তি হবে ইনশাল্লা
# যে বাড়িতে চায়ের সাথে বিষ মিশিয়ে মানুষ খুন হয় সেখানে চা খাওয়া ঠিক নিরাপদ না আশরাফ সাহেব এবং ওসি সাহেব আৎকে উঠলেন বুঝা গেল
# তাদেরকে বাংলাদেশে অনুপ্রবেশ করতে দেয়া হউক  তাদের জীবনটা রক্ষা হউক  আমার দেশ আমার দেশ বলে চিল্লাও মিয়ারা মরলে বুঝবা কোনটা আমার আর কোনটা তোমার দেশ  সকল রোহিংঙাদের প্রতি রইল আমার শ্রদ্ধা ও ভালবাসা
# কাংলা মানেই ভিক্ষারি পরিচারিকা শ্রমিক গরুচোর ডাকাত চরিত্রহীন বেশ্যা জঙ্গি
# পবিত্র ঈদুল আযহা উপলক্ষে আজ বৃহস্পতিবার থেকে নতুন নোট বিনিময়ের জন্য বাজারে ছেড়েছে বাংলাদেশ ব্যাংক   আগস্ট পর্যন্ত  সাপ্তাহিক ও সরকারি ছুটির দিন ছাড়া  বাংলাদেশ ব্যাংকের বিভিন্ন অফিসের কাউন্টারের মাধ্যমে জনসাধারণের মধ্যে নতুন নোট বিনিময় করা হবে
# আমাদের দেশে অনেক জায়গায় ডাক্তাররা ভয়ে রোগী দেখা বন্ধই করে দিয়েছেন  ভয় পেয়ে রোগীর কাছের আসছেন না অনেক ডাক্তার
# আজেষ্টিনার সাপটারা বড় বড় কথা বলা বাত দায় লজা করা ইচিত গোল খাওয়ার পরেই আবার কথা চোদায়
# লিখতে গিয়ে  ভয়  অনুভূতিটাকে বেছেছিলাম  আমার তীব্র কিছু অনুভূতির মধ্যে ভয় অন্যতম
# পতিবাদ করার মত আর কোনো দেশ নাই
# দুনিয়া উলটাপালটা হলেও কিছু হুজুর ধর্ম নিয়ে ব্যবসা ছাড়বেন না   যেখানে করোনা নিয়ে সবাই আতঙ্কে আছে   কিছু হুজুর কুসংস্কার ছড়ানো মতো  মহান কাজ করছে
# যুব মহিলা লীগ গঠন করা হয়েছিল যুব সমাজের চরিত্র ধ্বংস করার জন্য  অচিরে এই সংগঠনকে নিষিদ্ধ করা হোক
# ঘরে একটা তীব্র গন্ধ পাবে  ঘরটা শীতল হয়ে যাবে  হয়তো কেউ একজন থরথর করে কাঁপতে থাকবে  তার থমথমে গলার স্বর শুনেই আমাদের হাত পা ঠান্ডা হয়ে যায়
# তাদের কিছু বলা যাবে না  বললে বলবে  ক্রান্তিকালেও বিনোদনের দরকার আছে  বাংলাদেশ ঐ অর্থে একাত্তরে স্বাধীন হইয়া বাইচা গেসে  এই চিড়িয়া গুলান অই সময়ে থাকলে পাবলিক এটেন্সান কুড়াইতে কুড়াইতে দেশ চ্যালচ্যালায়া পরাশক্তির কাছে ছাইড়া দিতো
# বর্তমান সময়টা বেশ সংকটজনক অবস্থায় আছে  বিশেষ করে সাহিত্যের পাড়ায়  তথাকথিত কিছ ইতর ভদ্র সেলিব্রিটি হঠাৎ করে লেখক  কবি হয়ে গেলো  যে ব্যক্তি ইউটিউবে অশ্লীল ভিডিও দিয়ে ভরিয়ে দিলো সেও লেখক হয়ে গেলো  বড় ভাই শখ করে বই লিখলো বলে ছোট ভাইও একখানা পুস্তক লিখে ফেলল  বাহ্  কি সহজ  তারা আবার ঘনঘন বইমেলায় যান অটোগ্রাফ  ফটোগ্রাফ দিতে
# এই লাল সবুজের পতাকা কেবল একটি কাপড়ের খণ্ড নয়  স্বাধীনতা লাখো শহীদের প্রাণের বিনিময়ে অর্জিত মানচিত্র
# শেরপুরের শ্রীবরদীর ঐতিহ্যবাহী টেঙ্গরপাড়া উচ্চবিদ্যালয়ের ব্যবস্থাপনা কমিটির সভাপতি সিদ্দিকুর রহমান  বিদ্যালয়ের প্রধান শিক্ষক মো  আবু রায়হান ও শিক্ষক প্রতিনিধি আশিকুর রহমানের বিরুদ্ধে অর্থ আত্মসাতের অভিযোগ উঠেছে
# দাদা আপনার  গুলো ভালো লাগে  ডকুমেন্টারি টাইপের ভিডিও বানানো শুরু করেছি সবেমাত্র আপনারা সাপোর্ট করলে মোটিভেশন পাই  একজন ছোট  হতে চাই  আমাকে সাপোর্ট করুন  আমার ভিডিও গুলো দেখে আসুন  ভালো লাগলে পাশে থাকবেন আশা করি
# তাহসান ভাই  আপনার কথা গুলো সত্যি অসাধারণ  কোন মানুষকে কষ্ট দেওয়া ছাড়াই শিখিয়ে দেয় অনেক কিছু
#  ফেব্রুয়ারী তে প্রাইম বিশ্ববিদ্যালয়ের প্রথম রি ইউনিয়নে অনেকের সাথে অনেকদিন পরে দেখা হলো  এমনই এক আনন্দঘন মূহুর্তে নরসিংদীর ছেলে জাহিদুল ইসলাম সোহেল তার বিবাহের সুসংবাদ এবং দাওয়াত দিলো
# দুই শিশুর বিরুদ্ধে চট্টগ্রাম নগরের আকবরশাহ ও কোতোয়ালি থানায় ইয়াবা ও অস্ত্র  ছুরি  উদ্ধারের ঘটনার পৃথক দুটি মামলা রয়েছে  ওই মামলায় তিন মাস ধরে তারা গাজীপুরের কিশোর উন্নয়ন কেন্দ্রে রয়েছে  সেখান থেকে গতকাল হাজিরার জন্য চট্টগ্রাম আদালতে আনা হয়
# যেসব কুকুরের বাচ্চারা এসব তদারকি করার দায়িত্বে আছে ওইসব কুকুরের বাচ্চাদের আগে বিচার করা উচিত যারা নিরীহ মানুষগুলোর এভাবে আটকে রাখছে
# কে বলেছে নেই
# জাহেদ মালিক বলল  মাস আগে প্রস্তুতি আছে বাংলাদেশে
# আমার সামি বিদেশে থাকে আমি তাকে খুব ভালবাসি তার কাছে সুধু চাই সময় ও খুব বিরক্ত হয় আমার উপর
# নাইন–ইলেভেনের পর এমন নির্মমতার সাক্ষী হবে নিউইয়র্কবাসী  সেটা হয়তো কেউ কল্পনা করেনি  মৃত্যুর মিছিলে এখন বাংলাদেশিরা  বাড়ছে আতঙ্ক  উৎকণ্ঠা
# ক তাহসান ভাই
# ফিরে ফিরে বারবার সে এসেছে প্রতিটি বারে সেই সে নবীন পহেলা বৈশাখ    শুভকামনায় নববর্ষ রঙিন
# ধরেছেন হানিফ সংকেত মহোদয়   অসংখ্য ধন্যবাদ
# আমি এ দৃশ্য দেখে কাঁপতে শুরু করলাম  মনে হচ্ছিলো ভয়ে এক্ষুণি বেরিয়ে আসবে আমার প্রাণ
# ক্ষমতাসীন দল কারচুপির জন্য এই কথাই বলে
# বাইরে সারা শহরে নাৎসি বাহিনী  গেস্টাপো ঘুরে বেড়াচ্ছে  উপরে আকাশ থেকে বোমা বর্ষণ হচ্ছে  ধরা পড়লেই শেষ
# গোঙ্গানির শব্দপেয়ে আরো ভয় পেয়ে গেল  ভয়ের সাথে যুক্ত হল কৌতূহল
# ওখানে গিয়ে না খাইলেই হয়  সবাই যদি এইগুলা খাওয়া বন্ধ করে দেয় তাহলে এই   খাবার গুলা এতো দাম দিয়ে কেনার কোন মানে দেখি না  আরও থাকে ভেজাল মেশানো
# এরকম একজন ইই ছিল আর সব কাছের মানুষরাই আপনাকে যন্ত্রণা মনে করবে
# কা বা শরীফের তোআফের মাঠে মানুষ নেই কলিজাটা কেঁপে উঠে ভাবলেই  ওমরাহ ও অফ রেখেছে সৌদি সরকার নিরাপত্তার সার্থে এক শহর থেকে অন্য শহরে ঢুকতে দিচ্ছে না কাউকে
# যে ছেলে কাপর ছিড়ছিল তখন তাকে বলা উচিত ছিল তার নিজের মা বোনের কাপড় গিয়ে ছিড়তে  অবশ্য এদের জন্মেরইতো ঠিক নেই মা বোন থাকবে কোথ্থেকে
# হাসিনা তোমার দাদার পোলাপান যে টাইগারদের গালাগাল করেছে  আর পতাকার অবমাননা করেছে সেটার কি করবে
# সুফিয়া আপুর একটা ফুটফুটে পুত্র সন্তার হয়েছে  মা ও ছেলে সুস্থ আছে  যারা রক্ত দিয়েছে এবং দিতে চেয়েছে তাদের অনেক ধন্যবাদ  আল্লাহ তাদেরও এমন ফুটফুটে বাচ্চা দিক
# একজন সাংবাদিক অন্যায় করলে অন্যরা তার দায় নেন না  একজন জজ দোষ করলে তার দায় সকর্মীরা নেন না  একজন পুলিশ অপরাধ করলে তার দায় ডিপার্টমেন্ট নেয় না  তাহলে বিএমএ কেন কিছু ডাক্তারের অপরাধের দায় নিচ্ছে  অপরাধীর সাথে যোগ দিয়েছে
# করোনাভাইরাসের প্রাদুর্ভাব বাড়ায় বিশ্ববাজারে জ্বালানি তেলের চাহিদা কমছে  চাহিদা কমায় দামে নেতিবাচক প্রভাব পড়ছে
# কেউ একজন কোম্পানির শেয়ার কিনছে তাই বলে এতো গুলা মানুষরে মাইরা ফেলছে তাও আবার অন্য দেশে গিয়া মাইরা আইছে   হায়রে কুছ তো রাহেম কর
# গতকাল এক টুপি দাড়িওয়ালা ওয়াজ শ্রবণরত দোকানদার যখন পাঁচ টাকার মাস্ক পনের টাকা নিল  আমি বললাম  আপনার জন্য বেহেশতে হুর নাই ভাইজান  আপনারে জাহান্নামে নিয়া পোন্দাইয়া দিবে
# আগে ভাবতাম যে টলিউডের বাকি ছ্যাবলা গুলো থেকে অঙ্কুশ একটু আলাদা   এখন তো দেখছি অঙ্কুশ ই হল আসল বলদ
# একটা ক্লিপে দেখলাম  মেয়ে তার জন্মদাত্রী মা র—যিনি করোনাভাইরাসে আক্রান্ত— কাছে যাচ্ছে না  প্রায় বিশ গজ দূর থেকে চোখাচোখি করে কিছুটা আবেগাপ্লুত হয়ে মা র জন্য আনা খাবার রেখে হাত নেড়ে চলে গেল  নিঃসঙ্গ মা তখন খুঁড়িয়ে খুঁড়িয়ে এসে খাবারের পার্সেলটা নিয়ে ফিরে গেল নির্জন প্রকোষ্ঠে
# শুভেচ্ছা ওবায়দুল কাদের কে দলের সাধারণ সম্পাদক হওয়ায় তাকে অভিনন্দন
# আমি চোখ বন্ধ করে যখন শুয়ে থাকি আমি ফিল করি কেউ আমার চুল ধরে টানছে   এবার আমি অনেক জোরে চিৎকার করে উঠি
# না ফারাজের না  এই বাংলাদেশ শুধু ই তারেক রহমান অ তার বউ এর
# এরকম স্মার্ট মেয়র আবার কবে পাবো  জানি না  তবে আপনি আমাদের মনে থাকবেন স্যার
# এই বাঙ্গালীর কমন সেন্স দেখে আমি অবাক হই না  আতঙ্কিত হই  হোম কোয়ারেন্টাইনের পুরা ব্যাপারটাই একটা তামাশা পর্যায়ে নিয়ে গেছেন আপনারা  কি ভাবতেসেন  এইটা উৎসব  ঈদ লাগছে
# আমাদের বিড়ি মিনিস্টারের সাথে ভালোই মিল আছে
# গায়ে হাতে লোম শিরশির করছে  কিসের থেকে কি হয়ে গেল  হায়রে খোদা  মৃত্যুর এক ফোটাও কেমনে বিশ্বাস নেই
# স্কুল বন্ধু আরো একজন হারালাম  ইমন  এর পর৷
#     ভাই
# তোর আত্মার শান্তি কামনা করি
# আ আ আ কী ব‍্যাথা  চামড়া উঠে গেল কেউ  নিয়ে আসো  একটু নাচ হোক  আহা কী  কী লচক পচক বডি  কী লুল্লুরানী বডি
# রাতে খাওয়ার সময় বন্ধুদের সঙ্গে ভিডিও কলে কথা বলছিলাম  তাদের অনেকেই উহানের পার্শ্ববর্তী শহরে ছিল  বাড়িতে ফিরে আসতে ভয় পাচ্ছিল তারা
# সৌম্যর এমন ভরাডুবি দেখবো ভাবিনি সৌম্যর জন্য প্রার্থনা করা উচিত
# এতদিন অপরিচিত মানুষের মৃত্যু সংবাদ শুনেছি   তাই হয়ত মৃত্যুগুলো সংখ্যা ছাড়া আর কিছু মনে হয় নি আজকে করোনা আক্রান্ত হয়ে বন্ধুর বড় ভাই মৃত্যুর খবর শোনার পর থেকে মনে হচ্ছে সত্যিই করোনা ধরে ফেলল আমাদের
# তৎকালীন হিন্দু সমাজে উঁচু জাতে জন্মানোকে পুঁজি করে নিচু জাতের মানুষকে শোষণ করার ঘৃণ্য প্রথা   ব্রাহ্মণতন্ত্রে র বিরুদ্ধে সচেতনভাবে ঘৃণা রচিত হয়েছে এ চলচ্চিত্রে
# অনূর্ধ্ব  বিশ্বকাপে প্রথমবারের মতো ফাইনালে বাংলাদেশ  নিউজিল্যান্ডকে  উইকেটে হারিয়ে স্বপ্নের ফাইনালের দেখা পেল যুবারা
# বুঝলাম না কেন যে বালের আলো প্রত্রিকা রোহিঙ্গাদের পিছনে গেলেছে
# তাদের কে ঢুকতে দিলো কেন  এক মাস আগে থেকেই সাবধান হওয়া উচিৎ ছিলো
#
# ভাই আমাগো টাংগাইলা পোলা দেখিয়ে দিছে একাই একশ ওর মত জাতীয় দলে খেলোয়ার দরকার
# শিক্ষামন্ত্রী দীপু মনি বলেছেন  কোনো কোনো গাইড ও নোট বই মুদ্রণকারী প্রতিষ্ঠান অনৈতিকভাবে কোনো কোনো শিক্ষাপ্রতিষ্ঠানের শিক্ষকদের আর্থিকভাবে প্রলুব্ধ করে  তারা এসব নোট ও গাইড শিক্ষার্থীদের কিনতে বাধ্য করে  এই নোট ও গাইড বন্ধে জেলা প্রশাসনের সহযোগিতা চেয়েছেন শিক্ষামন্ত্রী
# হঠাৎ অরুণের সামনে চলে এলো মেয়েটি গলা টিপে ধরলো অরুণের শ্বাস নিতে পারছে না সে  মাথা ঘুরছে হঠাৎ মেয়েটি শূন্যে তুলে অরুণকে আছাড় মারল ছাদের রেলিঙে
# এই বাল তার মুখ যদি কেউ অফ করতে পারে      বাল একটা
# তোমাদের মত নাসতিক হলুদ মিডিদের কে আগে জেলে দেওয়া উচিত
# আলহামদুলিল্লাহ আলহামদুলিল্লাহ আলহামদুলিল্লাহ  মুহতারাম  কিজে ভালো লাগছে তা ভাষায় বুঝাতে পারছিনা  জাতির প্রতিটি অংগনে আপনাদের পদচারণা কামনা করি
# আমি জানি যখন কোনও উত্তেজিত বাচ্চা হিংস্র হয়ে ওঠে তখন পিতামাতারা যে ব্যথা অনুভব করেন
# এটা কতটুকু ঠিক     তাও আবার ছবি তুলে সোস্যাল মিডিয়ায় প্রকাশ    মানলাম দায়িত্ব  তারপরেও আমরা তো মানুষ বিবেকবোধ তো থাকা দরকার
# এই ছবি গুলা আর ভিডিও গুলা আমাকে  খুব ডিস্টার্ব করছে  একটু পর পর মনে পড়ছে আর আমি আবেগপ্রবণ  ভীত এবং  অসুস্থবোধ করছি
# ঠিক ঠিক করে ভাবলে এখনো এই গল্পে আমি ভয় পাই
# যে নারী স্ত্রী হিসেবে সমস্যা নিয়ে আলোচনার জন্য পুরুষের নির্ভরতা অর্জন করতে পারছেন না  সে নারীই একসময় মা হিসেবে সমস্যা নিয়ে আলোচনায় ছেলের কাছে গ্রহণযোগ্য হয়ে উঠছেন  তাই বিষয়টিকে সামান্য বলে এড়িয়ে যাওয়ার সুযোগ নেই
# পৃথিবীর সব চেয়ে সুখ কি জান  মা বাবার আদর আর সব চেয়ে অমুল্য রতন কি জান  মা বাবার ভালোবাসা
# বাংলাদেশের মানুষ আপনার কাছে চিরঋনি হয়ে থাকবে সব সময়  এই মানুষটাকে আমি একটু সময়ের জন্য ও বসতে দেখি নাই  সারাটা সময় ধরে ছেলেদেরকে সাহস দিয়ে গেছেন স্বার্থক তিনি
# তার মত একজনকেই হয়তো জাতীয় দলে খুব বেশি দরকার
#
# রুমে গ্রামের মানুষের ভীর জমে আছে মুরুব্বিরা বিভিন্ন দোয়া দরুদ পড়ছে সবার চোখেই পানি  সবাই তিন্নির এই অবস্থা দেখে অঝোরে কান্না শুরু করে দিলো
# পাকদের কে বাস দেয়েনা কে জেরকম আমাদের বাংলাদেশ দিয়ে ছিলো
# সরকার   সব মিথ্যা   বানোয়াট
# আমরা   প্রস্তুত
#  কোটি বাজেট করেছি
# সব চোরের দল
# সরকারের নির্দেশনানুযায়ী মাদকের বিরুদ্ধে যেমন  জিরো টলারেন্স  প্রদর্শন করা হচ্ছে  তেমনি নদী রক্ষার জন্য দখলকারীদের বিরুদ্ধেও  জিরো টলারেন্স  প্রদর্শন করা হবে বলে জানান তিনি
# সমাজের শিক্ষিত লোকেরা যদি এই ভাবে অপচয় করে তাহলে কাকে কি বলব
# গাঁজাখোর পরিচালক সিনেমার শুরুতে কি দেখালো এতো ফায়ার করছে তার পরেও কোন গুলিই লাগলো না জিতের এতো অবাস্তব করা কি দরকার
# জায়গাটা খুব ভয়ানক
# দেখতে দেখতে ভালবাসার এক বছর পূর্ণ হলো সবকিছুর জন্য আলহামদুলিল্লাহ
#  আমার এক ছেলে বড় হয়ে সিরিয়াল কিলার হতো  আরেকটা ড্রাগ অ্যাডিক্ট  আর মেয়ে হতো বেশ্যা    তোমাকে এই কথা কে বলেছে    শয়তান    শয়তান তোমাকে নিজে বলেছে    হু
# ধন্যবাদ মামা  আমার জন্য দোয়া করবেন
#   টাকা দিয়েই মুভি দেখবো  তাও আবার অঙ্কুশ শের মুভি হা হা হা লোলো ভাই সাহাব ঔ গেরার মুভি হা আর কোতো কি সুনবো ভোগোবন🥴🥴  কিরোণদা তুমি চিনতা কোরোনা আমরা তোমার সাথে আছি ♥️
# তার মাথা ঘুরতে থাকে  তার মনে হয় যে সে একটা ঘোরের মধ্যে রয়েছে  পকেট থেকে মোবাইলটা বের করে শিল্পাকে একটা কল দিবে এই শক্তিও তার নেই  সে মুখ দিয়ে যে  কোনো শব্দ করবে সেই শক্তিও তার নেই  তার মনে হয় কেউ একজন তার মুখ শক্ত করে ধরে রেখেছে
# তোর দুঃখে আমার সবসময় মজা লাগলেও এইবার খারাপ লাগতেছে  কালকে ইনশাআল্লাহ সব ঠিক হয়ে যাবে
# সৌভাগ্য এটা যে আমরা কোনরকম হট্টগোল ছাড়া শান্তিনিকেতনের শান্ত স্নিগ্ধ চেহারা মন ভরে উপভোগ করতে পারলাম
# অস্ট্রেলিয়ার চলমান ভয়াবহ দাবানল নিয়ন্ত্রণে ব্যর্থতার দায় স্বীকার করে দুঃখ প্রকাশ করেছেন প্রধানমন্ত্রী স্কট মরিসন আজ রোববার এবিসি টেলিভিশনকে দেওয়া এক সাক্ষাৎকারে নিজের দায় স্বীকার করে তিনি বলেন  এ ক্ষেত্রে আমার হয়তো আরও ভালোভাবে কিছু করার ছিল
# কানে না ধরায় খাবারের প্যাকেটটা হাতে দিয়ে বলতেন  যান চাচা  বাড়ি যান তাহলে বাহাদুরি হইতো  কানে ধরিয়ে বাহাদুরি নিচ্ছেন
#
# আজ বাতাসে সুবাসিত স্নিগ্ধতা  পাখিরা সারি সারি গাইছে গান  প্রকৃতি হেলে দুলে হয়েছে রঙিন  ফুলেরা সব ফুটেছে বাগানে  আজ আমার কাছের প্রিয় মানুষের জন্মদিন
# চিপায় বসে মিয়া গান করেন বাহিরে বের হন  গান গুলো আরো ভালো লাগবে  চিপায় বসে গান শোনলে কেমন যেনো দম বন্ধ বন্ধ লাগে
#  চারিদিক থেকে ভয়ের অনূভুতি গ্রাস করলো তাকে হাটার শক্তিও মনে হলো কেউ কমিয়ে দিয়েছে
# ভয় হচ্ছে কুসংস্কারের জনক  কুসংস্কারের সাথে জন্ম নেয় আরও ভয়
# মেয়েটা এত জোরে কান্না করছিল যে  মনে হচ্ছিল কেউ তাকে মারছে   আমি ঘুম থেকে উঠে এই মেয়েকে দেখে ভয় পেয়ে যাই
# মাননীয়া পুলিশ সুপার আপনাকে আবারো আমাদের চাঁদপুরে খুবই প্রয়োজন  কারন আপনে হচ্ছেন  নীতিবান পুলিশ অফিসার  আপনে দায়িত্ব কঠোরভাবে পালন করেন  স্যালুট জানাই ম্যাম
# ভালবাসা সব সময় সাথে আছে থেমে থাকবেন না দয়া করে  ভিডিও এর অপেক্ষায় থাকি
# যার স্বামী মারা গেছে তারই নাম বিধবা দুনিয়াতে তার আর আপন রইল কেবা বিধবা নারী বুক ভাসায় চোখের জলে
# আধা সরকারি বার্তা সংস্থা ফারসের খবরে বলা হয়  এক হাজারের বেশি শিক্ষার্থী দেশটির নেতাদের বিরুদ্ধে স্লোগান দিচ্ছিলেন  একই সঙ্গে সোলাইমানির ছবি ছিঁড়ে ফেলে  শিক্ষার্থীরা বিমানটিকে ভূপতিত করার সঙ্গে জড়িতদের এবং যারা নিজেদের দায়কে আড়াল করতে চেয়েছে তাদের সবার বিচার দাবি করেন
# মনে রাখবেন  পাপ তার বাপকেও ছাড়ে না  এই দেশটাকে  এই দেশের মানুষগুলোকে যারা শোষন করছেন  তারা কখনো সময়ের পরিনাম থেকে বাঁচতে পারবেন না
# ইনশাআল্লাহ টেষ্টে ও আমরা জিতব
# বোন করোনা ভাইরাস ধরেছে আজরাইল যখন আসবে তখন কি করবেন আল্লাহকে ভয় করুন আমিন
# ফাজিলের বাচ্চার হুগাই বাশ দিতে হবে
# ছো‌টো বেলায় শু‌নে‌ছিলাম   বাবা মার ভা‌লো সন্তান কখ‌নো পু‌লিশ হয়না   খারাপটায় হয়   কথাটা দেখ‌ছি   সত্যি
# আইইউসির এখন যা অবস্থা বন্ধ হয়ে গেলেও একজন সাবেক ছাত্র হিসাবে আমার কোন আপত্তি নাই  নস্ট সন্তানের কু কৃর্তী দেখার চেয়ে পিতার মৃত্যুই ভাল
# মাঠের মধ্যে আগ্রাসী আচরণ  প্রতিপক্ষ খেলোয়াড়কে উদ্দেশ করে খিস্তি খেউড় করার স্বভাব জেমস প্যাটিনসনের আজকের নয়  গত  মাসে এই কাজ আরও দুবার করেছেন  তাঁকে সতর্কও করা হয়েছিল  কিন্তু তাতে কী  আবার একই কাজ করলেন ভিক্টোরিয়ার এই পেসার
# এই  ছেলের  কি  কান্ড   বাপ  এর  চেয়ে    ডিগ্রী  বেশি  মেন্টাল  পেশেন্ট   থুক্কু  সায়েন্টিস্ট
# স্থগিত নয়  প্রত্যাহার এবং ডিসি অফিসের সাথে সংযুক্ত  তারা শাস্তি দিতে খুব মূল্যবান  কেবল চোখের জল
# ভাই আমরা আপনাকে  করি  আপনি সব সময় সত্যের সাথে থাকেন  আল্লাহ আপনাকে হেফাজত করুক
# হিটলার একজন অমুসলিম লক্ষ ইহুদি হত্যা করেছিলো  মিডিয়া একবারও তাকে বলেনি সে খৃষ্টান সন্ত্রাসী   জোসেফ স্ট্যালিন একজন অমুসলিম সে মিলিয়ন মানুষ হত্যা করেছে এবং মিলিয়ন মানুষ অসুস্থ হয়ে ধুঁকে ধুঁকে মারা গেছে   মিডিয়া একবারও তাকে বলেনি সে খৃষ্টান সন্ত্রাসী   মাও সে তুং একজন অমুসলিম থেকে মিলিয়ন মানুষ হত্যা করেছে  মিডিয়া একবারও তাকে বলেনি সে বৌদ্ধ সন্ত্রাসী   মুসলিনী ইটালী লাখ মানুষ হত্যা করেছে  সে কি মুসলিম ছিল  অন্ধ মিডিয়া একবারো বলে নাই খৃষ্টান সন্ত্রাসী   অ
# ভালোবাসার কষ্ট গান দিয়েই বোঝানো যায়
# আকাশের কষ্ট গুলো মেঘ হয়ে ভাসে  মেঘের কষ্ট গুলো বৃষ্টিহয়ে আসে  পাথরের কষ্ট গুলো ক্ষয়ে ক্ষয়ে পরে  আর মনের কষ্ট গুলো অশ্রু হয়ে ঝরে
# মেধার জোরে আসে নাই স‍্যার  সরকারের দালালি করে এখানে আসছে  তাদের চেয়ে যোগ্য লোক বাংলাদেশে অনেক আছে সরকারের দালালি করতে পারে নাই বলে তাদের চাকুরী হচ্ছে না
# আমি তোমার আর আমার ভেঙ্গে যাওয়া স্বপ্ন গুলো বুকের মাঝে পুষছি  আমি এখনো পারিনি তোমার মত ভুলে যেতে তোমার সাথে কাটানো কিছুটা সময় কিছু মুহূর্ত  পারিনি তুমি নামের সেই অতীতটাকে ভুলতে  জানি না কোন দিন পারবো কি না তোমায় ভুলতে
# যখনই ভয় পাচ্ছি চোখ বন্ধ করি কিন্তু ভয় যাচ্ছে না
#  হলরুমে একসঙ্গে  মানুষ ভয় পেয়ে চিৎকার করে উঠছে
# পরিবেশ দূষণকারী পলিথিন ব্যাগের ব্যবহার কমাতে দৈনিক এক লাখ পিস সোনালী ব্যাগ উৎপাদনের কার্যক্রম চালু করেছে বাংলাদেশ পাটকল কর্পোরেশন  বিজেএমসি   এতে অর্থায়ন করছে জলবায়ু পরিবর্তন ট্রাস্ট ফান্ড
# সে দোকান
# থেকে নেমে আমার পথেরদিকে তাকিয়ে
# আছে  ভয় পেয়েগেলাম প্রচ ন্ড ভয়
# ইচ্ছে হচ্ছিল ছুট লাগাই  কিন্তু কেনজানি
# দৌড়
# দিলাম না  জোরে জোরে পা চালাতে
# লাগলাম
# বাংলাদেশের তিন মাসে তিনবার পাকিস্তানে যাওয়ার পরিকল্পনা নিয়ে প্রশ্ন উঠেছে  সাবেক পাকিস্তানি তারকা শোয়েব আখতার অবশ্য বলছেন  বাংলাদেশের এভাবে পাকিস্তান সফরের পেছনে বাইরের কারও হাত আছে
# আপনার চাওয়াটা সহজ হলেও পাওয়াটা এর চেয়েও হাজার গুণ কঠিন
# লা লিগার সভাপতি হাভিয়ের তেবাস মে মাসে লিগ শুরু করতে পারবেন এমনটা আশা দেখছেন  যদিও বাস্তবতা হয়তো ভিন্ন  তবে যখনই শুরু হোক লিগ  বার্সেলোনার জার্সিতে তত দিনে মাঠে থাকবেন লুইস সুয়ারেজ
# আপনাদের সমস্যা কি
# আপনার এগুলো পোস্ট করে  তাকে ভাইরাল করেছে
# সে শেখ হাসিনা প্রিয় হওয়ার জন্য এগুলো বলে
# তোর মত কাউয়া কাক  যদি উপস্থাপনা করে তাহলে অনুষ্ঠানে যে কয়জন মানুষ আসবে সেই মানুষগুলোও পালাবে
# সুসার পতন ঘটল কোনোরকম বাধা ছাড়াই  সুসার বিশাল সম্পদের কারণে মুহূর্তের মধ্যেই আলেকজান্ডার তার সময়ের সবচেয়ে সম্পদশালী ব্যক্তিতে পরিণত হলেন
# এই বৃষ্টি ভেজা রাতে তুমি নেই বলে সময় আমার কাটে না চাঁদ কেনো আলো দেয় না পাখি কেনো গান গায় না তারা কেনো পথ দেখায় না তুমি কেনো কাছে আসো না
# ওরে ট্রাম্পরে দিয়ে চুদা দরকার
# রতন কাহার বেঁচে আছে না মরে গিয়েছে  কেউ কি জানেন  যে মানুষটা গান কে তার নিজের কন্যাসম মানতেন  গানের কথা সুর কাউকে নির্দ্বিধায় দিয়ে দিতেন  বদলে কেউ টাকা দিতে এলে বলতেন   আমি বিটি বিচে টাকা লুবো না   কেউ জানতেও চায় না আর সেই মানুষটার কথা
# টেস্ট অলরাউন্ডার র্যাংকিং এ উঠে আসতে হবে   শুভকামনা
# ভোরের প্রথম আলো যেমন সুন্দর  ভোরের হাওয়া যেমন স্নিগ্ধ  ভোরের পাখির ডাকযেমন মধুর  তেমনি সুন্দর হোক তোমার জীবন
# এত দিন দুপুরে ডাকাতি  এত পুকুর চুরির চেয়ে কম না  আবার চোরের মার বড় গলা  দোকানদার কে শাস্তি দেয়া হল না কেন   মোবাইল কোর্ট ঘুষ খায় নি তো ‌
#
# প্রানির মাধ্যমে এই রোগ ছড়ায়  মশা মাছির মাধ্যমে ও ছড়ায়  এসব ফালতু প‍্যচাল দিলে কানের নিচে থাপ্পড় দিমু
# সাকিবের ক্যাচটা ধরে দিলে ম্যাচ জিতে যেতাম
# রাজশাহীতে বড় ভাইয়ের লাঠির আঘাতে ছোট ভাইয়ের মৃত্যু হয়েছে  নিহত ব্যক্তির নাম আশরাফুল ইসলাম     এ ঘটনায় বড় ভাই নূর আলমকে    গ্রেপ্তার করেছে পুলিশ
# চীনে খরচ অনেক বাড়ছে  সেখানে একজন শ্রমিকের মজুরি  হাজার টাকা  বাংলাদেশে  হাজার টাকা  ফলে ভারত ও ভিয়েতনামের পাশাপাশি বাংলাদেশ মুঠোফোন তৈরির কেন্দ্র হতে পারে
# যাক  শেষমেশ এমন দিনও দেখা লাগলো যখন বৃহস্পতিবার সন্ধ্যায়ও আড্ডা দেওয়ার জন্য কাউকে পাওয়া যাবে না
# সরকার চট্টগ্রামকে গরুর মত দুধ দুয়ে দুয়ে খেয়েছে কিন্তু খাওয়াই নাই   বানিজ্যিক শহর হলে কি হবে  অনেক পিছিয়ে আছে
#  তাতে মনে হল আমার প্রায় পুরো জীবনটাই ভয় দিয়ে নিয়ন্ত্রিত হচ্ছে
# মুরলমানদেরকে বৌদ্বরা যেভাবে ধর্ষণ ও পুরিয়ে হত্যা করছে জারজ ওদেরকেও সেভাবে করা উচিত তাহলে ওরা বুঝতো ধর্ষণ আর পুরিয়ে হত্যা কি জিনিষ
# এটা সামগ্রিকভাবে চলমান এফটিপির বিশাল এক শূন্যতা  অন্য ভাষায় আইসিসির জন্য ব্যর্থতা  একটা উদীয়মান দেশকে পর্যাপ্ত ম্যাচ দিতে না পারাটা অবশ্যই আইসিসির ব্যর্থতা
# জ্যাকি চ্যানের যখন জন্ম হয় তখন তার বাবার আর্থিক অবস্থা  তিনি এতোই খারাপ ছিলো যে  তিনি চ্যানকে বিক্রি করে হসপিটালের টাকা পেইড করার সিদ্ধান্ত নেন
# একটি মহান কর্মসূচি দেখা গেল রাজশাহীর গোদাগাড়ীতে  সেখানে মুজিব বর্ষ উপলক্ষে একটি গ্রামের অর্ধশতাধিক বাসিন্দা বসতবাড়িতে কীটনাশক ও রাসায়নিক সারমুক্ত সবজি চাষ শুরু করেছেন  কালীদীঘি নামের গ্রামটি ইতিমধ্যেই  নিরাপদ সবজির গ্রাম  হিসেবে পরিচিত হয়ে উঠেছে
# চোখের পানিই হল সব থেকে মূল্যবান পানি   কারন কি জানেন   পৃথিবীতে অনেক রকমের পানি থাকলেও একমাত্র চোখের পানিই বুঝাতে পারে কাউকে হারানোর কষ্ট
# তোমার চোখের চেয়ে সুন্দর চোখ আমি জীবনে খুব বেশি দেখিনি দিদি ওইদিন গ্রিম রুমে অল্প সময়ের দেখায় বলার সুযোগ হয়নি
# মালু গো চুদা মুদির জারজ সন্তান তোর দিদিরে কিন্তু চুইদ্দা মাইরা পালামু খানকির পোলা
# বাজারের এই দশার জন্য অন্যতম দায়ী ব্যাংক খাতের দুরবস্থা  ক্রমবর্ধমান খেলাপি ঋণের কারণে ব্যাংক খাতে তারল্য–সংকট আছে  ব্যাংকের আর্থিক ভিত্তি নিয়েও মানুষ সন্দিহান  ফলে ব্যাংকের শেয়ারের পতন হয়েছে
# আমি একটা জিনিস বুঝি না বাংলাদেশ সরকারি বেসরকারি চ্যানেলের অভাব নেই  কিন্তু এইসব সংবাদ যদি গ্রেফতারের আগে প্রচারণা করা হয় নাই কেন  আর আমি আদালতকে বলবো পাপিয়ার বিরুদ্ধে এমন চার্জশিট তৈরি করা হোক যাতে করে জিবনেও কারাগার থেকে মুক্তি না পায়  ও মডেল হিসেবে থাকুক
# সাকিব ভারি সুন্দর লাগছে তোমাদের কে
# চোরের দেশে চোর তো জন্ম হবে ই
# ভারত পাকিস্তান অস্ত্রের প্রতিযোগিতা করছে  আর বাঙালিরা কথার নোংরা কথার প্রতিযোগিতা করছে
# বান্দরবানের লামা উপজেলায় পুকুরে ভাসমান অবস্থায় তিন বছর বয়সী একটি মৃত হস্তীশাবক পাওয়া গেছে উপজেলার ইয়াংছা এলাকায় আজ সোমবার সেলিম চৌধুরীর রাবার বাগানের পুকুরে মৃত হস্তীশাবকটি পাওয়া যায়
# রাত শুধু আধার নয়  একটু খানি আলো  রাত শুধু খারাপ নয়  স্বপ্ন গুলো ভালো
# আমি এই মুহূর্তে ভবিষ্যত সম্পর্কে খুব উদ্বেগ বোধ করছি কিভাবে আমি সামনের সময়গুলা কাটিয়ে উঠব কি হবে আমার ভবিষ্যৎ এইগুলা ভাবতেই গা চমচম করে
# কর্মীর সঙ্গে প্রেমের সম্পর্ক গড়ে তোলার কারণে ফাস্ট ফুডের বিশ্ব বিখ্যাত চেইন ম্যাকডোনাল্ডস তাদের প্রধান নির্বাহী কর্মকর্তাকে  সিইও  বরখাস্ত করেছে  এ ব্যাপারে মার্কিন এই ফাস্ট ফুড জায়ান্ট জানিয়েছে  সম্পর্কটি দুজনের সম্মতিতে হলেও সিইও স্টিভ ইস্টারব্রুক  প্রতিষ্ঠানের নীতি ভঙ্গ  করেছেন এবং  সিদ্ধান্ত গ্রহণে অদক্ষতার  পরিচয় দিয়েছেন
# বিকল্প নেই বলে বলে খেলানোর ধান্দা     সুযোগ দিল তো পারফর্ম করবে সুযোগ না দিয়ে চিলাচিল্লি করলে কেমনে   আর এখানে তামিমের সাথে সাকিবের নাম জুড়ে দেয়ার কোন অর্থ নেই    তামিম পারফর্ম করছে না
# এরকম অভিযোগে বুধবার রাত টা থেকে বিশ্ববিদ্যালয় ক্যাম্পাস উত্তাল হয়ে উঠেছিল  এসময় ক্ষুব্ধ শিক্ষার্থীদের বিরুদ্ধে ছাত্রকল্যাণ পরিচালকের কার্যালয়ের জানালা এবং নেমপ্লেট ভাঙা  বিশ্ববিদ্যালয়ের বিভিন্ন বিভাগের তালায় সুপার গ্লো লাগিয়ে দেওয়ার অভিযোগ উঠেছে
# এই গত কয়েক মাসে যেভাবে কিছু খবর  কিছু ভিডিও চোখের সামনে আসতেসে  যেটা ক্রমান্বয়ে খারাপতর হচ্ছে  তা দেখে ব্যথিত হইসি   হচ্ছি
# নয় বছর যে অামার বলে জানতাম হঠাৎ একদিন অন্য কারোর হয়ে গেল         অঙ্গ যায়  জ্বলিয়া
# সহজলভ্যতা অনেক বড় কিছুকে ছোট বানিয়ে ফেলে  অপূর্ণতা মানুষের অপ্রাপ্তির ক্ষুধা মনে হয় বাড়িয়ে দেয়
# ভাই ক্যাপশনটা তা অনেক সুন্দর হইছে
# কক্সবাজারের চকরিয়া উপজেলার মাতামুহুরী নদীতে প্রতিমা বিসর্জন দেখতে গিয়ে পানিতে ডুবে মারা গেছে এক স্কুলশিক্ষার্থী  মঙ্গলবার রাত পৌনে আটটার দিকে তাঁর লাশ উদ্ধার করেন ফায়ার সার্ভিসের কর্মীরা  লাশ উদ্ধার হওয়া ওই ছাত্রের নাম আওরঙ্গজেব বিশাল     সে চকরিয়া উপজেলার ফাঁসিয়াখালী ইউনিয়ন পরিষদের সাবেক সদস্য আলমগীর কবিরের ছেলে
# ভারতের গল্পটাও অন্যান্য দেশের মতো  টানা কয়েক বছরের দ্রুত প্রবৃদ্ধির পর দেশটির অর্থনীতি গতি হারিয়েছে  সে জন্য অর্থনীতিবিদদের শঙ্কা  ভারতের অবস্থাও মেক্সিকো ও ব্রাজিলের মতো হতে যাচ্ছে কি না
# এ গুলো কারো দলে না
# বোকাচোদা নামে বন্ধুমহলের কোনো একজনের নাম  করছিলাম কিন্তু কে এই বোকাচোদা তা মনে করতে পারি না
# বিরক্ত  লাগে       দিলে   তাড়াতাড়ি  দিবেন  না  দিলে   পোস্ট  করে  বলবেন  না
# সংবর্ধনা দিলেই সব সর্বনাশ হয়  আর খেলল ওরা আর ফুল পেল কে   কোন দরকার নেই সংবর্ধনার
# দেখার মত একটা ছবি আমার কাছে সেই ভাল লাগে  আমি প্রায় দেখি দারুণ একটা মুভি  এবং পছন্দের একজন নায়ক জিৎ
# তার আচার আচরণে স্পষ্ট যে সেও পাহাড়ি সন্ত্রাসীদের একজন  এজন্য তাকে  পাহাড়ি সন্ত্রাসী  বলতে আপত্তি নাই
# অতিদারিদ্র্যের হার এ বছর এক অঙ্কের ঘরে নেমে এসেছে  গত জুন মাস শেষে অতিদারিদ্র্যের হার  দশমিক  শতাংশ হয়েছে বলে জানিয়েছে পরিকল্পনা কমিশনের সাধারণ অর্থনীতি বিভাগ  জিইডি   গত  বছরে প্রায় এক কোটি লোক নিজেদের হতদরিদ্র অবস্থা কাটানোর যুদ্ধে জয়ী হয়েছেন
# আমি তখন কিছুই বলতে পারি নি কারণ আব্বু আমার কোনো কথাই বিশ্বাস করবে না আব্বু উনাদের সামনেই আমাকে অনেক গুলা থাপ্পড় দিলেন খুব কষ্ট হচ্ছিল তখন তারা যাওয়ার পরেও আমাকে অনেক মারধর করে
# কেমন যেনো বিরক্ত হয়ে গেছি  জীবন কি শুধু গৌরবের পেছনে রাত দিন ছুটা ছুটি
# একজন ক্রেতা আলু–আটার দাম নিয়ে দোকানিকে প্রশ্ন তুলেছেন  দোকানি অনেকটা বিরক্ত হয়ে বললেন   আপনার না পোষালে মাল রেখে যান  অন্য দোকান থেকে কিনুন
# আমাদের এলাকায় রাতে চুরি করা লাগে নাই  দিনে ভোট ডাকাতি করেছে
# উত্তর সিটিতে টি ও দক্ষিণ সিটিতে টি সাধারণ ওয়ার্ড রয়েছে  এখন পর্যন্ত দুই সিটির চারটি ওয়ার্ডে বিএনপি প্রার্থীদের ওপর হামলার অভিযোগ পাওয়া গেছে  এ ছাড়া উত্তরে অন্তত টি ও দক্ষিণে টি ওয়ার্ডে বিএনপি প্রার্থীদের পোস্টার ছেঁড়া ও প্রচারণার কাজে বাধা দেওয়া হয়েছে
# এরকম আরো একজন বাবা আছেন এখন আমার বাসায় তিনি সম্পর্কে আমার মামা শশুর হন  তার অনেকগুলো ছেলে মেয়ে ও আছে ভাগ্যের নির্মম পরিহাস এখন কেও উনাকে রাকতে চায় না  বাসা থেকে বের করে দাওয়া হয়েছে
# যে ব্যক্তি সবচাইতে ভয়ঙ্কর সিনেমা দেখছিল সে কয়েকবার ভয়ে লাফিয়ে ওঠে
# পার্বতীপুর উপজেলার মধ্যপাড়া পুলিশ ফাঁড়ির ইনচার্জ সিরাজুল ইসলাম বলেন  ছেলে সাবলুরের মোটরসাইকেলে চড়ে মোস্তাফিজুর চিকিৎসার জন্য রংপুরে যাচ্ছিলেন  পার্বতীপুর মধ্যপাড়া বাজারে পৌঁছালে বিপরীত দিক থেকে আসা একটি বাস তাঁদের মোটরসাইকেলে ধাক্কা দেয়  এতে ঘটনাস্থলেই বাবা মোস্তাফিজুরের মৃত্যু হয়  হাসপাতালে নেওয়ার পথে সাবলুর মারা যান
# আমি আমার বিয়ের প্রথম জীবনে আমার ডাক্তার স্বামীর কাছে সময়  টাকা তেমন কিছুই পাইনি  যখন অন্যরা আনন্দ করতে ব্যস্ত  তখন আমরা বেঁচে থাকার লড়াইয়ে ব্যস্ত ছিলাম
# মাঝে মাঝে তোমার উপরে খুব রাগ হয়  সে রাগ গুলো জমে অভিমান হয় যায়  আর আমার অভিমান যদি তুমি বুঝতে না পারো তখন আর আমার ভালো লাগে
# তাদের সাথে গেলাম গিয়ে দেখি লিমনের লাশ টা পড়ে আছে  তার লাশটা দেখতে গত রাতের ভয়নকর ভুতটার মতো ছিলো
# তাড়িয়ে দেবার আগেই ক্যাম্পাসকে আপন করে নাও  জীবন আর জীবিকার তাগিদে ক্যাম্পাস ছেড়ে চলে যাবার পরে ভুলে যাবার ভান করে থাকতে হয়না যেন
# খেলা নিয়ে এত এত গান  আসিফের  সাবাশ বাংলাদেশ গানটা কেউ আজঅব্দি টপকাইতে পারল না আমার কাছে ওটাই সেরা
# ম্যাচের আগে অশ্বিনকে আটকে রেখেছিল প্রতিপক্ষ দলের তিন চার সমর্থক  তাঁর আঙুল ফেলে দেওয়ার হুমকিও দেওয়া হয়েছিল
# এগিয়ে চলো মিরাজ ও সাকিব
# ভাইয়া আপনি আমার জানের জান প্রানের প্রান ক্রিকেটার
# সেপ্টেম্বরে যুক্তরাষ্ট্র দুবার পাকিস্তানকে হামলার বিষয়ে সতর্কও করে  শেষ পর্যন্ত ইন্দিরা গান্ধী হামলার পরিকল্পনা থেকে সরে দাঁড়ান
# ভাই চিত্রগল্প আপনার   জানতাম ই না  অথচ কত আগের ভালবাসা চিত্রগল্প
# জয় ভোদাবান দেবীচুদা নম নম
# আমি ফোন কেটে দিয়ে আবিদকে ফোন দিই  কাঁদতে কাঁদতে বলি   কালকের মধ্যে তুমি আমার বাড়িতে তোমার বাবা মা কে পাঠাবা  তোমার সাথে বিয়ে না হলে আমি বিষ খাবো
# ...
# বাস হচ্ছে ভয়ানক ঘাতক  আমাদের সবার উচিৎ বাস থেকে  গজ দূর দিয়ে চলাফেরা করা
# দাদীতো মাজার ব্যাথায় দুইদিন ধরে ঠিকমতো দাঁড়াতেই পারে না  নিঃশব্দে উঠলো কি করে  তাহলে  একটু আগে দাদী রূপে কে ছিল সাথে  হাত পা ভয়ে ঠান্ডা হয়ে আসে
# ঢাকা আন্তর্জাতিক বাণিজ্য মেলার  ডিআইটিএফ  সময় আরও দুই দিন বাড়ল  মেলা শেষ হবে  ফেব্রুয়ারি বৃহস্পতিবার
# বাংলাদেশ থেকে বলছি আপনার ভিডিও গুলো অনেক ভালো লাগে আপনি সোজাসুজি সব কিছু বলতে পারেন কোন লুকোচুরি নেই৷  সত্যি গুলো খুব ক্লিয়ারলি বলতে পারেন
#
#  যেদিন আমার বোনম্যারো ট্রান্সপ্লান্ট হয়  তার আগের রাতে আমি ঘুমাতে পারি নি  কালকে ট্রান্সপ্লান্ট চলাকালীন আমি ফট করে মরে যেতে পারি ভেবে এক ধরণের গা শিরশিরে অনুভুতি হচ্ছিল
#    আমি      বিষয়ে ট্রেনিং এর জন্য নির্বাচিত হয়েছি  এই ট্রেনিং বাংলাদেশে এই প্রথম এবং এতে নির্বাচিত প্রত্যেকের পেছনে সরকারের খরচ হবে এক লক্ষ দশ হাজার টাকা  বিদেশি এক এর মাধ্যমে নেয়া এ ট্রেনিং এ পরীক্ষার মাধ্যমে নির্বাচিত সেরা  জনকে এই মডিউলে প্রশিক্ষণের সুযোগ দেয়া হয়েছে
# না আছে শহীদদের প্রতি শ্রদ্ধা  না আছে নিজস্ব সংস্কৃতি    বিবেকহীন শিক্ষক  তথাকথিত অভিভাবক
# হায়রে বাঙ্গালি    এত শুন্দর একটা ভিডিও   তবুও কতগুলা মাদারচুদে ডিসলাইক দিছে
# এক্সপো অ্যাকসেসরিজের এই শস্যদানা থেকে তৈরি ব্যাগ পরিবেশবান্ধব  নির্দিষ্ট সময়ের পর তা মাটিতে মিশে যায় এবং দেখতেও পলিথিনের মতো  কিন্তু তা তৈরি হচ্ছে শস্যদানা দিয়ে  এর আগে পাট দিয়ে পলিথিন তৈরি করা হয়েছে
# কইও কইও কইও রে ভ্রমর  কৃষ্ণরে বুঝাইয়া মুই রাধা মইরা যাইম  কৃষ্ণ হারা হইয়া রে  ভ্রমর  🥀
# এখানে বল লাগলে ম্যন অব দা ফ্লপ হতে হবে
# এখন আমুলীগ প্রমান করবে ওটা মানুষ নয় এলিয়েন ছিল
# এমন অবস্থা আপনার মনে হচ্ছে হুইল চেয়ারে বসেও বল করার আশা রাখেন  যত্তসব ফালতু একটা জায়গা জুড়ে বসে আছে নির্লজ্জের মতো  ছিঃ
# সাবাস আল্লাহ আপনার সহায় হোক
# সবাই সাবধানে থাকলো  একদিন সকালে ঐ মহিলা চিৎকার আরম্ভ করলো  সবাই তো ভয়ে শেষ
# লক্ষ করে দেখেছি আমি যখন কোন কাজে ব্যাস্ত থাকি ঠিক তখনই হয় কলিংবেল নয় ত টেলিফোন বাঁজতে থাকে সেই শব্দে কিন্ত আর কাউকে ব্যাস্ত হতে দেখা যায় না
# জনের পরিবর্তে জন ভারতিও মালাউনকে ঘন্টার ভিতর হত্যা করা হোউক  আর আমি জানি পাকিস্তান তোমরা সেটা পারবে এবং করবে
# বাংলাদেশে ক্রিকেট টিমে চান্স পেতে হলে একজন ছেলেকে কি পরিমান খড়কুটো পোড়াতে হয় সেটা ওই ছেলেটাই জানে  ওই মানুষগুলোকে শুধু শুধু গালি দিয়েন না
# আল্লাহ তাকে বেহেস্ত নসিফ করুন আমিন
# উত্তর সিটিতে টি ও দক্ষিণ সিটিতে টি সাধারণ ওয়ার্ড রয়েছে  এখন পর্যন্ত দুই সিটির চারটি ওয়ার্ডে বিএনপি প্রার্থীদের ওপর হামলার অভিযোগ পাওয়া গেছে  এ ছাড়া উত্তরে অন্তত টি ও দক্ষিণে টি ওয়ার্ডে বিএনপি প্রার্থীদের পোস্টার ছেঁড়া ও প্রচারণার কাজে বাধা দেওয়া হয়েছে
# আগামীকাল এইচ এস সি পরীক্ষার রেজাল্ট দিবে  কে জানে কপালে কি আছে  ভয় হচ্ছে খুব
# যে সমস্ত বস্তা পচা সিনেমা করা হয় তাতে হল বন্ধ হওয়াই উচিত
# বস আমিও তোমাকে স্যালুট জানালাম
# এক বিয়ে খাইছে বাপরে    তোমাদেরকে বিয়েতে দাওয়াত দেয় কে
# দূর সালা মুড টাই পুরা খারাপ করে দিল  ভাবছিলাম এইবার হয়তো সত্য প্রকাশ হবে কিন্তু কই কি হল গুরে ফিরে আবারও সেই পুরান নাটক
# পাকিস্তানের পাঞ্জাব প্রদেশের ডেরা গাজি খান শহরের পরিত্যক্ত এলাকায় ঘেরা কম্পাউন্ডে দেশটি গোপনে পরমাণু অস্ত্র বানাচ্ছে বলে দাবি করেছে ভারতের গোয়েন্দারা সম্প্রতি উপগ্রহের পাঠানো ছবিও তারই প্রমাণ দিয়েছে বলে দাবি ভারতের  তথ্যসূত্র বলছে  গত  মাসে ডেরা গাজি এলাকার ওই বিশাল কম্পাউন্ড অনেকটাই প্রশস্ত হয়েছে
# আমি মনে করি আমার হাসব্যান্ড এইরকম রোমান্টিক হবে  আমাকে ওর মতো করেই ভালবাসবে সেই অপেক্ষায় আছি আমি জানি না কখন শেষ হবে আমার অপেক্ষা
#      এই ভিডিও সেরা ক্লিপ হিসাবে নির্বাচিত  আর মিউজিক টা পুরাই আগুন
# কিন্তু পঞ্চাশ পেরুনো মোসাম্মৎ আনোয়ারা বেগমের বড়ই অভিমান হয় কেন ভুলে গেলো মেয়েটা তার কথা  তিনি তো সবার কথা মনে রাখেন
# বালের ফালতু মিডিয়া     আর কিছু পায় নাই বাল গুলারা নিয়ে প্রোগাম করে এই সব বাল ছাল বাদ দিয়ে ভাল কিছু করেন যেটা করলে মানুষ একটু হলেও উপকৃত হয়
# আঞ্চলিকতা মানেই সংকীর্ণতা নয়  অনাধুনিকতা নয়  আঞ্চলিক ভাষার মাঝেই আছে আত্মপরিচয়  এই ভাষাতেই কথা বলেন আমাদের মায়েরা  তাই  কথা বলায় যে আঞ্চলিকতার টানই থাক না কেন  তা তো মায়েরই ভাষা  নিজের শেকড়ের ভাষা  আসুন আলিঙ্গন করি নিজের মায়ের ভাষাকে  জোর গলায় বলি মায়ের ভাষায় কথা বলতে লজ্জা কিসের  চলুন ফিরে যাই শেকড়ের আহ্বানে  মায়ের কাছে  মায়ের ভাষার কাছে  ভাষার মাসে এই হোক আমাদের অঙ্গীকার
# ওমানের ভিসা অলরেডি বন্ধ হয়ে গেছে
# আমার পচন্দের প্রিয় অনুষ্টানটি ইত্যাদি
# এটা বিদ্যানন্দ এক টাকার আহার গ্রুপ অনেক অনেক ধন্যবাদ জানাই দীর্ঘ জীবী হোক আপনাদের এই মহত্ত্ব
# কেউ যদি চলে যেতে চায় তবে তাকে কোন মতেই আটকানো যায় না
# বর্তমান সরকার বিভিন্ন কৌশলে বিএনপিকে পরাজিত করতে চায় উল্লেখ করে বিএনপি মহাসচিব মির্জা ফখরুল ইসলাম আলমগীর বলেছেন  ঐক্যবদ্ধ হতে পারলে ক্ষমতাসীনদের তাঁরা পরাজিত করতে পারবেন
# অসাধারণ বক্তব্য   মন জয় করে নিল বাংলার জনগনের   অনেক অনেক ধন্যবাদ আপনাকে
# হাই রাজশাহীর আপু অনেক কিউট লাগছে
# আমি পাগলের মতো হাটতে থাকি  কোথায় যাচ্ছি জানি না  এই গলি থেকে সেই গলি  প্রেতের মতো ঘুম আমার চোখ অন্ধ করে দিতে চায়  যেন হাটতে হাটতেই ঘুমিয়ে যাব  কোথায় যাচ্ছি জানি না
# এই বিশ্বকাপে মিস ফিল্ডিংয়ে বেশ কিছু রান হজম করেছে বাংলাদেশ  মিস ফিল্ডিংয়ে রান দেওয়াতে বাংলাদেশের চেয়ে এগিয়ে কেবল আফগানিস্তান  শেষ পর্যন্ত এই রানগুলোই বাংলাদেশের স্বপ্নের পথে বাধা হয়ে দাঁড়াবে
# এরকম পরিষ্কার ছবি দেখার মজাই আলাদা  এমন মুভি উপহার দেয়া জিৎ এর পক্ষেই সম্ভব
# কাপা হাতে দ্রুত দরজায় কড়া নাড়তে লাগলাম  আমার শরীরও কাপতে ছিল  পেছনে তাকাতে ভয় পাচ্ছিলাম  মনে হচ্ছিল কেউ একজন আমার পেছনে দাড়িয়ে আছে  জীবনে এমন অভিজ্ঞতা খখনো হয়নি আর  তাই বেশ অস্বস্তিতে ছিলাম
# আমি এটির একটি অন্যায় প্রতিক্রিয়া জানি কিন্তু আমি কীভাবে কাঁপছি তা বোধ করার উপায় ছাড়াই আমি এখনই সামনে আসতে পারিনি
# সৌদি থেকে আরিফ আপু তুমি আমার অনেক প্রিয়ো
# ও এসব জালিয়াতির টাকা নিবে না  ভালো মানুষ  তোর আমার মত ক্রিমিনাল নাকি
# বাংলাদেশ হারাচ্ছে তার সর্বকালের সেরা অধিনায়ককে সত্যি অনেক কষ্ট লাগতেছে প্রিয় ক্রিকেটার মাশরাফি বিন মুর্তজা বাংলাদেশে ক্রিকেট থেকে অবসর নেওয়াটা
# করো উন্নতি হউক বা না হউক মেডামের শরীরের ভালো উন্নতি হয়ছে
# আমার মনে হয় এরা স্বর্গে গেলেও পায়খানা করতে চাইবে যদিওবা এই ব্যবস্থা নাই   আমার ঘৃনা যে লিখসে তার জন্য   সিসি টিভি তে ফোটেজ থাকতে পারে
# বরাবরের মত সবাই কাঠের চশমা পরে নিছে  লাভ নাই ভাই কিছু করতে পারবেন না  ভুইলা যান  হলে গিয়ে ঘুম দেন
# আজকে তোরা চুপ থাকস কারণ এইগুলা তোদের স্পর্শ করে নাই  আজকে তোদের কিছু যায় আসে না কারণ তোদের ঘরে আগুন লাগে নাই  কিন্তু বেশি দিন লাগবে না টের পাবি  তোরাও টের পাবি
# তুমি এই দিনে পৃথিবীতে এসেছ   শুভেচ্ছা তোমায় তাই অনাগত ক্ষণ হোক আরো সুন্দর উচ্ছল দিন কামনায়  আজ জন্মদিন তোমার
# বলদের ঘরের বলদ  চাকরির ইন্টারভিউ দিতে গেলে লাথি মেরে বের করে দিবে  এসব আবালগিরি এপিসোড বানিয়ে বেটাগিরি দেখাইসনা  জেহেতু ভাল জায়গায় সেহেতু ভাল কাজে নিজের ব্রেন টাকে কাজে লাগা
# যে মানুষটার জন্য তোমার মনের ভেতর মায়া জন্মে গেছে  সেই মায়ার জাল ছিড়ে বেড়িয়ে আসা খুব কঠিন
# সেদিন পরিক্ষা হওয়ার কারণে আমাদের মধ্যে অনেকেই পরিক্ষায় অংশগ্রহণ করে এবং আমাদের মতো অনেকেই এই জিনিসটা নিতে না পেরে আবার আমাদেরই মধ্যে কয়েকজনের সাথে খুব ন্যাক্কারজনক ব্যবহার করি
# সত্যিকারের পুরুষ হয়ে ওঠার জন্য সমাজ যে মিথ তৈরি করে রেখেছে  সেখানে পুরুষের আবেগের প্রকাশ বড্ড বেমানান  পুরুষ নারীর সামনে সমস্যা নয়  বরং সমস্যা সমাধানের নায়ক হিসেবে নিজেকে উপস্থাপন করতেই ভালোবাসেন
# আধা স্বায়ত্তশাসিত শহরটির ওপর চীনা শাসনের বিরোধিতা করে জনগণ বিক্ষোভে ফেটে পড়েছে  প্রায় চার মাস ধরে চলমান আন্দোলন শেষ হওয়ার কোনো লক্ষণ দেখা যাচ্ছে না  পুলিশের ছোড়া কাঁদানে গ্যাস এবং প্রজেক্টাইল থেকে বাঁচতে বিক্ষোভকারীরা হলুদ হেলমেট  কালো বা রঙিন চশমা এবং কৃত্রিম শ্বাসপ্রশ্বাসের ব্যবস্থাসম্পন্ন মুখোশ পরছেন  তাঁদের যেন শনাক্ত করা না যায়  এ জন্য তাঁরা ফেস মাস্ক বা মুখোশ ব্যবহার করছেন
# আমার সামি বিদেশে থাকে আমি তাকে খুব ভালবাসি তার কাছে সুধু চাই সময় ও খুব বিরক্ত হয় আমার উপর
# প্রায়ই দেখা যাচ্ছে মায়ের হাতে সন্তান খুন  স্ত্রীর হাতে স্বামী খুন  প্রেমিকের সাথে পালিয়ে গেছে নবজাতকের মা  কিংবা  মায়ের আত্মহত্যা  আমরা তখন কী করি  কথা ছাড়া মেয়ের দোষ দিয়ে হাত ধুয়ে ফেলি
# অথচ ওই মানুষ টা নাই আমার  কেউ আমারে মেনশন দিয়া কয়না ওইদিন একটু তারাতাড়ি অফিস ম্যানেজ কইরা বের হইবা  বকুল তলায় বইয়া কোলে মাথা রাইখা গান শুনতাম
# সবাই এতো সুন্দর সুন্দর কমেন্ট করেছেন  আমি কি বলবো বুঝতে পারছি না  শুধু এইটুকু বলবো সুরজিৎ দার সব গানের মধ্যে এটা একটা অদ্ভুত সুন্দর গান
# খালের ওপাড়েই শ্মশান  সেদিকে তাকাতেই কেমন গা ছমছমে অনুভূতিতে আপ্লুত হলাম
# সামনে এখন আরেকটা বাড়ি  রক্তাক্ত ধারালো ছুড়িটা নিয়ে এগিয়ে যাচ্ছে সেদিকে  হাসিমুখে  নতুন শিকারের খোঁজে
# এত কস্ট পেলাম  বুক টা ভেঙে যাচ্ছে  আহারে সন্তান কত কষ্ট করেই না ওদের কে মানুষ করলো
# আওয়ামী লীগ ও বিএনপির চার মেয়র পদপ্রার্থী প্রতিদিনই নির্বাচনী প্রচারে নামছেন কয়েক শ কর্মী–সমর্থক নিয়ে  আনুষ্ঠানিক পথসভা না করলেও তাঁরা মিছিল স্লোগানে মাতিয়ে রাখছেন  প্রার্থীরা যেখানেই যাচ্ছেন  সেখানেই সড়কে চলাচলে বিঘ্ন ঘটছে
# দুঃখ না হয় তুমি পেলে সীমাহীন  তবুও তুমি ভালবেসো আমায়
# আমি শিউরে উঠি
# কেননা  জমাট রক্ত তাড়া করে আমায়
# চাইতে দেখি এই এর বেশি  জাদু করছ আমারে একটু বল
# দক্ষিণ আফ্রিকার কেপটাউনে পানি নেই  ভারতের অনেক শহরেও পানির তীব্র অভাব  আমরাও ঠিক এই পরিণতির দিকে এগিয়ে যাচ্ছি  পানি থাকবে না  ছায়া থাকবে না  সবুজ থাকবে না
# প্রায়  মিনিট পর আমি আমার উপস্থিতিকে এক বিশাল খোলা নদীর তীরে আবিষ্কার করলাম  শো শো করে প্রচুর বাতাস বইছে সাথে উড়ে আসছে বালি এবার কিছুটা ভয় পেয়ে গেছি
# বুধবার সকালে আমি বাবার সঙ্গে দেখা করতে থানায় আসি কিন্তু আমাকে দেখা করতে না দিয়ে ওসি আবুল বাশার ও পরিদর্শক  তদন্ত  মনোরঞ্জন মিস্ত্রি গালাগাল করে তাড়িয়ে দেয়  সারা দিনে আমাকে বাবার সঙ্গে দেখা করতে দেয়নি  ওসি বলেন টাকা নিয়ে আস তারপর দেখা করতে দেব
# কেন যে মানুষ এই রায়হানের জন্য এতো পাগল বুঝলাম না
# বাবা খায়া লাইভে আইসা পাগলের মতো নাচে  অশ্লীল অঙ্গভঙ্গি করে এগুলাই নাকি মানুষ পছন্দ করে ভাইরাল করে
# কতোটা বিকৃত রুচির হয়ে যাচ্ছি আমরা দিন দিন
# আমি এসএসসি তে   পাইনি   পাইছি আম্মু বকা দেয়নি একটু  শান্তনা দিছে সামনে এক্সামে ভালো করবি সত্যি মায়ের উৎসাহ পেয়ে এইচএসসি তে   পেয়েছি
# আসল কথা হচ্ছে  এরা বুঝতেই পারছে না ভাইরাস টা কি জিনিস  আর আমার মনে হয় এদেরকে কেউ বোঝাতেও পারবে না পুলিশের ডান্ডা ছাড়া
# কোথাও কোনও জন মনিষ্যি নেই কোথাও একটা ডাহুক ডেকে উঠলো  দাদুর গা টা একটু ছমছম করে উঠলো
#  মার্চ ভারতীয় সিনেমা  ডিকশনারি র শুটিং শুরু করবেন এই অভিনয়শিল্পী  এমনটাই নিশ্চিত করেছেন মোশাররফ করিমের স্ত্রী রোবেনা রেজা জুঁই
# কি সুন্দর পানি নামছে উপর থেকে  প্রথম দুইটা একটু ছোট ছোট ঝর্ণা  কিন্তু পরের দুইটা একটু বড়  অনেক উপর থেকে পানি পড়ছে  দেখতে কি ভালো লাগে
# সবচেয়ে বড় মুনাফিক সে বলেছিল সৌদিয়া নতুন ইউরোপ জুয়া এখন বৈধ বোরকা ছাড়া নারী চলাফেরা বৈধ
#
# বি এন পি কে মারার দিকে এগিয়ে যাচ্ছে দেশ
# কিরে বৃষ্টি নিয়া তোমাগো স্টেটাস টিকটক গান নাচ হাগা মুতা কই
# ঘুম থেকে উঠে এভাবে হতাশ হয়ে যাবো ভাবিনাই
# ভয়ের  সময় কিছু হয় আমার  যার মধ্যে গলা শুকিয়ে যাওয়া অন্যতম
# এই ছাগলের বাচ্চাগুলো যেনো ধর্ম নিয়ে কোনো কথা না বলে
# ভয়ে শরীরের পশমগুলো দাঁড়িয়ে গেছে  এবার আমি স্পষ্ট শুনতে পেয়েছি  অনেকটা বাতাসে ভর করে যেনও আসছিলো কথাগুলো   মিম    মিম
# আজকে  টেম্পু  তে  এক  মাদারচোদ  আমার  সামনে  আমার  দিকে কাঁশতেছিলো   মনে  হচ্ছিলো  মারি  দি  ইতারে
# পুলিশটা সেই লাশটাকে কোলের উপর রেখে কামরিয়ে কামরিয়ে খাচ্ছে পুলিশটার মুখে লাল টকটকে রক্ত লেগে আছে সে তখনি রিকসা টা থামিয়ে জোরে একটা দৌড় দিল এবং কিছুদূর গিয়ে অজ্ঞান হয়ে পড়লো
# শালার শোক প্রকাশ করার লোকের অভাব হয় না কিন্তু জীবন্ত মানুষ বাঁচার জন্য পাগল হয়ে গেলেও কানে সবাই  যারা কিছু করার ক্ষমতা রাখে  তুলা দিয়ে রাখে
#
# বাংলাদেশের এম্পি মুন্ত্রিদের কথা শুনে  করনো ভাইরাস মনে হয় নিজেই কনফিউজড   নিজেদের মধ্যে বলাবলি করতেছে এ কোন বাইঞ্চুদ্দের দেশে আসলাম রে বাবা   কোনো দামই দিচ্ছে না বাল
# শুভ অষ্টমী পূজার শুভেচ্ছা বিদ্যা মেডাম ও সবাইকে
# ভাইরে এক্কেবারে ফাটাইয়া দিছেন
# এই ওয়েদারে হালকা বৃষ্টির সাথে ইন্ডিয়ার টপাটপ উইকেট বৃষ্টি  মন ভাল হইতে কিইবা লাগে আর
#  তিন বছর রিলেশনশিপে কখনো দ্বীপ এমন অশ্লীল ভাষায় কথা বলেনি আর কিস করতে হলেও অনুমতি নিয়েই করতো সেটাও ফোন থেকে
# তৃতীয় সন্তান জন্মের পর থেকেই তাঁর মানসিক ভারসাম্য নষ্ট হয়ে যেতে থাকে  নিজের সন্তানদের যাতে ক্ষতি না করতে পারেন  সেজন্য তিনি আত্মহত্যা করতে চাইলেন দুইবার   দুইবারই তিনি ব্যর্থ হলেন
# ইয়াসির আজমান আরও বলেন  তাঁদের দিনে প্রায়  হাজার নতুন সিম দরকার  হাতে থাকা সিম ফুরিয়ে যাওয়ার পর প্রায় চার লাখ খুচরা বিক্রেতার কাছে থাকা সিম বিক্রি হবে  সিমের দাম বেড়ে যেতে পারে  সব মিলিয়ে একটা খারাপ পরিস্থিতি আসছে
# তাতে আপনার এত মাথা বেথা ক্যান   ও পারে বলেই এইসব করে আর আপনারা পারেননা তাই কুতস্যা রটাইতে জানেন  এইটা তার ক্রেডিট    আর খাইয়া কাজ নাই তাই মানুষের নামে বাজে নিউজ ছাপাইতে চান যত্তসব ফালতু
# দাদাভালো জবাব দিয়েছোঠান্ডা মাথায় এমন জবাব দেবার দরকার ছিল      বাঁদর নাচের উত্তরটা সেরা ছিল
# আগামী একটা প্রজন্ম হয়তো এ কারণে হীনমন্যতায় ভুগবে যে   জীবদ্দশায় তাদের বাপ দাদারা বইমেলা পেয়েও কয়েকটা বই প্রকাশ করতে পারেনি
# অরুন্ধতী রায় মনে করেন  এনপিআর এনআরসি সিএএ নামের আইনগুলোর মূল লক্ষ্য হচ্ছে সাধারণ জনগণকে বিভক্ত করা ও তাদের মধ্যে অস্থিতিশীলতা ছড়িয়ে দেওয়া
# তাতে আমরা ধন্য হয়ে গেছি  নায়ক নায়িকারা পাদ মারলেও নিউজ করতে হবে  ভোদাই এডমিন আমার
# আমি অনেকগুলা জিনিস প্রসেস করতে পারতেসিনা  এর মধ্যে একটা হচ্ছে সাউথ  নম্বর রুমটাতে আর তাহমিদকে দেখা যাবে না  তাহমিদকে আর দেখা যাবে না  আমি এই ব্যাপারটাই প্রসেস করতে পারতেসি না  নিজের রুমের চাইতে বেশি সময় এই রুমটাতে থাকা হইত  ঐ রুমে আর কিভাবে যাব
# মাশরাফির জারজগুলা এতো মূর্খ ক্যান    চটি পেজের নিউজ নিয়া লাফায়
# গান টা অতিব ভালো  তবে যে গান টা গেয়েছে তাকে বলি একেবার যা বিচ্ছিরি গানের গলা তেমনই বিচ্ছিরি গান টা গেয়েছে  হেঁড়ে গলা
# মুরলমানদেরকে বৌদ্বরা যেভাবে ধর্ষণ ও পুরিয়ে হত্যা করছে জারজ ওদেরকেও সেভাবে করা উচিত তাহলে ওরা বুঝতো ধর্ষণ আর পুরিয়ে হত্যা কি জিনিষ
# আওয়ামী লীগ সরকারের টানা  বছর অর্থমন্ত্রীর দায়িত্ব পালন করেছেন আবুল মাল আবদুল মুহিত  জাতীয় সংসদে টি বাজেট উপস্থাপন করেছেন তিনি  শেয়ারবাজার  বেসিক ব্যাংক  একাধিক আর্থিক কেলেঙ্কারিসহ নানা বিষয়ে সমালোচনাও ছিল তাঁর আমলে
# হঠাৎ মনে হলো ভয় তাড়া করছে আমাকে  হাঁটছি তো হাঁটছি
#
# মুখটা যেনও কেউ এসিডদিয়ে ঝলসে দিয়েছে   ওটা দেখে নুরু ভাই ভয়ে কাপাকাপি শুরু করে দিল
# এরকম সন্তান থাকার চেয়ে বন্ধ্যা থাকা অনেক ভালো কি দরকার এমন ছেলে রেখে যে মা বাবার খবর নেই না
# তুমি আমি কেন দূরে দূরে  খুজে বেড়াই ঘুরে ঘুরে  মন কি যে চায়  কাটে শুধু বেদনায়
# আজকের জামানায় যদি আবু জাহেল বেঁচে থাকত তাহলে তোর কাছে হার মেনে যেত সেই সাথে তোকে লিডার মেনে নিত
# সুফিয়া আপুর একটা ফুটফুটে পুত্র সন্তার হয়েছে  মা ও ছেলে সুস্থ আছে  যারা রক্ত দিয়েছে এবং দিতে চেয়েছে তাদের অনেক ধন্যবাদ  আল্লাহ তাদেরও এমন ফুটফুটে বাচ্চা দিক
# স্যার অসম্ভব দামি কিছু কথা
# সচরাচর কেউ বলে না তাই আপনাকে হৃদয়ের অন্তস্থ থেকে সাধুবাদ
# সালা    টে রিমেক বই করে  আললু অরজুনের সাথে তুলোনা  করছে সোন   আললু অরজুনের বালের  যগো নোশ তোর বালের  বই    টাকা দিয়ে দেখার  চে    আর পানু দেখা অনেক ভালো
# যে কোন এক্সপেরিয়েন্স হলেই খুশী হবি  ভাববি জ্ঞানের পাল্লা ভারী হচ্ছে
# আনিসুল হক স্যারের অভাব পূরন হবার নয়
# প্রিতমের সাথে তোমার এতো ঘেষাঘেষি কিসের
#
# বাংলাদেশ যেভাবে উন্নয়ন হচ্ছে শেখ হাসিনাকে আরো দশ বছর থাকা উচিত
# খেলা নিয়ে এত এত গান  আসিফের  সাবাশ বাংলাদেশ গানটা কেউ আজঅব্দি টপকাইতে পারল না আমার কাছে ওটাই সেরা
# দক্ষিণখানে দুই শিশুসহ মা খুন  লাশ উদ্ধারের পর থেকে শিশুদের বাবা নিখোঁজ  পুলিশের সন্দেহ  ডায়েরির লেখা তাঁর হতে পারে  খুনের ঘটনায় তিনি জড়িত
# আপনাদের গালিই প্রমাণ করে আমিই রাইট
# যারা মরে যায় তারা সব কিছুর পাট চুকিয়ে চলে যায়  আমরা যারা থেকে যাই শরীর ও স্মৃতির অসহায়ত্ব নিয়ে  দীর্ঘশ্বাস ও না বলা কথার যন্ত্রণা নিয়ে  তারাও এক রকম মরি  আমাদের পাট চুকে না
# আমি প্রচন্ড ভয় পেলাম  হাত পা কাঁপতে শুরু করলো আমার  আমি কোনোমতে মোবাইলটা বের করে ফেসবুকে ঢুকলাম  দেখলাম তামান্না এক্টিভ
# আপনের কুতু কুতু প্রেমের গুললি মারেন  মজা পাইলাম  সব রাইখা গুল্লি মারেন  খাস বাংলা
# অতিদারিদ্র্যের হার এ বছর এক অঙ্কের ঘরে নেমে এসেছে  গত জুন মাস শেষে অতিদারিদ্র্যের হার  দশমিক  শতাংশ হয়েছে বলে জানিয়েছে পরিকল্পনা কমিশনের সাধারণ অর্থনীতি বিভাগ  জিইডি   গত  বছরে প্রায় এক কোটি লোক নিজেদের হতদরিদ্র অবস্থা কাটানোর যুদ্ধে জয়ী হয়েছেন
# বান্দরবানের লামায় বন্যহাতির পায়ে পিষ্ট হয়ে নুরুল ইসলাম    নামে এক শ্রমিকের মৃত্যু হয়েছে  বৃহস্পতিবার সন্ধ্যায় লামা উপজেলার ফাসিয়াখালী ইউনিয়নের বড় ছনখোলা এলাকায় এ ঘটনা ঘটে
# এক ভদ্রমহিলা মুখ বাঁকিয়ে বললো চেহারা দেখেই বুঝা যায় বদমাইশ টাইপ  এইসব কুলাঙ্গারদের জন্য মেয়েদের রাস্তাঘাটে চলাচলই এখন দায় হয়ে পড়েছে
# ফুল গুলি সব ঝরে গেছে বাগান আজ শুন্য  তোমার কথা মনে হলে লাগে যে বিষন্ন  হঠাৎ করে হারিয়ে গেলে অজনা এক দেশে  কেমন করে চলে গেলে হাওয়ার সাথে মিশে
# এই লাশটার চোখ বন্ধ করা  লাশটার শরীর যেন অনেকটা পঁচে গেছে  লাশটা থেকে তিব্র পঁচা গন্ধ ভেসে আসছে  লাশটাকে চিনতে রহিমের অসুবিধে হয়নি  এটা সেই মাঝির লাশ যে মাঝি এতক্ষণ ধরে নৌকা চালাচ্ছিল  নৌকায় এখন রহিম শুধু একা  নৌকার বৈঠা কেউ বাইছে না  তবুও নৌকা ভেসে চলেছে
# এমন একটা সুখের ঘর যদি প্রতিটি নারীর জীবনে আশে তহলে তদের জীবনটা ধন্য
# এই  পার্লার  এর  মহিলা  গুলা  নং   ডাকাত  কারণ  এরা  সব  সেবার  এতো   প্রাইস  রাখে  তা  বলার  মতো  না  উচিত  হয় নি   এই  মহিলাকে  রোডে  এই  ভাবে  অপমান  করা
# আজ ও মেয়েরা সস্তা মাল
# গুরুতর পরিস্থিতিতে ভয় পাবেন এটাই স্বাভাবিক  কিন্তু যদি অহেতুক ভয়ভীতি পেয়ে যাই
# সব শ্রেণি ও পেশার মানুষ সরকারের শুদ্ধি অভিযানকে স্বাগত জানিয়েছে  আওয়ামী লীগের যেসব পোড় খাওয়া নেতা অনুপ্রবেশকারী ও সুযোগসন্ধানীদের কনুইয়ের গুঁতোয় টিকতে পারছিলেন না  তাঁরাও মনেপ্রাণে চাইছিলেন এ রকম একটি অভিযান চলুক
# সরকারের বিবিন বাহিমনিই এক মাএ ভরসা
# আমি ছিড়ে ফেলেছি ডায়রীর পাতা  যেখানে লিখা ছিলো হাজারো স্বপ্নের কথা   শুধু ছিড়তে পারিনি আমার মনের পাতা  যেখানে জমা আছে অনেক ব্যাথা

# %%
print(training_data1)
print("\n split\n")
print(training_data1)
# Out:
#                                                    text reaction  label  \
# 0     মামা ভয়ে ভয়ে লুকিং গ্লাসের কাপড় সরিয়ে দিয়...     fear      4
# 1     এই বয়সে নাতি নাতনিদের সঙ্গে আনন্দে মেতে থাকার ...  disgust      3
# 2                         আপু আপনাকে খুব সুন্দর লাগছে      happy      0
# 3     তোমার শহরের কোণে কেউ মায়া জমায় কি  আমি এখনো ভা...      sad      1
# 4     এর মাথা পুরোটাই নষ্ট  পশ্চিম বঙ্গবাসী একে ভোট ...    angry      2
# ...                                                 ...      ...    ...
# 3715  আমি কষ্টের স্মৃতি নিয়ে করি বসবাস আমায় নিয়ে কখন...      sad      1
# 3716  আজ থেকে অফিসে এবং বাসায় প্রথম আলো পত্রিকা  বাদ...    angry      2
# 3717  এই নোয়াখাইল্লা বাইনচুদেরে বেধে লেংটা করে রোদে ...    angry      2
# 3718  হিরু আলম জায়েদ খান  ওরা ও  নায়েক আর নোবেল ও এক...  disgust      3
# 3719  সত্যি সাকিব ভাই আজ আপনি আবার প্রমান করলেন কেন ...    happy      0
#
#       num_of_words
# 0               16
# 1               15
# 2                5
# 3               15
# 4               12
# ...            ...
# 3715            22
# 3716            31
# 3717            18
# 3718            14
# 3719            13
#
# [3720 rows x 4 columns]
#
#  split
#
#                                                    text reaction  label  \
# 0     মামা ভয়ে ভয়ে লুকিং গ্লাসের কাপড় সরিয়ে দিয়...     fear      4
# 1     এই বয়সে নাতি নাতনিদের সঙ্গে আনন্দে মেতে থাকার ...  disgust      3
# 2                         আপু আপনাকে খুব সুন্দর লাগছে      happy      0
# 3     তোমার শহরের কোণে কেউ মায়া জমায় কি  আমি এখনো ভা...      sad      1
# 4     এর মাথা পুরোটাই নষ্ট  পশ্চিম বঙ্গবাসী একে ভোট ...    angry      2
# ...                                                 ...      ...    ...
# 3715  আমি কষ্টের স্মৃতি নিয়ে করি বসবাস আমায় নিয়ে কখন...      sad      1
# 3716  আজ থেকে অফিসে এবং বাসায় প্রথম আলো পত্রিকা  বাদ...    angry      2
# 3717  এই নোয়াখাইল্লা বাইনচুদেরে বেধে লেংটা করে রোদে ...    angry      2
# 3718  হিরু আলম জায়েদ খান  ওরা ও  নায়েক আর নোবেল ও এক...  disgust      3
# 3719  সত্যি সাকিব ভাই আজ আপনি আবার প্রমান করলেন কেন ...    happy      0
#
#       num_of_words
# 0               16
# 1               15
# 2                5
# 3               15
# 4               12
# ...            ...
# 3715            22
# 3716            31
# 3717            18
# 3718            14
# 3719            13
#
# [3720 rows x 4 columns]

# %%
print(f"training dataset 1 = \n{training_data1['reaction'].value_counts()}")
print(f"testing dataset 1 = \n{testing_data1['reaction'].value_counts()}")
# Out:
# training dataset 2 =
# happy      883
# sad        810
# disgust    799
# angry      629
# fear       599
# Name: reaction, dtype: int64
# testing dataset 2 =
# happy      311
# disgust    289
# sad        275
# angry      208
# fear       182
# Name: reaction, dtype: int64

# %% [markdown]
# **cleaning ds2**

# %%
training_data2["text"] = training_data2["text"].apply(clean_text)
training_data2["label"] = training_data2["reaction"].apply(get_emotion)
training_data2["num_of_words"] = training_data2["text"].apply(lambda x:len(str(x).split()))

print("\n split \n")

testing_data2["text"] = testing_data2["text"].apply(clean_text)
testing_data2["label"] = testing_data2["reaction"].apply(get_emotion)
testing_data2["num_of_words"] = testing_data2["text"].apply(lambda x:len(str(x).split()))
# Out:
# মামা ভয়ে ভয়ে লুকিং গ্লাসের কাপড় সরিয়ে দিয়ে দেখে বাচ্চাটি একটা রক্তাক্ত পা চিবাই চিবাই খাচ্ছে
# এই বয়সে নাতি নাতনিদের সঙ্গে আনন্দে মেতে থাকার কথা তা নয় এ বুড়ো বয়সের ভীমরতি
# আপু আপনাকে খুব সুন্দর লাগছে
# তোমার শহরের কোণে কেউ মায়া জমায় কি  আমি এখনো ভাবি সেই তোমাকে ফেরানো যাবে কি
# এর মাথা পুরোটাই নষ্ট  পশ্চিম বঙ্গবাসী একে ভোট দেয়   ছ্যা ছ্যা ছ্যা
# আমি গত সপ্তাহের কতটা মনে পড়ছি তা দেখে আমি চমকে উঠতে শুরু করি আমি নিশ্চিত অসুস্থ কিছুটা নার্ভাস বোধ করি
#  শেষ সময়ে এসে কিছু তিক্ত ঘটনা ঘটে গেলো কিন্তু এর জের ধরে নিজ নিজ ইগো নিয়ে যদি সবাই বসে থাকি তাহলে আজ থেকে অনেক বছর পর অবশ্যই পোড়াবে
# রবি আজিয়াটা লিমিটেডের দুই ব্র্যান্ড রবি ও এয়ারটেলের আয়োজনে বাংলাদেশে প্রথমবারের মতো অনুষ্ঠিত হলো আন্তর্জাতিক অনলাইন গেমিং প্রতিযোগিতা  আজিয়াটা গেম হিরো   প্রতি দলে  জন করে  দলের  জন প্রতিযোগী বাংলাদেশ পর্বের চূড়ান্ত পর্বে অংশগ্রহণ করেন  অংশগ্রহণকারী টি দল প্রায়  লাখ টাকার পুরস্কার জিতেছে
# একটা সেকেন্ডও স্কিপ করিনি পুরাই আগুন ছিলো লাভ ফ্রম বাংলাদেশ
# জাহালমের আটক থাকার ঘটনাকে ন্যাক্কারজনক বলে সমালোচনা করে বিএনপির সিনিয়র যুগ্ম মহাসচিব রুহুল কবির রিজভী বলেছেন  তার  জাহালম  দীর্ঘদিন কারাভোগের ঘটনায় দুদকের ভূমিকা নজীরবিহীনভাবে ন্যাক্কারজনক
# স্কুলে ঠিক সময়ে পৌঁছতে না পারার ভয়  এইরকম কতশত ভয় নিয়েই তো আমরা বড় হই
# দায়িত্বে অবহেলা ডাক্তারদের শাস্তি মূলক ব্যবস্থা গ্রহণ করুন  এরকম ছোট মন নিয়ে ডাক্তারি পেশায় আসা উচিত হয়নি
# টিক টক পাগলের কথা জানি না
# কিন্তূ তোমার কথা শুনে
# সবাই হাসতে হাসতে পাগল হয়ে যাবে
# বাঁধন খুলে দিতেই নগ্ন আতঙ্কভরা চোখে সার্জনের দিকে তাকিয়েছিল রোগী  অবিশ্বাস  মিনতি  আতঙ্ক মিলেমিশে একাকার দুচোখে
# হঠাৎ কালো রঙের একটা প্রাইভেট কার সাদিয়ার সামনে এসে দাঁড়ালো সে গাড়িতে উঠতে যাবে এমন সময় গাড়ির ভেতরে কী যেনো একটা দেখে ভড়কে গেলো
# ভাইয়া অামি বাংলাদেশের জয়পুরে থাকি অামার এলাকায় করনার জন্য সব বন্ধ এমন ওভাবি লোক অাছে যারা খুবি ওসহায় অার তাদের দেখলে খুব কস্ট লাগে মনে হয় না খেয়ে মারা জাবে
# ছাত্রীকে যৌন হয়রানির অভিযোগ ওঠা জাহাঙ্গীরনগর বিশ্ববিদ্যালয়ের  জাবি  সরকার ও রাজনীতি বিভাগের এক শিক্ষককে বিশ্ববিদ্যালয়ের সব একাডেমিক ও প্রশাসনিক কার্যক্রম থেকে বিরত থাকার নির্দেশ দিয়েছে বিশ্ববিদ্যালয় প্রশাসন
# সোয়া আটটায় রোকেয়া হলের সামনে থেকে একলা ফেরত আসার সময় চাঁদের আলোয় বুঝতে পারলাম  ক্যাম্পাসের প্রতি মায়া চলে আসলো বোধহয়   সেইযে মায়া বাড়া শুরু করলো  হায়
# অধিকাংশ ভৌতিক সিনেমা দেখলে মনে হয় শুধুমাত্র বীভৎস সব চেহারা কিংবা রক্তভরা মুখ দেখিয়ে দর্শককে ভয় দেখানোটাই বুঝি পরিচালকের একমাত্র আগ্রহ ছিল
# দিদি দেখি পুরা পাগল হয়ে গেছে  ভারতে পাগলা গারত না থাকে বাংলাদেশে পাঠিয়ে দেও ভাল চিকিৎসা হবে
# কেন সে এত হাইপার হচ্ছে  এবং সে কী প্রমাণ করার চেষ্টা করছে  স্পষ্টতই এই অফিসার  স্বাস্থ্যকর্মী  ব্যাংকাররা বা লকডাউনের এই মুহুর্তে এখনও ডিউটিতে থাকা কর্মকর্তারা আমাদের বিনোদন দেওয়ার জন্য এখানে নেই
# সরকারের পক্ষ থেকে জনসমাগম এড়িয়ে চলার কথা বলা হচ্ছে  ইতিমধ্যে স্কুল কলেজ বন্ধ ঘোষণা করা হয়েছে  কিন্তু জনসাধারণের মধ্যে এ নিয়ে খুব একটা সচেতনতা তৈরি হয়েছে বলে মনে হয় না  নইলে প্রার্থনার নামে বড় জনসমাবেশ করা বা সন্তানদের শিক্ষাপ্রতিষ্ঠান বন্ধের সুযোগে ভ্রমণের পরিকল্পনা করত না এত মানুষ
# ইতিহাসের যেসব ভয়ংকর দিনের কথা শুনেছি সেগুলো কি আমরা এবার দেখতে চলছি আল্লাহ্ একটু করুনা করুন  রক্ষা করুন সবাইকে
# আরো একটু সামনে এগিয়ে কেমন এক অপার্থিব শব্দ শুনতে পেলাম  সারা শরীরের পশম খাড়া হয়ে গেলো
# উপস্থাপক কে শুদ্ধ বাংলা বলতে শিখিয়ে পাঠান  বুড়ো বয়সে এত নেকা উচ্চারণ কেনো
# শীশির ভেজা দুর্বা ঘাসে  শীশির কনা বলছে হেসে  বিদায় নিয়েছে হিমাল রাত  জানাই তোমাদের সুপ্রভাত
# জাতিগতভাবে আমাদের যে চোর বা পকেটমার পিটায়ে মাইরা ফেলার সংস্কৃতি  একজন নারী অপরাধীরে উনার অপরাধের শাস্তি পাওয়ার পরেও ধর্ষণের আমাদের যেই আকাংক্ষা  উনারে সম্মিলিতভাবে বেশ্যা বানানোর যেই প্রকল্প  তা থিকা আপনারা দয়া কইরা বাইর হইয়া সুস্থ হন  দয়া কইরা সুস্থ হন  দয়া কইরা সুস্থ হন
# তারা ঠিকই ব্যাডমিন্টন খেলে  অথচ মানুষের প্রজেক্ট আইডিয়া দেখার টাইম নাই  আমাদের  এর টাইমে তাদের টাইম হয়
# সরকার বলার পরই যদি সব মানতে হয়  তাহলে বিবেকটা কই রাখলেন  বিবেক বিবেচনাবোধ বলতে কিছু একটা আছ তো
# কোন জানি ঠেলা দেয় পরীক্ষায় কারণ জাতির গুরুদের তো হাত একটায় যে দেখিয়ে ছাড়বো দাড়াও  এই ভয়ে হয়তো কিছু স্পষ্ট জোর দিয়ে বলতেছে না
# কৃষ্ণকাঠি এলাকার জ্বরের রোগী সুখী আক্তার    বলেন   প্রচণ্ড জ্বরের কারণে দাঁড়াতেই পারছি না  ভাবছিলাম হাসপাতাল থেকে চিকিৎসা পাব  কিন্তু ডাক্তার জ্বরের রোগী দেখতে ভয় পাচ্ছেন
#  সাহস
# বলে যতই নাম ডাক থাকুক  ভূতের
# ভয় তার বেজায়
# কাজের কাজ কিছুই হয় না
# আসলে ভাই দোষটা ওর না দোষটা হলো দেশি বেলুন কম্পানি গোলার হালারপুতেরা অতিরিক্ত মুনাফা লাভের আশায় পাতলা করে কন্ডম বানায় আর এগোলা ফুটো হয়ে ওর মতো দুই একটা সানি লিওন জন্ম নেয়   এদের বাবা মা নাই     কেউ কি দেখতে পায়না এদের কর্মকাণ্ড
# শুনে খুশি হলাম  আরো ভাইরাস ছড়িয়ে পরলে   আরো পিছানো হবে    আহা কি আনন্দ আকাশে বাতাসে
# এই হল বালকাতায় পাকি বির্যের অবৈধ বংশ এ জন্য দেখবেন পাকিদে
# অনেকদিন পর ভাইদের সাথে দেখা     ভাইয়ের সাথে আড্ডা দিয়ে অনেক মজা পেলাম
# নোবেল মানষিক ভারসাম্যহীন হয়ে গেছে তাকে পাবনায় পাঠানো হোক
# আমার বড়ভাইকে পছন্দ হয়নি ভালো কথা  কিন্তু যে ছেলে দেখতে গেছে তার ছোটভাই কে কিভাবে পছন্দ হয়  মেয়েটার কি লজ্জা শরম বলতে কিছুই নেই  পরিবারই বা কি শিক্ষা দিয়েছে মেয়েটাকে
# হিংসা ও ঘৃণাকে দূরে সরিয়ে সাম্প্রদায়িক সম্প্রীতির হাত বাড়িয়ে দেয়ার আহ্বান জানান এই তারকারা
# রহিম নৌকাটার পাশে তাঁকাতেই চমকে উঠে  তার শিরদাড়া দিয়ে যেন ভয়ের একটা শীতল স্রোত বয়ে যায়  নৌকার ঠিক গা ঘেসে একটা মরা লাশ ভেসে চলেছে
# এখানে একদিন আমি কৃকেট খেলেছি
# মসৃন হোক জাগোর পথ চলা সুযোগ পেলে অংশিদা র হওয়ার আশা আছে
# এখনো তার ভৌতিক কর্মকান্ড থেমে নেই  কেউ তার অনুমতি ছাড়া ছবি তুললে তাকে ভয়ানক পরিণতির মুখে পড়তে হয়
# ভয় আছড়ে ভয় পাছড়ে ভয় নিত্য ভয় সনাতন ভয়
# শিশুটি হয়ত আর দশদিন বাঁচবে  তবে শেষটা ক্রিকেটের সাথেই   পাঁচ বছরের ছোট্ট শিশু স্ল্যাটার ওয়াকার  যেকোনো দিন পৃথিবীর মায়া ত্যাগ করে চিরতরে চলে যেতে পারে ক্যান্সার আক্রান্ত শিশুটি
# পুশ ব্যাক আপনারে করবো   চুপ থাকেন
# তাদের সেই ব্যারিকেড  তাদের তল্লাশি চৌকি তাদের বর্ণবাদী দেয়াল সব টপকে আমি আমার মাতৃভূমিতে ফিরে যাবই  আমি আরবের কালো মেয়ে আর আমরা আসছি যাবতীয় ক্রোধের সিঁড়ি বেয়ে
# দেশে অনেক কিছু হচ্ছে অবশ্যই বাইরের দেশের লোকরা সেটা জানতে পারছেনা কেননা তারা সেটা পাশে না সামান্য কিছুই তাদের কাছে পৌঁছে তাই বললাম
# সকালের উৎসাহটা রাত বাড়ার সাথে সাথে কেমন মিইয়ে গেলো  আপাত সাহসী শিপ্রার এত বড় বাড়িতে  দুটো বাচ্চাকে নিয়ে রাত কাটানোটা বেশ ভয়েরই মনে হলো
# বেঁচে থাকো বোন হাজার বছর বাবা মায়ের হৃদয় জুড়ে
# তাইলে পাপন অটো চয়েজ এগ্লা ফাইজলামি পাকিস্তানে যায় নাই তাই নাটক বানাইতেছে মনে হয় ওগো বাপে পাপন্স আইয়া খেইলা দিব
# বল্টু বুঝে গেল মহা বিপদে পড়েছে সে  এখনই চিতা তাকে ঘাড় মটকে খাবে  এখন যে প্রাণটা যাবে
# পরিচালক একটা নাম্বার ওয়ান লুইচ্চা       নয়তো ভদ্রতা বজায় রেখে যে নাটক তৈরী হয়ে থাকে সেখানে কেন এত পোষাকের অভদ্রতা
# বাংলাদেশের সঙ্গে সম্পর্ককে  আরও উচ্চতায়  নিয়ে যাওয়ার অঙ্গীকার পুনর্ব্যক্ত করেছে ভারত  আজ শনিবার নয়াদিল্লিতে প্রধানমন্ত্রী শেখ হাসিনার সঙ্গে সাক্ষাৎ করে ভারতের পররাষ্ট্রমন্ত্রী এস জয়শঙ্কর এই অঙ্গীকার পুনর্ব্যক্ত করেন
# ঝুমুর আপুকে অনেক সুন্দর লাগে হাসিটা অনেক সুন্দর আপু
# দায়িত্বে থাকা নার্স ইলা সিকদার ব্যবস্থাপত্র লেখার কথা শুনে রাগ করে সেই কক্ষ থেকে চলে যান  চিকিৎসক দেখাতে না পেরে হতাশ হয়ে চলে যাচ্ছেন রোগীরা
# আজকে তোরা চুপ থাকস কারণ এইগুলা তোদের স্পর্শ করে নাই  আজকে তোদের কিছু যায় আসে না কারণ তোদের ঘরে আগুন লাগে নাই  কিন্তু বেশি দিন লাগবে না টের পাবি  তোরাও টের পাবি
# সে মিথ্যা বলে আসলো আর সে মিথ্যা এই জন্য বলেছে কজ নিজের দেশে সে সিকিউরড ফিল করছেনা সংখ্যালঘু হিসেবে সে অপেক্ষাকৃত দুর্বলের মধ্যে পরে তাই কেউ মেরে ফেলার আগে জানপ্রান বাঁচাতে মিথ্যে বলেছে
# আপনাকে চক বাজারের পুরানা সেন্ডেল গুলো দিয়ে ইচ্ছামতো বাইরাইলে আপনি ঠিক হবেন মিঃ ফাহমি
# হে খোদা আপনি কাফেরদের দংস করে দিন
# গাজা খুরি কথা ওরে ভিসা দিয়েছে কে দেশের
# তুই ছাত্রলীগ তাই তুই জানিস না সালাম ডান হাতদিয়ে দিতে হয়  তোরা যে বাংলাদেশের লোক না তোরা ইন্ডিয়ান এর দালাল এই কারণে বাংলাদেশের লোক এই ভাবে কথা কয়
#    আমি      বিষয়ে ট্রেনিং এর জন্য নির্বাচিত হয়েছি  এই ট্রেনিং বাংলাদেশে এই প্রথম এবং এতে নির্বাচিত প্রত্যেকের পেছনে সরকারের খরচ হবে এক লক্ষ দশ হাজার টাকা  বিদেশি এক এর মাধ্যমে নেয়া এ ট্রেনিং এ পরীক্ষার মাধ্যমে নির্বাচিত সেরা  জনকে এই মডিউলে প্রশিক্ষণের সুযোগ দেয়া হয়েছে
# হাসপাতালে নেওয়ার পর চিকিৎসকরাও ভাবেননি ওয়াটসন বাঁচবেন   দিন কোমায় ছিলেন  মাথায় টি অস্ত্রোপচার করতে হলো  জ্ঞান ফেরার পর আরও ছয় মাস কাটল ইনটেনসিভ কেয়ারে
# আমি হলাম আকাশ  কষ্ট আমার মেঘ  জোস্না আমার আবেগ  বৃষ্টি আমার কান্না  রোদ আমার হাসি  কি করলে বুঝবে  বন্ধু তোমায় আমি কত ভালোবাসি
# রাজধানীর জুরাইন  শ্যামপুর  ধোলাইপাড়  দনিয়াসহ আশপাশ এলাকায় খাবার পানির তীব্র সংকট  ওয়াসার পানিতে দুর্গন্ধ  রং ও কালচে পানির কল ছাড়লেই দুর্গন্ধসহ ফেনায় ভরে ওঠে পাত্র  ওয়াসার পানির এই চিত্র নগরীর  নম্বর ওয়ার্ডের রসুলবাগের ইদ্রিস মিয়ার  নম্বর বাড়ি থেকে নেওয়া ছবি
# সমাজে বিষাক্ত মানুষ গুলো যুগে যুগে ছিল  আছে থাকবে
# এই বিষাক্ত আগাছা গুলো এরিয়ে চলাই উত্তম
# সেদিন বন্ধুরা আড্ডা দিচ্ছি  হাসছি   হঠাৎ করে আমি বললাম  অনেকতো আনন্দ হলো এখন চলো আমরা যে যার দুঃখ গুলো শেয়ার করি  কেউ পাত্তাই দিলো না  তখন মনে হলো  বেদনা আসলে লজ্জাস্থানের মতো  ওগুলো লুকিয়ে রাখতে হয়
# ভালবাসা দাওনি ঠিক আছে অন্তত বিয়েতে দাওয়াতটা দিয়ো কেমন  অনেকদিন ভালোমন্দ খাই না
# এরদোগান কার বিরুদ্ধে হুংকার দিবে ইজরাইল দ্রুত সুস্থ হোক ফিলিস্তিনে নির্যাতন শুরু করুক তাহলে আমরা খলিফা এরদোয়ানের হুংকার শুনতে পাবো
# সৃষ্টি হবে অন্যরকম গল্প আজ আলোর নিচে সাজাবো আমি  অন্ধকারের সাজ  দেখে আবার আসেনা যেনো  তোমার চোখে পানি  হঠাত্‍ করে দেখবে তুমি হারিয়ে গেছি আমি
# বড়ো স্বপ্ন নিয়ে পোলট্রি খামার শুরু করেছিলেন গাজীপুরের আব্দুর রউফ স্বপন  কয়েক বছরের মধ্যে লাভের মুখও দেখতে শুরু করেন তিনি  কিন্তু ফিডের অতিরিক্ত দাম  মুরগির নানা অসুখ বিসুখে প্রয়োজনীয় প্রতিষেধকের অভাব  বড়ো উত্পাদনকারীদের সঙ্গে অসম প্রতিযোগিতাসহ বিভিন্ন কারণে থমকে যায় তার স্বপ্ন
# কথা হইল  এই কুত্তামারা মেকাপভরা মুখের ঢং দেখব নাকি কি বলতেছে তা শুনব  এ নিয়া ভাবতে ভাবতে আমার ডিপ্রেশনে যাওয়ার অবস্থা হয়া গেছে
#  স্মৃতি আছে এখানে—আছে তার সমস্ত ভয়াবহতা নিয়ে
# অত্যন্ত আশাব্যঞ্জক খবর হলো  এই প্রবণতা এখন কাটতে শুরু করেছে  বেসরকারি উদ্যোগে রাজধানীর কয়েকটি হাসপাতালে নারীর স্বাভাবিক প্রসবের হার বাড়ছে  দেখা গেছে  এ বছর এসব হাসপাতালে  জনের মধ্যে  জন গর্ভবতী মায়ের স্বাভাবিক প্রসব করানো হয়েছে
# বার্মা থেকে আসা ইয়াবা ঠেকাতে তৎপরতা নেই অথচ অসহায় রোহিঙ্গাদের ঠেকাতে এতো তৎপরতা
# আমাদের বাংলা ভাষা সারা বিশ্ব ছড়িয়ে যাবে একদিন জয় হোক বাংলার
# বাঙ্গালী বরাবরের মতোই অতি আবেগী আর কুসংস্কার প্রিয়
# ও মাবুদ দয়ার আল্লাহ দুনিয়ায় সমস্ত মানুষ কে এই মহামারি গজব থেকে বাচিয়ে দিন  সবাই কে সিরাতল মুস্তাকিমের রাস্তায় আসার তৌফিক দান করুন  আমিন
# আজকের এই মহান রাতেই কিছু মৃত মানুষ প্রাণ ফিরে পেয়ে কবর থেকে ওঠে আসবে  কারণ আগামীকাল যে নির্বাচন
#  সালে কুয়াকাটা সমুদ্রসৈকতকে পর্যটন কেন্দ্র ঘোষণার পর থেকে সেখানে পর্যটকদের সংখ্যা ক্রমাগত বেড়ে চলেছে  স্থানীয় হোটেল ও মোটেল ব্যবসায়ীদের মতে   সালে কুয়াকাটায়  লাখের কাছাকাছি পর্যটক গিয়েছিলেন  ঘূর্ণিঝড় বুলবুল ও চলতি মৌসুমে শীতের প্রকোপ বেড়ে যাওয়ায় গত বছর পর্যটক সংখ্যা কিছুটা কমেছিল  তবে সংশ্লিষ্টরা আশা করছেন  শীত কমে গেলে পর্যটকের সংখ্যা আবার বাড়বে
# যেদিন খুলনা দিয়ে চলে আসার সময় হয় দেখি ছোট বোন দরজা আটকাইয়া কাদে  সারাদিন কাদে  সকালে থেকে শুরু করে রাত অবধি কাদে
# মাশাল্লাহ অনেক সুন্দর লাগছে আপু আপনাকে
# বাল ফালাইয়া টাল দিয়ে দিবে
# গভীর রাতে একটুখানি জানলা দিয়ে গান শুনতে পেয়ে কনর্সাটে যাওয়ার আকুলতা হত  এমনকি টিকেট কেটে অনেক দূরে যেতাম তা দেখতে  আর এখন প্রতিনিয়ত এসব দেখার সুযোগ থেকেও যেতে ইচ্ছে হয় না
# আজকে রাতে শহর থেকে ক্যাম্পাসে ফিরার সময় মাতামুহুরি বাসে আমার একটা ব্যাগ ভুলে ফেলে এসেছি  ব্যাগটি  এর ছিলো ব্যাগে কিছু কাপড় এবং একটি খাতা ছিল  যদি কেউ পেয়ে থাকেন তাহলে জানানোর জন্যে অনুরোধ করা হলো
# আমাদের এখনে দেখলাম যারা সারাদিন মোমবাতি জ্বালানোর বিরোধীতা করলো অথচ রাত হতেই বাজি ফাটাতে আরম্ভ করলো এরা জানোয়ার ছাড়া  আর কিছু না
# প্রতীক আসল কথা না   কথা হচ্ছে মানুষ টা কে
# কোনোকিছুকে ভয় পাচ্ছি মনে হলে  প্রথম যেটা মনে হয়  এই ভয়টা আমাকে কাটাতেই হবে
# অস্ট্রেলিয়ার পূর্ব উপকূলীয় এলাকায় গত সেপ্টেম্বর থেকে দাবানলের আগুন জ্বলছে  দাবানলে এ পর্যন্ত  জনের মৃত্যুর পাশাপাশি ব্যাপক ক্ষয়ক্ষতি হয়েছে  প্রশান্ত মহাসাগরে পৌঁছে যাচ্ছে ভয়াবহ এই দাবানলের ধোঁয়া
# ইট আর সিমেন্ট এর দেয়ালে মানুষের এক চিলতে ভালোবাসা আমাদের বাঁচতে শেখায়  বাঁচাতে  শেখায়  আল্লাহর কাছে প্রার্থনা করি যেন সুখে থাকো  ভালো আর সুস্থ থাকো
# এক্সপেরিয়েন্স হয়েছে বেশ হয়েছে  এতো নেগেটিভ রিভিউ এর পর আপনারা যান বলে তারা খাবার এর মান ঠিক রাখে না
#
# ভাইরে ভাই  গাজা খেয়ে সিনেমা বানালেও এতো বাজে সিনেমা বানানো সম্ভব না  এরা আসলে কি খায়
# দিপুর ডাক্তার হবার জেদের শুরু তখন থেকেই  দীর্ঘশ্বাস ফেললো দিপু  ওর এখন মনে হচ্ছে ডাক্তার না হলেই মনে হয় ভালো হতো
# কিছু না হলে তর শরীরের উন্নতি হয়েছে অষ্টলিয়া গরুর মত
# ভালবাসা বুঝি শুধু কষ্ট দিতেই জানে  তোমাকে ছাড়া যে আমার নিশ্বাস নিতেও কষ্ট হয়
# বন্যার পানিতে ডুবে গেছে ইতালির ভেনিস শহরের অধিকাংশ স্থান  এখন পর্যন্ত দুজনের মৃত্যু হয়েছে বলে জানা গেছে  ভেনিসের মেয়র লুইগি ব্রুগনারোর দাবি  জলবায়ু পরিবর্তনের সরাসরি প্রভাবেই এই বন্যা
# বিষাদ ছুঁয়েছে আজ  মন ভালো নেই  মন ভালো নেই  ফাঁকা রাস্তা  শূন্য বারান্দা সারাদিন ডাকি সাড়া নেই  একবার ফিরেও চায় না কেউ পথ ভুলকরে চলে যায়  এদিকে আসে না আমি কি সহস্র সহস্র বর্ষ এভাবে তাকিয়ে থাকবো শূন্যতার দিকে
# তোমার মত আমিও এইরকম একটা স্ট্যাটাস দিব ভাবছিলাম কিন্তু সাহস পাইনাই
# আপনাদের কি পাকিস্তান আর বি এন পি ছারা কোন খবর নেই
# এইভাবে করতে করতে যখন হাসপাতাল থেকে আর একটু দূরে তখন সেই মানুষদের মধ্যে থেকে একজন এসে জানালায় ঘুষি মেরে গাড়ির কাচটা ভেঙে ফেলল  ড্রাইভারকে মারধোর করে ফেলে রাখলো রাস্তায়  আর আমাদের কাছ থেকে কেঁড়ে নিলো আমাদের বাবুটাকে  কেঁড়ে নিয়েই ছুড়ে দিলো সামনের একটা জলাশয়ে  সেই জলাশয় আমি কোনোদিন দেখিনি  পুরো পানি কালির মতো কালো
# কোন মুভির নাম জানোস না আবার কথা কস অল ভিডিও বানাস বলদ কোথাকার
# আমরা চাই রোহাঙ্গাদের কে বাংলাদেশে ডুকতে দেয়া হওক
# আমি আর বাবা এটা নিয়ে অনেক মজা নিচ্ছিলাম  যদিও ক্লাস শুরুর পরে বুঝতে পারি ব্যাপারটা সিরিয়াস খুব কারণ আমাদের ফার্স্ট ইয়ারে ক্যাম্পাসে ছেলে মেয়ে কথা বলা নিষিদ্ধ ছিলো  যেটা খুবই ফ্রাসট্রেটিং
# মেডিকেল এর ফাস্ট ইয়ার এ যখন কলেজের  তালায় হোস্টেল এ ছিলাম     আজ কতই না আমূল পরিবর্তন  ভালই ছিল সেই দিনগুলি বন্ধু
# পানি যেন বেশিদূর না গড়ায় তাই অলিম্পিয়াস একজন শিষ্যকে ঘুষ দিয়ে বিয়ের অনুষ্ঠানেই নিজের স্বামীকে খুন করালেন  অন্যদিকে সতীন ক্লিওপেট্রাকেও মেরে ফেললেন বিষ খাইয়ে
# খেলার মাঠের মেয়েটিকে ধরে রান্নাঘরে আটকে দেওয়ায় কোনো সমস্যা নেই  সমস্যা হলো মেয়েটি পড়ালেখা করে নিজের পায়ে দাড়ানোটা  এই সমাজে মেয়েদের কোনো স্বাধীনতা নেই  নেই নিজেকে আত্মপ্রকাশের সুযোগ  শুধু মুখেই বলি আছে নারী পুরুষ সমান অধিকার
# কেউ রান্না করতে ভয় পায়  কেউ আবার বেড়াল দেখলে কেঁপে ওঠে
# আরে মূর্খ বলদ আগে সঠিক ভাবে  গাধা  বানান শিখে আয় তারপর  গাঁদা  বইলা গালি দিস  আবাল কোথাকার
# সময় বদলে যায় জীবনের সঙ্গে জীবন বদলে যায় সম্পর্কের সাথে সময় বদলায় না আপনজনের সঙ্গে শুধু আপনজন বদলে যায় সময়ের সঙ্গে
#  সব মাছে গু খায় গাওরা মাছের দোষ হয়    শুধু মিডিয়া জগতে নয়  অন্য প্রতিষ্ঠান গুলোতে কি হয় না   অবশ্যই হয়   আমি  এ পা দিলাম  অভিজ্ঞতায় বাস্তব অর্জন কম নয়
# আমরা জিতলেও বাংলাদেশ হারলেও বাংলাদেশ
#  ডিয়ার বাংলাদেশ নাটকে ইনি অভিনয় করেছেন আমার তখন থেকেই এই আপুকে ভালো লাগে
# লোকটি আগের আমলের মণি ঋষিদের মতো লম্বা চুল  খালি গায়ে বসা  চোখ বন্ধ  তবে রমিজ সাহেব সবচেয়ে যেই
# জিনিসটা দেখে ভয় পেয়েছিলেন যে  ঐ বৃদ্ধ লোকের গা দিয়ে আলোর মতন বের হচ্ছে এবং আশ্চর্য এক মায়াবী গন্ধ পুরো ঘর জুড়ে
# ভুটানের   এত সুন্দর বাংলা বলতে পারে গর্বে বুকটা ভরে গেল
# গলা বাজিতে কাজ হবেনা দিদি
# কোথায় স্বাস্থ্যসেবার প্রতি ধন্যবাদ দিয়ে নিউজ করাবে আসছে এখন ব্লেইম গেইম খেলতে  গরুছাগল জীবনে মানুষ হবেনা
#   সেশনের মেডিকেলের ভর্তি পরীক্ষায় জঘন্যতম প্রশ্নফাঁসের শিকার এই ব্যাচটাই যখন প্রথমবারের মতো ভর্তিযুদ্ধে অংশগ্রহণ করে
# যদি খোদা সবাইকে একরকম বানাতে চাইতেন তাহলে তিনি সবার পায়ে ধনুর্বন্ধনী লাগিয়ে দিতেন
# এত বছর ক্ষমতায় থাকার পরেও দেশের এ অবস্থা  ধিক্কার জানাই সরকারের অব্যবস্থাপনাকে
# আপনার মত ভদ্র একজন মানুষের কাছ থেকে এই মনোভাবই  আশা করা যায়  আপনি অসামান্য একজন মানুষ  গায়ক  ইন্ডিয়া থেকে আপনার একজন গুণমুগ্ধ
# এইল লোকের নাটক ভালো লাগছে
# এরা রেঁধে এরাই খায় আমার কি লাভ  আমিতো ববিতার কম ছবি দেখি নাই  আগে জানলে ছবিও দেখতাম না টাকাও খরচ করতাম না ববিতাও এতো বড় পাহাড়ের চুড়ায় উঠতে পারতোনা
# অস্ট্রেলিয়ায় বিশ্বের অন্যতম ভয়ংকর বিষাক্ত ছত্রাকের সন্ধান মিলেছে  ফায়ার কোরাল নামের এই ছত্রাক দেখতে ভোজ্য মাশরুমের মতো  বৃহস্পতিবার এ তথ্য প্রকাশ করেছেন দেশটির জেমস কুক ইউনিভার্সিটির একদল গবেষক
# ওর ঘরে গিয়ে দেখি ওর ঘাড়ের মাংস অধেক নেই আর মেঝেতে রক্ত পড়ে আছে  শিবানি আর শিবানি নেই
# একটা জিনিস খুব ভাল্লাগে আমাদের বিশ্ববিদ্যালয়ের টা হলের টা আমাদের বিশ্ববিদ্যালের সাবেক ছাত্রদের নামে যারা কিনা মুক্তিযুদ্ধে প্রাণ দিয়ে গেছেন
# আমি তাদের কাছাকাছি থাকতে ভয় পেয়েছি এখনই আমার ব্লগ লেখা বন্ধ করা উচিত
# সে আমাকে বুকে জড়িয়ে কেবল বলেছিল   তুমি কেঁদে কী করবে  সারাদেশে তোমার বাবার মতো কত মানুষকে মেরেছে ওরা  সারা দেশটাই তো আজকে কাঁদছে
# বাইরে কেমন যেন একটা খসখস শব্দ হচ্ছে  তার মনে হচ্ছে কেউ যেন হেঁটে হেঁটে তার কাছেই আসছে  সে চোখ বন্ধ করে সমানে দোয়া পড়ে যাচ্ছে  এভাবেই সারাটা রাত প্রচণ্ড ভয়ে না ঘুমিয়ে কাটল সোমার
# আমি সিঙ্গেল রুমে থাকতাম   কিছুটা ভয় পেয়ে পাশের রুমের বড় ভাইকে ডেকে তুললাম
#  সালে অনুষ্ঠিত রিয়েলিটি শো  ফেয়ার অ্যান্ড হ্যান্ডসাম  প্রতিযোগিতার প্রথম রানারআপ রিয়াদ রায়হান হচ্ছেন কবরীর নতুন সিনেমার নায়ক
# শীতল সকালে মুন্সীগঞ্জ এর আলদী বাজারে মাঠা খেয়ে আসলাম
#
# এই সকালে কুয়াশা  শিশির অন্যরকম হয় সকালবেলা  খেজুররস  মাঠা  ছানা  দই  মুন্সিগঞ্জ এর আলাদী বাজার এলাকার হিন্দু ঘোসেরা এই পেশায় নিয়োজিত  যুগ যুগ ধরে এই মাঠার দোকান গুলো প্রাচীন ঐতিহ্যের একটি অংশ হয়ে আছে আলদী বাজার এলাকার লোকালয়ের মাঝে
# যে মসজিদ এতো গুরুত্বের তার নামাজিরা কতো গুরুত্বের  আসুন নিয়মিত নামাজ আদায় করি
# এমন করে এগিয়ে যাও বাংলাদেশ
# শিওর গাঁজা খেয়ে প্রশ্ন করছে    আর মেয়েগুলা আন্তর্জাতিক পর্যায়ে কমপিট করবে  তারা প্রেশার সিচুয়েশনে এইভাবে ঘাবড়ে গেল  তাদের গ্রুমিং করছে কোন ছাগলে   পুরা শো টাই ক্রিঞ্জ
# সবচেয়ে ভয়ংকর ব্যাপারটা হচ্ছে মৃত বাচ্চাটি সিটের উপর দাড়িয়ে তাদের দিকে মুচকি হাসছে এবং বাচ্চাটির চোখের মনি নেই
# ওরে শালার ফরমালিন গুগল ও বের হয়ে গেছে
# চুয়েটে  বছর থাকাকালীন কখনো দেখি নাই  এমনও হয়েছে যে হল গুলোকে সাউথ ও নর্থ হল নামেই অনেকে চিনে  আসল নাম অনেকে জানেই না
# পাকিস্তানে টেস্ট   তে  তাহলে পাকিস্তান সফর ও তো  মুজিব বর্ষের শ্রেষ্ঠ উপহারের তালিকায় থাকা উচিত
# পুলিশ বলেছে  হাতুড়ি দিয়ে মাথায় আঘাত করে মুন্নীকে  আর দুই শিশুকে শ্বাসরোধ করে হত্যা করা হয়েছে
#  জিহাদ ও খেলাফতের সিলসিলা বইটিকে নামের কারনে এক অনলাইন পরিবেশক তাদের ওয়েবসাইটে রাখেন নাই  দুইজন পাঠক বইটির কারনে পুলিশের হাতে হয়রানি হয়েছেন
# ইননানিললাহি ওয়া ইননা ইলাইহি রাজিওন আললা ওনাকে জাননাতের মেহমান হিসেবে মেনে নিন আমিন
# আমরা একটু আগে দেখলাম খুব ভাল লেগেছে
# নাজমা কি মারা গেছে নাকি তাকে মারা হয়েছে    হায়রে বাংলাদেশ    কেন যে এই বাংলাদেশে গজব পরেনা
# চাকায় একটা ব্রেক চিলো ঐ চুইচ টা পা দিয়ে চাপ দিলে হতো ঐ খানে যারা চিলো বলদ মার্কা তাই এমন হলো ঐখানে লোকগুলো দেখতেছে সবাই সহযোগিতা করলে এমন হতোনা সব শালারা ভিডিও করতেছে সব মাদারচোদ
# আপনি একবার কাচ্চি ভাইয়ে গিয়ে কাচ্চি খাদক খেয়েছিলেন তা দেখে আমরা গিয়েছিলাম কিন্তু সেখানেও আমাদেরকে আপনার চাইতে চাল ও মাংস পরিমাণের অনেক পার্থক্য ছিল  তাই এখন আর আপনাদের ব্লগ দেখে যাওয়ার চিন্তা করিনা কারন ওটা আপনাদের জন্যই ঠিক আছে
# করোনাভাইরাস ছড়িয়ে পড়ার আতঙ্কে যুক্তরাষ্ট্রের সান ফ্রান্সিসকোতে আগামী মার্চ মাসে অনুষ্ঠেয় মার্কেটিং সম্মেলন বাতিল করেছে ফেসবুক কর্তৃপক্ষ
# ভাই এটা কি আপনি গল্প লিখলেন আমার মনে আতঙ্ক শুরু হয়েছে আর এরকম গল্প পোস্ট করেননা প্লিজ  ভয় লাগে
# সে জানে যে  এরপর সে নিজেও মারা যাবে  তার মৃত্যু অতি সন্নিকটে  পরিবারের বাকি সদস্যদের মতো সেও হয়তো কোন এক দুর্ঘটনায়ই মারা যাবে  তার মৃত্যুও এবার কেউই ঠেকাতে পারবে না
# চুরির চুরি উল্টো সিনা জুরি  আবার সাংবাদিক কে তাদের দায়িত্ব শিক্ষাচ্ছে  বাটপারটাকে উচিৎ শিক্ষা দেয়া খুব জরুরী
# আমার চোখমুখ দেখে সম্ভবত কিছু একটা আচ করলো সে ভয়ে ভয়ে জিজ্ঞেস করলো কি হয়েছে স্যার  আমি কাঁপা গলায় বললাম রাসেল ফাসির মঞ্চের দিকে তাকিয়ে দেখো ত কিছু দেখতে পাচ্ছো
# পকি তোদের মা আর রেন্ডিয়া তোদের বাপ লগে নাকি অন্যের চরকায় তেল না দিয়ে নিজের চরকায় তেল দে নিজের দেশ নিয়ে মাথা ঘামা
# তোমার জন্য এই রোদেলা স্বপ্ন সকাল  তোমার জন্য হাসে অনরল স্নিগ্ধ বিকেল  ভালবাসা নিয়ে নিজে তুমি  ভালোবাসো সব সৃষ্টিকে
# জাতীয় অধ্যাপক ড  আনিসুজ্জামান বলেছেন   যারা প্রতিবন্ধী  তাদের প্রতি সমাজের একটা বিশেষ দায়িত্ব আছে  কিন্তু সেই দায়িত্ব সম্পর্কে আমরা খুব সচেতন নই  সচেতন হলে তাদের কল্যাণে অনেক প্রতিষ্ঠান ও সংগঠন গড়ে উঠত
# আজও কষ্ট পায় কিন্তু কিছু করতে পারেনা  তাই আজ আমরা আলাদা হয়েও হয়ত আলাদা নই
# দয়া কইরা আপনাদের এইসব অসৎ শিক্ষকদের  আপনাদের অসৎ গবেষক  আপনাদের অসৎ চিকিৎসক  আপনাদের অসৎ রাজনীতিবিদদের লাত্থি দিয়া ফালায়ে দেওয়া শিখেন
# লোকটা ভয়ে ভয়ে বলল মানে  মেয়েটা ভয়ংকর একটা হাসি দিয়ে বললমনে পড়ে আজ থেকে দশ বছর আগে রাস্তার পাশে একটা মেয়ের লাশ পড়ে থাকতে দেখেছিলেন
#  বাংলাদেশটা ভালো নেই     লাল সবুজের দেশটাতে সবুজ হারিয়ে শুধু রক্তের লাল রয়ে গেছে
# যে দেশে একজন করোনা  রোগীকে সামন্য আইসিউ দিতে পারেনা সে দেশে মানুষ কিভবে চিন্তা করবে যে হাসপাতল গুলোতে চিকিৎসা পাবে
# যতই প্রমান দেখাছ কাজ হবে না   আমরা সব ইতিহাস জানি তাই তোর এই বালের লিঙ্কে ঢুকে ফাদে পড়তে যাবো না
# শিল্পোদ্যোক্তারা সেটির বিরোধিতা করে বলেন  কাঁচামাল হিসেবে ব্যবহৃত শিল্প লবণের শুল্ক বাড়ালে শিল্পকারখানা ক্ষতিগ্রস্ত হবে  অন্য দিকে মিলমালিকেরা সোডিয়াম ক্লোরাইড আমদানির অনুমতি চান
#  সাল থেকে এ পর্যন্ত মানুষের নাগালে থাকা স্বাদু পানির সহজলভ্যতার পরিমাণ অর্ধেকে নেমে এসেছে  ফলে বিশ্ববাসী সুপেয় পানির ঘাটতির চাপে পড়েছে
# বিরোধের জের ধরে এই দুই গ্রুপের মধ্যে আগেও বেশ কয়েকবার বন্দুকযুদ্ধের ঘটনা ঘটেছে  সর্বশেষ গত  ডিসেম্বর ভোরে দুই বাহিনীর মধ্যে গোলাগুলিতে জোনাব আলীর ছেলে কায়সার গুরুতর আহত হন  পরে চিকিৎসাধীন অবস্থায় তিনি মারা যান
# আপনার ইংরেজি উচ্চারণ শুনলে ইংরেজি শেখার আগ্রহ বেরে য়ায়
# পরবর্তী ভিডিও র অপেক্ষায় রইলাম
# ছোট থেকেই শুনতে হতো আমি আপুর মতো না আমাদের বোন বলে মনে হয় না বিয়ের অনুষ্ঠানে অথবা ফটো ফ্রেমে পরিবারের সবার মাঝখানে নিজেকে খাপছাড়া লাগতো সবাই ঠাট্টা করে বাবা মাকে বলতো  ওকে দেখে বোঝা যায় না আপনাদের সন্তান   কথাটা গায়ে কাঁটার মতো লাগতো
# মাঝেমধ্যেই রাফিদের ভয়ংকর চিৎকারে আমার ঘুম ভেঙে যায়  কখনো তিন চারদিনের জন্য উধাও হয়ে যায়  কই চলে যায় কে জানে
# মাঝে মাঝে মনে হয় কান এর নিচে একটা চওর লাগাই দিই   অনেক অসহ্য লাগে মাঝে মাঝে তার উপর  একটা বেত নিয়ে মনের জোট ক্ষোভ আছে সব মিটাই নিই
# ব্যস্ত বগরীর ব্যস্ত পথগুলো এতোটা ফাঁকা হতে আর কখনও দেখিনি
# সবকিছু স্থবির  স্থির হয়ে আছে
# অজানা অচেনা প্রতিষেধকহীন এই ক্ষুদ্র অনুজীবের আড়ালে আঘাতে
# আমি খুব অনিশ্চিত বোধ করছি এবং আমি চাই না যে আপনি প্রেম করার জন্য চাপ অনুভব করবেন
# মমতা বলেন   এখনো দিল্লিতে মিলছে মানুষের মৃতদেহ  গতকালও চারটি মৃতদেহ মিলেছে  প্রতিদিন নালা খুলছে আর বের হচ্ছে মৃতদেহ  দিল্লি থেকে আজ বহু মানুষ প্রাণের ভয়ে পালিয়ে গেছে  এবার দিল্লির মানুষের পাশে দাঁড়াতে হবে
# ক্যাম্পাসে কিছু হেডম ওয়ালা কর্মচারী থাকে   এদের ভাব স্যারদের থেকেও বেশি  মনডা চায়        নিয়া এগুলারে  করি
# আমার কিছু বলতে ইচ্ছা করছিল না  তবু বললাম
#  বিগত   ইং তারিখে কতিপয় উশৃঙ্খল শিক্ষার্থী কর্তৃক আমার অফিস কক্ষের সামনে আমারসহ আরও কিছু শিক্ষকদের নাম ফলক ও জানালার কাচ ভাংচুর করা হয়  যা আমার গায়ে হাত তােলারই সমতুল্য
# স্বাধীনতার  বছর পরে একটা স্বাধীর রাষ্ট্রের কাছে এই চাওয়া গুলো কি খুব বেশী কিছু চাওয়া  মানুষ যদি নাই বাঁচে  প্রতি মুহুর্তে একটা ভীতির মধ্যে থাকে তবে কি হবে  সমূদ্রের মাঝখানে ব্রীজ বানিয়ে কিংবা আকাশ চুম্বি ভবন নির্মাণ করে
# জনগণের ভোটে নির্বাচিত এই সরকারের কোন জনদরদী নেতার কানে এ কথাগুলো পৌঁছাতে পারলেই ওদের আর কোন চিন্তার কোন কারণ থাকবে না
# বিদেশি শ্রমিকদের টাকা দিয়ে দেশ উন্নয়ন হচ্ছে আপনাদের টাকায় না
# শিক্ষকের হাত থেকে শাসনের বেতটি কেড়ে নেওয়ার কারণেই আজ প্রতিটা সমাজে তথা দেশে এতো বেশি বেয়াদবের জন্ম
# এই দানব রাষ্ট্রের সাথে অামাদের কোন যোগা যোগ থাকতে পারেনা
# সবগুলো রে জুতার মালা দিয়ে সংবর্ধনা  দেওয়া হোক
# যারা তাকে বিশ্বাস ঘাতক বলে এখন তারা আসলেই বোকা  কেননা তারা জানে না কুকুরের লেজ কখনও সোজা হয়না
# ছবি গুলা বেশি কিউট  অসংখ্য ধন্যবাদ এত সুন্দর আর কিউট ছবি দিয়ে উইশ করার জন্য
# আচমকা আমার গায়ের ওপর একটা শীতল হাতের ছোঁয়া পেয়ে আঁতকে উঠলাম ভয়ে  বুক ধুকধুক করে উঠল
# এতো ভালো একটা গান থাকতেও আমার বিয়েতে এই গানটা বাজানো হলো না
#
# আইজকাই ছোট ভাই গুলারে বাইন্ধা ট্রস ট্রস কইরা পিডামু
# বাস্তবতা এতই কঠিন যে কখনও কখনও বুকের ভিতর গড়ে তোলা বিন্দু বিন্দু ভালবাসাও অসহায় হয়ে পড়ে
# আমি চিৎকার করে আমার ওরনা দিয়ে ওর হাতটা বাধলাম আমার চিৎকার শুনে আশেপাশের সবাই ছুটে এসে আমদেরকে হাস্পাতাল এ নিয়ে যায়
# আমদানিনির্ভরতা ছেড়ে প্রমিক্সো উৎপাদকে পরিণত হওয়ার ফলেই এমনটা হয়েছে  আর মৌসুমী ইসলামের প্রমিক্সো হেলথ কেয়ার তো এখন বিদেশেও চিকিৎসা সরঞ্জাম এবং ফার্নিচার রপ্তানির স্বপ্নও দেখছে
# আমি বাবাকে জড়িয়ে ধরে চিৎকার করে কান্না করতে করতে বললাম বাবা আমার টাকা লাগবে না
# সব ধরণের পদক্ষেপ নেওয়া আছে   আর  সঠিক সময়ে সঠিক সিদ্ধান্ত নিয়েছি বলেই করোনা নিয়ন্ত্রণে রাখতে পেরেছি   ইউরোপ  আমেরিকা যেখানে হিমশিম খাচ্ছে   সেখানে বাংলাদেশে আমরা নিয়ন্ত্রণে রাখতে পেরেছি   কারণ সঠিক সময়ে সঠিক সিদ্ধান্ত   আর   আমরা করোনার চেয়ে শক্তিশালী   বাকি সব গুজব    এসব কথা শুনলে বা চিন্তা করলে ভাবি   আমরা কেমন মানুষ  অনেক আশ্চর্য লাগে
# একসময় সে বললঃ  তোমাদের মত এত কিছু কেউ জানতে চায়না  সবাই ছবি তুলে চলে যায়  তোমাদের আগ্রহ দেখে ভালো লাগল
# বুয়েটছাত্র আবরার হত্যাকাণ্ডে নানা ধরনের মন্তব্য আসছে সামাজিক যোগাযোগ মাধ্যমগুলোতে  এ হত্যাকাণ্ড নিয়ে নিজের ফেসবুক পেজে স্ট্যাটাস দিয়ে আলোচিত হয়েছেন ভারতীয় তরুণী তনুশ্রী রায়  কলকাতা নিবাসী যাদবপুর বিশ্ববিদ্যালয়ের ছাত্রী তনুশ্রী তার স্ট্যাটাসে লেখেন   যদিও আমি ভারতীয় তারপরও বাংলাদেশের প্রতি আমার আলাদা টান রয়েছে  কারণ আমার পূর্বপুরুষ বাংলাদেশের মানুষ ভালো থাকুক এটা আমি সব সময় চাই
# আনিসুল হক স্যারের অভাব পূরন হবার নয়
# পোস্টের কমেন্টবক্সে লকডাউনে ঘরে আটকে থাকা আমাদের মতো মানুষজন গিয়ে হাহুতাশ করছে  জীবনে জীবনে কত পার্থক্য
# মারুফ হেয়ার কাট জোশ ছিল এটা  রাকিব ভাই আপনি পুরুষ না  মহা পুরুষ ভাই মহাপুরুষ
#  নিরাপত্তাহীনতায় ভুগছেন  জানিয়ে থানায় পাঁচটি সাধারণ ডায়েরি  জিডি  করেছিলেন ব্যবসায়ী মো  ইয়াছিন আলী  আশঙ্কার কথা জানিয়ে আবেদন করেছিলেন পুলিশের কর্মকর্তাদের কাছেও  শেষমেশ তিনি খুন হয়েছেন  তাঁর লাশ পাওয়া গেছে রাজধানীর শেরেবাংলা নগর সরকারি বালিকা উচ্চবিদ্যালয়ের প্রধান ফটকে
# আমি তো সমাজ বহির্ভূত কোনো মানুষ না তবে কেনো আমি তোমাদের মতো করে চিন্তা করতে জানিনা খুব বেশি কিছু কি চেয়েছিলাম  খুব সরল একটা ভালোবাসা ছিলো আমার  অল্প দামের একটা শার্ট হলেও তো চলতো না হয় সারাদিনের ক্লান্তি শেষে তোমার হাতে করা একটু ডাল ভাত খেয়ে তোমার হাত ধরে একটু গল্প আর তোমার কালো কেশের ঘ্রানের আত্নতৃপ্তি এমন একটা সহজ জীবন চাওয়া কি পাপ বলেন  হ্যাঁ পাপ কারণ তোমার পাশের বাসার ছেলে জর্জ মেয়ে ডাক্তার
# চেহারার ঘা থেকে পুজ গড়িয়ে পড়ছিলো  ওর চোখ দুইটা জ্বলজ্বল করছিলো  এতো ভয়ংকর চেহারা কারো থাকতে পারে  জানা ছিলোনা
# বাইরের মানুষ বানানে ভুল করলে কত কি বলা হয়ে যায় আমাদের  এই যদি হয় নিজেদের গাড়ির অবস্থা তখন নিজেদের কি বলবো আমরা
# আপনি  পুলিশ  ফোন  দিয়ে  ওই দোকানের  লোকেশন  বলুন
# বোরকা না পড়লেই চলতো  বোরকার অপমান করার কি প্রয়োজন ছি
# আমি ও তোমাদের সাথে যেতে চাই  ওদের কঠিন শাস্তি হবে ইনশাল্লা
# যে বাড়িতে চায়ের সাথে বিষ মিশিয়ে মানুষ খুন হয় সেখানে চা খাওয়া ঠিক নিরাপদ না আশরাফ সাহেব এবং ওসি সাহেব আৎকে উঠলেন বুঝা গেল
# তাদেরকে বাংলাদেশে অনুপ্রবেশ করতে দেয়া হউক  তাদের জীবনটা রক্ষা হউক  আমার দেশ আমার দেশ বলে চিল্লাও মিয়ারা মরলে বুঝবা কোনটা আমার আর কোনটা তোমার দেশ  সকল রোহিংঙাদের প্রতি রইল আমার শ্রদ্ধা ও ভালবাসা
# কাংলা মানেই ভিক্ষারি পরিচারিকা শ্রমিক গরুচোর ডাকাত চরিত্রহীন বেশ্যা জঙ্গি
# পবিত্র ঈদুল আযহা উপলক্ষে আজ বৃহস্পতিবার থেকে নতুন নোট বিনিময়ের জন্য বাজারে ছেড়েছে বাংলাদেশ ব্যাংক   আগস্ট পর্যন্ত  সাপ্তাহিক ও সরকারি ছুটির দিন ছাড়া  বাংলাদেশ ব্যাংকের বিভিন্ন অফিসের কাউন্টারের মাধ্যমে জনসাধারণের মধ্যে নতুন নোট বিনিময় করা হবে
# আমাদের দেশে অনেক জায়গায় ডাক্তাররা ভয়ে রোগী দেখা বন্ধই করে দিয়েছেন  ভয় পেয়ে রোগীর কাছের আসছেন না অনেক ডাক্তার
# আজেষ্টিনার সাপটারা বড় বড় কথা বলা বাত দায় লজা করা ইচিত গোল খাওয়ার পরেই আবার কথা চোদায়
# লিখতে গিয়ে  ভয়  অনুভূতিটাকে বেছেছিলাম  আমার তীব্র কিছু অনুভূতির মধ্যে ভয় অন্যতম
# পতিবাদ করার মত আর কোনো দেশ নাই
# দুনিয়া উলটাপালটা হলেও কিছু হুজুর ধর্ম নিয়ে ব্যবসা ছাড়বেন না   যেখানে করোনা নিয়ে সবাই আতঙ্কে আছে   কিছু হুজুর কুসংস্কার ছড়ানো মতো  মহান কাজ করছে
# যুব মহিলা লীগ গঠন করা হয়েছিল যুব সমাজের চরিত্র ধ্বংস করার জন্য  অচিরে এই সংগঠনকে নিষিদ্ধ করা হোক
# ঘরে একটা তীব্র গন্ধ পাবে  ঘরটা শীতল হয়ে যাবে  হয়তো কেউ একজন থরথর করে কাঁপতে থাকবে  তার থমথমে গলার স্বর শুনেই আমাদের হাত পা ঠান্ডা হয়ে যায়
# তাদের কিছু বলা যাবে না  বললে বলবে  ক্রান্তিকালেও বিনোদনের দরকার আছে  বাংলাদেশ ঐ অর্থে একাত্তরে স্বাধীন হইয়া বাইচা গেসে  এই চিড়িয়া গুলান অই সময়ে থাকলে পাবলিক এটেন্সান কুড়াইতে কুড়াইতে দেশ চ্যালচ্যালায়া পরাশক্তির কাছে ছাইড়া দিতো
# বর্তমান সময়টা বেশ সংকটজনক অবস্থায় আছে  বিশেষ করে সাহিত্যের পাড়ায়  তথাকথিত কিছ ইতর ভদ্র সেলিব্রিটি হঠাৎ করে লেখক  কবি হয়ে গেলো  যে ব্যক্তি ইউটিউবে অশ্লীল ভিডিও দিয়ে ভরিয়ে দিলো সেও লেখক হয়ে গেলো  বড় ভাই শখ করে বই লিখলো বলে ছোট ভাইও একখানা পুস্তক লিখে ফেলল  বাহ্  কি সহজ  তারা আবার ঘনঘন বইমেলায় যান অটোগ্রাফ  ফটোগ্রাফ দিতে
# এই লাল সবুজের পতাকা কেবল একটি কাপড়ের খণ্ড নয়  স্বাধীনতা লাখো শহীদের প্রাণের বিনিময়ে অর্জিত মানচিত্র
# শেরপুরের শ্রীবরদীর ঐতিহ্যবাহী টেঙ্গরপাড়া উচ্চবিদ্যালয়ের ব্যবস্থাপনা কমিটির সভাপতি সিদ্দিকুর রহমান  বিদ্যালয়ের প্রধান শিক্ষক মো  আবু রায়হান ও শিক্ষক প্রতিনিধি আশিকুর রহমানের বিরুদ্ধে অর্থ আত্মসাতের অভিযোগ উঠেছে
# দাদা আপনার  গুলো ভালো লাগে  ডকুমেন্টারি টাইপের ভিডিও বানানো শুরু করেছি সবেমাত্র আপনারা সাপোর্ট করলে মোটিভেশন পাই  একজন ছোট  হতে চাই  আমাকে সাপোর্ট করুন  আমার ভিডিও গুলো দেখে আসুন  ভালো লাগলে পাশে থাকবেন আশা করি
# তাহসান ভাই  আপনার কথা গুলো সত্যি অসাধারণ  কোন মানুষকে কষ্ট দেওয়া ছাড়াই শিখিয়ে দেয় অনেক কিছু
#  ফেব্রুয়ারী তে প্রাইম বিশ্ববিদ্যালয়ের প্রথম রি ইউনিয়নে অনেকের সাথে অনেকদিন পরে দেখা হলো  এমনই এক আনন্দঘন মূহুর্তে নরসিংদীর ছেলে জাহিদুল ইসলাম সোহেল তার বিবাহের সুসংবাদ এবং দাওয়াত দিলো
# দুই শিশুর বিরুদ্ধে চট্টগ্রাম নগরের আকবরশাহ ও কোতোয়ালি থানায় ইয়াবা ও অস্ত্র  ছুরি  উদ্ধারের ঘটনার পৃথক দুটি মামলা রয়েছে  ওই মামলায় তিন মাস ধরে তারা গাজীপুরের কিশোর উন্নয়ন কেন্দ্রে রয়েছে  সেখান থেকে গতকাল হাজিরার জন্য চট্টগ্রাম আদালতে আনা হয়
# যেসব কুকুরের বাচ্চারা এসব তদারকি করার দায়িত্বে আছে ওইসব কুকুরের বাচ্চাদের আগে বিচার করা উচিত যারা নিরীহ মানুষগুলোর এভাবে আটকে রাখছে
# কে বলেছে নেই
# জাহেদ মালিক বলল  মাস আগে প্রস্তুতি আছে বাংলাদেশে
# আমার সামি বিদেশে থাকে আমি তাকে খুব ভালবাসি তার কাছে সুধু চাই সময় ও খুব বিরক্ত হয় আমার উপর
# নাইন–ইলেভেনের পর এমন নির্মমতার সাক্ষী হবে নিউইয়র্কবাসী  সেটা হয়তো কেউ কল্পনা করেনি  মৃত্যুর মিছিলে এখন বাংলাদেশিরা  বাড়ছে আতঙ্ক  উৎকণ্ঠা
# ক তাহসান ভাই
# ফিরে ফিরে বারবার সে এসেছে প্রতিটি বারে সেই সে নবীন পহেলা বৈশাখ    শুভকামনায় নববর্ষ রঙিন
# ধরেছেন হানিফ সংকেত মহোদয়   অসংখ্য ধন্যবাদ
# আমি এ দৃশ্য দেখে কাঁপতে শুরু করলাম  মনে হচ্ছিলো ভয়ে এক্ষুণি বেরিয়ে আসবে আমার প্রাণ
# ক্ষমতাসীন দল কারচুপির জন্য এই কথাই বলে
# বাইরে সারা শহরে নাৎসি বাহিনী  গেস্টাপো ঘুরে বেড়াচ্ছে  উপরে আকাশ থেকে বোমা বর্ষণ হচ্ছে  ধরা পড়লেই শেষ
# গোঙ্গানির শব্দপেয়ে আরো ভয় পেয়ে গেল  ভয়ের সাথে যুক্ত হল কৌতূহল
# ওখানে গিয়ে না খাইলেই হয়  সবাই যদি এইগুলা খাওয়া বন্ধ করে দেয় তাহলে এই   খাবার গুলা এতো দাম দিয়ে কেনার কোন মানে দেখি না  আরও থাকে ভেজাল মেশানো
# এরকম একজন ইই ছিল আর সব কাছের মানুষরাই আপনাকে যন্ত্রণা মনে করবে
# কা বা শরীফের তোআফের মাঠে মানুষ নেই কলিজাটা কেঁপে উঠে ভাবলেই  ওমরাহ ও অফ রেখেছে সৌদি সরকার নিরাপত্তার সার্থে এক শহর থেকে অন্য শহরে ঢুকতে দিচ্ছে না কাউকে
# যে ছেলে কাপর ছিড়ছিল তখন তাকে বলা উচিত ছিল তার নিজের মা বোনের কাপড় গিয়ে ছিড়তে  অবশ্য এদের জন্মেরইতো ঠিক নেই মা বোন থাকবে কোথ্থেকে
# হাসিনা তোমার দাদার পোলাপান যে টাইগারদের গালাগাল করেছে  আর পতাকার অবমাননা করেছে সেটার কি করবে
# সুফিয়া আপুর একটা ফুটফুটে পুত্র সন্তার হয়েছে  মা ও ছেলে সুস্থ আছে  যারা রক্ত দিয়েছে এবং দিতে চেয়েছে তাদের অনেক ধন্যবাদ  আল্লাহ তাদেরও এমন ফুটফুটে বাচ্চা দিক
# একজন সাংবাদিক অন্যায় করলে অন্যরা তার দায় নেন না  একজন জজ দোষ করলে তার দায় সকর্মীরা নেন না  একজন পুলিশ অপরাধ করলে তার দায় ডিপার্টমেন্ট নেয় না  তাহলে বিএমএ কেন কিছু ডাক্তারের অপরাধের দায় নিচ্ছে  অপরাধীর সাথে যোগ দিয়েছে
# করোনাভাইরাসের প্রাদুর্ভাব বাড়ায় বিশ্ববাজারে জ্বালানি তেলের চাহিদা কমছে  চাহিদা কমায় দামে নেতিবাচক প্রভাব পড়ছে
# কেউ একজন কোম্পানির শেয়ার কিনছে তাই বলে এতো গুলা মানুষরে মাইরা ফেলছে তাও আবার অন্য দেশে গিয়া মাইরা আইছে   হায়রে কুছ তো রাহেম কর
# গতকাল এক টুপি দাড়িওয়ালা ওয়াজ শ্রবণরত দোকানদার যখন পাঁচ টাকার মাস্ক পনের টাকা নিল  আমি বললাম  আপনার জন্য বেহেশতে হুর নাই ভাইজান  আপনারে জাহান্নামে নিয়া পোন্দাইয়া দিবে
# আগে ভাবতাম যে টলিউডের বাকি ছ্যাবলা গুলো থেকে অঙ্কুশ একটু আলাদা   এখন তো দেখছি অঙ্কুশ ই হল আসল বলদ
# একটা ক্লিপে দেখলাম  মেয়ে তার জন্মদাত্রী মা র—যিনি করোনাভাইরাসে আক্রান্ত— কাছে যাচ্ছে না  প্রায় বিশ গজ দূর থেকে চোখাচোখি করে কিছুটা আবেগাপ্লুত হয়ে মা র জন্য আনা খাবার রেখে হাত নেড়ে চলে গেল  নিঃসঙ্গ মা তখন খুঁড়িয়ে খুঁড়িয়ে এসে খাবারের পার্সেলটা নিয়ে ফিরে গেল নির্জন প্রকোষ্ঠে
# শুভেচ্ছা ওবায়দুল কাদের কে দলের সাধারণ সম্পাদক হওয়ায় তাকে অভিনন্দন
# আমি চোখ বন্ধ করে যখন শুয়ে থাকি আমি ফিল করি কেউ আমার চুল ধরে টানছে   এবার আমি অনেক জোরে চিৎকার করে উঠি
# না ফারাজের না  এই বাংলাদেশ শুধু ই তারেক রহমান অ তার বউ এর
# এরকম স্মার্ট মেয়র আবার কবে পাবো  জানি না  তবে আপনি আমাদের মনে থাকবেন স্যার
# এই বাঙ্গালীর কমন সেন্স দেখে আমি অবাক হই না  আতঙ্কিত হই  হোম কোয়ারেন্টাইনের পুরা ব্যাপারটাই একটা তামাশা পর্যায়ে নিয়ে গেছেন আপনারা  কি ভাবতেসেন  এইটা উৎসব  ঈদ লাগছে
# আমাদের বিড়ি মিনিস্টারের সাথে ভালোই মিল আছে
# গায়ে হাতে লোম শিরশির করছে  কিসের থেকে কি হয়ে গেল  হায়রে খোদা  মৃত্যুর এক ফোটাও কেমনে বিশ্বাস নেই
# স্কুল বন্ধু আরো একজন হারালাম  ইমন  এর পর৷
#     ভাই
# তোর আত্মার শান্তি কামনা করি
# আ আ আ কী ব‍্যাথা  চামড়া উঠে গেল কেউ  নিয়ে আসো  একটু নাচ হোক  আহা কী  কী লচক পচক বডি  কী লুল্লুরানী বডি
# রাতে খাওয়ার সময় বন্ধুদের সঙ্গে ভিডিও কলে কথা বলছিলাম  তাদের অনেকেই উহানের পার্শ্ববর্তী শহরে ছিল  বাড়িতে ফিরে আসতে ভয় পাচ্ছিল তারা
# সৌম্যর এমন ভরাডুবি দেখবো ভাবিনি সৌম্যর জন্য প্রার্থনা করা উচিত
# এতদিন অপরিচিত মানুষের মৃত্যু সংবাদ শুনেছি   তাই হয়ত মৃত্যুগুলো সংখ্যা ছাড়া আর কিছু মনে হয় নি আজকে করোনা আক্রান্ত হয়ে বন্ধুর বড় ভাই মৃত্যুর খবর শোনার পর থেকে মনে হচ্ছে সত্যিই করোনা ধরে ফেলল আমাদের
# তৎকালীন হিন্দু সমাজে উঁচু জাতে জন্মানোকে পুঁজি করে নিচু জাতের মানুষকে শোষণ করার ঘৃণ্য প্রথা   ব্রাহ্মণতন্ত্রে র বিরুদ্ধে সচেতনভাবে ঘৃণা রচিত হয়েছে এ চলচ্চিত্রে
# অনূর্ধ্ব  বিশ্বকাপে প্রথমবারের মতো ফাইনালে বাংলাদেশ  নিউজিল্যান্ডকে  উইকেটে হারিয়ে স্বপ্নের ফাইনালের দেখা পেল যুবারা
# বুঝলাম না কেন যে বালের আলো প্রত্রিকা রোহিঙ্গাদের পিছনে গেলেছে
# তাদের কে ঢুকতে দিলো কেন  এক মাস আগে থেকেই সাবধান হওয়া উচিৎ ছিলো
#
# ভাই আমাগো টাংগাইলা পোলা দেখিয়ে দিছে একাই একশ ওর মত জাতীয় দলে খেলোয়ার দরকার
# শিক্ষামন্ত্রী দীপু মনি বলেছেন  কোনো কোনো গাইড ও নোট বই মুদ্রণকারী প্রতিষ্ঠান অনৈতিকভাবে কোনো কোনো শিক্ষাপ্রতিষ্ঠানের শিক্ষকদের আর্থিকভাবে প্রলুব্ধ করে  তারা এসব নোট ও গাইড শিক্ষার্থীদের কিনতে বাধ্য করে  এই নোট ও গাইড বন্ধে জেলা প্রশাসনের সহযোগিতা চেয়েছেন শিক্ষামন্ত্রী
# হঠাৎ অরুণের সামনে চলে এলো মেয়েটি গলা টিপে ধরলো অরুণের শ্বাস নিতে পারছে না সে  মাথা ঘুরছে হঠাৎ মেয়েটি শূন্যে তুলে অরুণকে আছাড় মারল ছাদের রেলিঙে
# এই বাল তার মুখ যদি কেউ অফ করতে পারে      বাল একটা
# তোমাদের মত নাসতিক হলুদ মিডিদের কে আগে জেলে দেওয়া উচিত
# আলহামদুলিল্লাহ আলহামদুলিল্লাহ আলহামদুলিল্লাহ  মুহতারাম  কিজে ভালো লাগছে তা ভাষায় বুঝাতে পারছিনা  জাতির প্রতিটি অংগনে আপনাদের পদচারণা কামনা করি
# আমি জানি যখন কোনও উত্তেজিত বাচ্চা হিংস্র হয়ে ওঠে তখন পিতামাতারা যে ব্যথা অনুভব করেন
# এটা কতটুকু ঠিক     তাও আবার ছবি তুলে সোস্যাল মিডিয়ায় প্রকাশ    মানলাম দায়িত্ব  তারপরেও আমরা তো মানুষ বিবেকবোধ তো থাকা দরকার
# এই ছবি গুলা আর ভিডিও গুলা আমাকে  খুব ডিস্টার্ব করছে  একটু পর পর মনে পড়ছে আর আমি আবেগপ্রবণ  ভীত এবং  অসুস্থবোধ করছি
# ঠিক ঠিক করে ভাবলে এখনো এই গল্পে আমি ভয় পাই
# যে নারী স্ত্রী হিসেবে সমস্যা নিয়ে আলোচনার জন্য পুরুষের নির্ভরতা অর্জন করতে পারছেন না  সে নারীই একসময় মা হিসেবে সমস্যা নিয়ে আলোচনায় ছেলের কাছে গ্রহণযোগ্য হয়ে উঠছেন  তাই বিষয়টিকে সামান্য বলে এড়িয়ে যাওয়ার সুযোগ নেই
# পৃথিবীর সব চেয়ে সুখ কি জান  মা বাবার আদর আর সব চেয়ে অমুল্য রতন কি জান  মা বাবার ভালোবাসা
# বাংলাদেশের মানুষ আপনার কাছে চিরঋনি হয়ে থাকবে সব সময়  এই মানুষটাকে আমি একটু সময়ের জন্য ও বসতে দেখি নাই  সারাটা সময় ধরে ছেলেদেরকে সাহস দিয়ে গেছেন স্বার্থক তিনি
# তার মত একজনকেই হয়তো জাতীয় দলে খুব বেশি দরকার
#
# রুমে গ্রামের মানুষের ভীর জমে আছে মুরুব্বিরা বিভিন্ন দোয়া দরুদ পড়ছে সবার চোখেই পানি  সবাই তিন্নির এই অবস্থা দেখে অঝোরে কান্না শুরু করে দিলো
# পাকদের কে বাস দেয়েনা কে জেরকম আমাদের বাংলাদেশ দিয়ে ছিলো
# সরকার   সব মিথ্যা   বানোয়াট
# আমরা   প্রস্তুত
#  কোটি বাজেট করেছি
# সব চোরের দল
# সরকারের নির্দেশনানুযায়ী মাদকের বিরুদ্ধে যেমন  জিরো টলারেন্স  প্রদর্শন করা হচ্ছে  তেমনি নদী রক্ষার জন্য দখলকারীদের বিরুদ্ধেও  জিরো টলারেন্স  প্রদর্শন করা হবে বলে জানান তিনি
# সমাজের শিক্ষিত লোকেরা যদি এই ভাবে অপচয় করে তাহলে কাকে কি বলব
# গাঁজাখোর পরিচালক সিনেমার শুরুতে কি দেখালো এতো ফায়ার করছে তার পরেও কোন গুলিই লাগলো না জিতের এতো অবাস্তব করা কি দরকার
# জায়গাটা খুব ভয়ানক
# দেখতে দেখতে ভালবাসার এক বছর পূর্ণ হলো সবকিছুর জন্য আলহামদুলিল্লাহ
#  আমার এক ছেলে বড় হয়ে সিরিয়াল কিলার হতো  আরেকটা ড্রাগ অ্যাডিক্ট  আর মেয়ে হতো বেশ্যা    তোমাকে এই কথা কে বলেছে    শয়তান    শয়তান তোমাকে নিজে বলেছে    হু
# ধন্যবাদ মামা  আমার জন্য দোয়া করবেন
#   টাকা দিয়েই মুভি দেখবো  তাও আবার অঙ্কুশ শের মুভি হা হা হা লোলো ভাই সাহাব ঔ গেরার মুভি হা আর কোতো কি সুনবো ভোগোবন🥴🥴  কিরোণদা তুমি চিনতা কোরোনা আমরা তোমার সাথে আছি ♥️
# তার মাথা ঘুরতে থাকে  তার মনে হয় যে সে একটা ঘোরের মধ্যে রয়েছে  পকেট থেকে মোবাইলটা বের করে শিল্পাকে একটা কল দিবে এই শক্তিও তার নেই  সে মুখ দিয়ে যে  কোনো শব্দ করবে সেই শক্তিও তার নেই  তার মনে হয় কেউ একজন তার মুখ শক্ত করে ধরে রেখেছে
# তোর দুঃখে আমার সবসময় মজা লাগলেও এইবার খারাপ লাগতেছে  কালকে ইনশাআল্লাহ সব ঠিক হয়ে যাবে
# সৌভাগ্য এটা যে আমরা কোনরকম হট্টগোল ছাড়া শান্তিনিকেতনের শান্ত স্নিগ্ধ চেহারা মন ভরে উপভোগ করতে পারলাম
# অস্ট্রেলিয়ার চলমান ভয়াবহ দাবানল নিয়ন্ত্রণে ব্যর্থতার দায় স্বীকার করে দুঃখ প্রকাশ করেছেন প্রধানমন্ত্রী স্কট মরিসন আজ রোববার এবিসি টেলিভিশনকে দেওয়া এক সাক্ষাৎকারে নিজের দায় স্বীকার করে তিনি বলেন  এ ক্ষেত্রে আমার হয়তো আরও ভালোভাবে কিছু করার ছিল
# কানে না ধরায় খাবারের প্যাকেটটা হাতে দিয়ে বলতেন  যান চাচা  বাড়ি যান তাহলে বাহাদুরি হইতো  কানে ধরিয়ে বাহাদুরি নিচ্ছেন
#
# আজ বাতাসে সুবাসিত স্নিগ্ধতা  পাখিরা সারি সারি গাইছে গান  প্রকৃতি হেলে দুলে হয়েছে রঙিন  ফুলেরা সব ফুটেছে বাগানে  আজ আমার কাছের প্রিয় মানুষের জন্মদিন
# চিপায় বসে মিয়া গান করেন বাহিরে বের হন  গান গুলো আরো ভালো লাগবে  চিপায় বসে গান শোনলে কেমন যেনো দম বন্ধ বন্ধ লাগে
#  চারিদিক থেকে ভয়ের অনূভুতি গ্রাস করলো তাকে হাটার শক্তিও মনে হলো কেউ কমিয়ে দিয়েছে
# ভয় হচ্ছে কুসংস্কারের জনক  কুসংস্কারের সাথে জন্ম নেয় আরও ভয়
# মেয়েটা এত জোরে কান্না করছিল যে  মনে হচ্ছিল কেউ তাকে মারছে   আমি ঘুম থেকে উঠে এই মেয়েকে দেখে ভয় পেয়ে যাই
# মাননীয়া পুলিশ সুপার আপনাকে আবারো আমাদের চাঁদপুরে খুবই প্রয়োজন  কারন আপনে হচ্ছেন  নীতিবান পুলিশ অফিসার  আপনে দায়িত্ব কঠোরভাবে পালন করেন  স্যালুট জানাই ম্যাম
# ভালবাসা সব সময় সাথে আছে থেমে থাকবেন না দয়া করে  ভিডিও এর অপেক্ষায় থাকি
# যার স্বামী মারা গেছে তারই নাম বিধবা দুনিয়াতে তার আর আপন রইল কেবা বিধবা নারী বুক ভাসায় চোখের জলে
# আধা সরকারি বার্তা সংস্থা ফারসের খবরে বলা হয়  এক হাজারের বেশি শিক্ষার্থী দেশটির নেতাদের বিরুদ্ধে স্লোগান দিচ্ছিলেন  একই সঙ্গে সোলাইমানির ছবি ছিঁড়ে ফেলে  শিক্ষার্থীরা বিমানটিকে ভূপতিত করার সঙ্গে জড়িতদের এবং যারা নিজেদের দায়কে আড়াল করতে চেয়েছে তাদের সবার বিচার দাবি করেন
# মনে রাখবেন  পাপ তার বাপকেও ছাড়ে না  এই দেশটাকে  এই দেশের মানুষগুলোকে যারা শোষন করছেন  তারা কখনো সময়ের পরিনাম থেকে বাঁচতে পারবেন না
# ইনশাআল্লাহ টেষ্টে ও আমরা জিতব
# বোন করোনা ভাইরাস ধরেছে আজরাইল যখন আসবে তখন কি করবেন আল্লাহকে ভয় করুন আমিন
# ফাজিলের বাচ্চার হুগাই বাশ দিতে হবে
# ছো‌টো বেলায় শু‌নে‌ছিলাম   বাবা মার ভা‌লো সন্তান কখ‌নো পু‌লিশ হয়না   খারাপটায় হয়   কথাটা দেখ‌ছি   সত্যি
# আইইউসির এখন যা অবস্থা বন্ধ হয়ে গেলেও একজন সাবেক ছাত্র হিসাবে আমার কোন আপত্তি নাই  নস্ট সন্তানের কু কৃর্তী দেখার চেয়ে পিতার মৃত্যুই ভাল
# মাঠের মধ্যে আগ্রাসী আচরণ  প্রতিপক্ষ খেলোয়াড়কে উদ্দেশ করে খিস্তি খেউড় করার স্বভাব জেমস প্যাটিনসনের আজকের নয়  গত  মাসে এই কাজ আরও দুবার করেছেন  তাঁকে সতর্কও করা হয়েছিল  কিন্তু তাতে কী  আবার একই কাজ করলেন ভিক্টোরিয়ার এই পেসার
# এই  ছেলের  কি  কান্ড   বাপ  এর  চেয়ে    ডিগ্রী  বেশি  মেন্টাল  পেশেন্ট   থুক্কু  সায়েন্টিস্ট
# স্থগিত নয়  প্রত্যাহার এবং ডিসি অফিসের সাথে সংযুক্ত  তারা শাস্তি দিতে খুব মূল্যবান  কেবল চোখের জল
# ভাই আমরা আপনাকে  করি  আপনি সব সময় সত্যের সাথে থাকেন  আল্লাহ আপনাকে হেফাজত করুক
# হিটলার একজন অমুসলিম লক্ষ ইহুদি হত্যা করেছিলো  মিডিয়া একবারও তাকে বলেনি সে খৃষ্টান সন্ত্রাসী   জোসেফ স্ট্যালিন একজন অমুসলিম সে মিলিয়ন মানুষ হত্যা করেছে এবং মিলিয়ন মানুষ অসুস্থ হয়ে ধুঁকে ধুঁকে মারা গেছে   মিডিয়া একবারও তাকে বলেনি সে খৃষ্টান সন্ত্রাসী   মাও সে তুং একজন অমুসলিম থেকে মিলিয়ন মানুষ হত্যা করেছে  মিডিয়া একবারও তাকে বলেনি সে বৌদ্ধ সন্ত্রাসী   মুসলিনী ইটালী লাখ মানুষ হত্যা করেছে  সে কি মুসলিম ছিল  অন্ধ মিডিয়া একবারো বলে নাই খৃষ্টান সন্ত্রাসী   অ
# ভালোবাসার কষ্ট গান দিয়েই বোঝানো যায়
# আকাশের কষ্ট গুলো মেঘ হয়ে ভাসে  মেঘের কষ্ট গুলো বৃষ্টিহয়ে আসে  পাথরের কষ্ট গুলো ক্ষয়ে ক্ষয়ে পরে  আর মনের কষ্ট গুলো অশ্রু হয়ে ঝরে
# মেধার জোরে আসে নাই স‍্যার  সরকারের দালালি করে এখানে আসছে  তাদের চেয়ে যোগ্য লোক বাংলাদেশে অনেক আছে সরকারের দালালি করতে পারে নাই বলে তাদের চাকুরী হচ্ছে না
# আমি তোমার আর আমার ভেঙ্গে যাওয়া স্বপ্ন গুলো বুকের মাঝে পুষছি  আমি এখনো পারিনি তোমার মত ভুলে যেতে তোমার সাথে কাটানো কিছুটা সময় কিছু মুহূর্ত  পারিনি তুমি নামের সেই অতীতটাকে ভুলতে  জানি না কোন দিন পারবো কি না তোমায় ভুলতে
# যখনই ভয় পাচ্ছি চোখ বন্ধ করি কিন্তু ভয় যাচ্ছে না
#  হলরুমে একসঙ্গে  মানুষ ভয় পেয়ে চিৎকার করে উঠছে
# পরিবেশ দূষণকারী পলিথিন ব্যাগের ব্যবহার কমাতে দৈনিক এক লাখ পিস সোনালী ব্যাগ উৎপাদনের কার্যক্রম চালু করেছে বাংলাদেশ পাটকল কর্পোরেশন  বিজেএমসি   এতে অর্থায়ন করছে জলবায়ু পরিবর্তন ট্রাস্ট ফান্ড
# সে দোকান
# থেকে নেমে আমার পথেরদিকে তাকিয়ে
# আছে  ভয় পেয়েগেলাম প্রচ ন্ড ভয়
# ইচ্ছে হচ্ছিল ছুট লাগাই  কিন্তু কেনজানি
# দৌড়
# দিলাম না  জোরে জোরে পা চালাতে
# লাগলাম
# বাংলাদেশের তিন মাসে তিনবার পাকিস্তানে যাওয়ার পরিকল্পনা নিয়ে প্রশ্ন উঠেছে  সাবেক পাকিস্তানি তারকা শোয়েব আখতার অবশ্য বলছেন  বাংলাদেশের এভাবে পাকিস্তান সফরের পেছনে বাইরের কারও হাত আছে
# আপনার চাওয়াটা সহজ হলেও পাওয়াটা এর চেয়েও হাজার গুণ কঠিন
# লা লিগার সভাপতি হাভিয়ের তেবাস মে মাসে লিগ শুরু করতে পারবেন এমনটা আশা দেখছেন  যদিও বাস্তবতা হয়তো ভিন্ন  তবে যখনই শুরু হোক লিগ  বার্সেলোনার জার্সিতে তত দিনে মাঠে থাকবেন লুইস সুয়ারেজ
# আপনাদের সমস্যা কি
# আপনার এগুলো পোস্ট করে  তাকে ভাইরাল করেছে
# সে শেখ হাসিনা প্রিয় হওয়ার জন্য এগুলো বলে
# তোর মত কাউয়া কাক  যদি উপস্থাপনা করে তাহলে অনুষ্ঠানে যে কয়জন মানুষ আসবে সেই মানুষগুলোও পালাবে
# সুসার পতন ঘটল কোনোরকম বাধা ছাড়াই  সুসার বিশাল সম্পদের কারণে মুহূর্তের মধ্যেই আলেকজান্ডার তার সময়ের সবচেয়ে সম্পদশালী ব্যক্তিতে পরিণত হলেন
# এই বৃষ্টি ভেজা রাতে তুমি নেই বলে সময় আমার কাটে না চাঁদ কেনো আলো দেয় না পাখি কেনো গান গায় না তারা কেনো পথ দেখায় না তুমি কেনো কাছে আসো না
# ওরে ট্রাম্পরে দিয়ে চুদা দরকার
# রতন কাহার বেঁচে আছে না মরে গিয়েছে  কেউ কি জানেন  যে মানুষটা গান কে তার নিজের কন্যাসম মানতেন  গানের কথা সুর কাউকে নির্দ্বিধায় দিয়ে দিতেন  বদলে কেউ টাকা দিতে এলে বলতেন   আমি বিটি বিচে টাকা লুবো না   কেউ জানতেও চায় না আর সেই মানুষটার কথা
# টেস্ট অলরাউন্ডার র্যাংকিং এ উঠে আসতে হবে   শুভকামনা
# ভোরের প্রথম আলো যেমন সুন্দর  ভোরের হাওয়া যেমন স্নিগ্ধ  ভোরের পাখির ডাকযেমন মধুর  তেমনি সুন্দর হোক তোমার জীবন
# এত দিন দুপুরে ডাকাতি  এত পুকুর চুরির চেয়ে কম না  আবার চোরের মার বড় গলা  দোকানদার কে শাস্তি দেয়া হল না কেন   মোবাইল কোর্ট ঘুষ খায় নি তো ‌
#
# প্রানির মাধ্যমে এই রোগ ছড়ায়  মশা মাছির মাধ্যমে ও ছড়ায়  এসব ফালতু প‍্যচাল দিলে কানের নিচে থাপ্পড় দিমু
# সাকিবের ক্যাচটা ধরে দিলে ম্যাচ জিতে যেতাম
# রাজশাহীতে বড় ভাইয়ের লাঠির আঘাতে ছোট ভাইয়ের মৃত্যু হয়েছে  নিহত ব্যক্তির নাম আশরাফুল ইসলাম     এ ঘটনায় বড় ভাই নূর আলমকে    গ্রেপ্তার করেছে পুলিশ
# চীনে খরচ অনেক বাড়ছে  সেখানে একজন শ্রমিকের মজুরি  হাজার টাকা  বাংলাদেশে  হাজার টাকা  ফলে ভারত ও ভিয়েতনামের পাশাপাশি বাংলাদেশ মুঠোফোন তৈরির কেন্দ্র হতে পারে
# যাক  শেষমেশ এমন দিনও দেখা লাগলো যখন বৃহস্পতিবার সন্ধ্যায়ও আড্ডা দেওয়ার জন্য কাউকে পাওয়া যাবে না
# সরকার চট্টগ্রামকে গরুর মত দুধ দুয়ে দুয়ে খেয়েছে কিন্তু খাওয়াই নাই   বানিজ্যিক শহর হলে কি হবে  অনেক পিছিয়ে আছে
#  তাতে মনে হল আমার প্রায় পুরো জীবনটাই ভয় দিয়ে নিয়ন্ত্রিত হচ্ছে
# মুরলমানদেরকে বৌদ্বরা যেভাবে ধর্ষণ ও পুরিয়ে হত্যা করছে জারজ ওদেরকেও সেভাবে করা উচিত তাহলে ওরা বুঝতো ধর্ষণ আর পুরিয়ে হত্যা কি জিনিষ
# এটা সামগ্রিকভাবে চলমান এফটিপির বিশাল এক শূন্যতা  অন্য ভাষায় আইসিসির জন্য ব্যর্থতা  একটা উদীয়মান দেশকে পর্যাপ্ত ম্যাচ দিতে না পারাটা অবশ্যই আইসিসির ব্যর্থতা
# জ্যাকি চ্যানের যখন জন্ম হয় তখন তার বাবার আর্থিক অবস্থা  তিনি এতোই খারাপ ছিলো যে  তিনি চ্যানকে বিক্রি করে হসপিটালের টাকা পেইড করার সিদ্ধান্ত নেন
# একটি মহান কর্মসূচি দেখা গেল রাজশাহীর গোদাগাড়ীতে  সেখানে মুজিব বর্ষ উপলক্ষে একটি গ্রামের অর্ধশতাধিক বাসিন্দা বসতবাড়িতে কীটনাশক ও রাসায়নিক সারমুক্ত সবজি চাষ শুরু করেছেন  কালীদীঘি নামের গ্রামটি ইতিমধ্যেই  নিরাপদ সবজির গ্রাম  হিসেবে পরিচিত হয়ে উঠেছে
# চোখের পানিই হল সব থেকে মূল্যবান পানি   কারন কি জানেন   পৃথিবীতে অনেক রকমের পানি থাকলেও একমাত্র চোখের পানিই বুঝাতে পারে কাউকে হারানোর কষ্ট
# তোমার চোখের চেয়ে সুন্দর চোখ আমি জীবনে খুব বেশি দেখিনি দিদি ওইদিন গ্রিম রুমে অল্প সময়ের দেখায় বলার সুযোগ হয়নি
# মালু গো চুদা মুদির জারজ সন্তান তোর দিদিরে কিন্তু চুইদ্দা মাইরা পালামু খানকির পোলা
# বাজারের এই দশার জন্য অন্যতম দায়ী ব্যাংক খাতের দুরবস্থা  ক্রমবর্ধমান খেলাপি ঋণের কারণে ব্যাংক খাতে তারল্য–সংকট আছে  ব্যাংকের আর্থিক ভিত্তি নিয়েও মানুষ সন্দিহান  ফলে ব্যাংকের শেয়ারের পতন হয়েছে
# আমি একটা জিনিস বুঝি না বাংলাদেশ সরকারি বেসরকারি চ্যানেলের অভাব নেই  কিন্তু এইসব সংবাদ যদি গ্রেফতারের আগে প্রচারণা করা হয় নাই কেন  আর আমি আদালতকে বলবো পাপিয়ার বিরুদ্ধে এমন চার্জশিট তৈরি করা হোক যাতে করে জিবনেও কারাগার থেকে মুক্তি না পায়  ও মডেল হিসেবে থাকুক
# সাকিব ভারি সুন্দর লাগছে তোমাদের কে
# চোরের দেশে চোর তো জন্ম হবে ই
# ভারত পাকিস্তান অস্ত্রের প্রতিযোগিতা করছে  আর বাঙালিরা কথার নোংরা কথার প্রতিযোগিতা করছে
# বান্দরবানের লামা উপজেলায় পুকুরে ভাসমান অবস্থায় তিন বছর বয়সী একটি মৃত হস্তীশাবক পাওয়া গেছে উপজেলার ইয়াংছা এলাকায় আজ সোমবার সেলিম চৌধুরীর রাবার বাগানের পুকুরে মৃত হস্তীশাবকটি পাওয়া যায়
# রাত শুধু আধার নয়  একটু খানি আলো  রাত শুধু খারাপ নয়  স্বপ্ন গুলো ভালো
# আমি এই মুহূর্তে ভবিষ্যত সম্পর্কে খুব উদ্বেগ বোধ করছি কিভাবে আমি সামনের সময়গুলা কাটিয়ে উঠব কি হবে আমার ভবিষ্যৎ এইগুলা ভাবতেই গা চমচম করে
# কর্মীর সঙ্গে প্রেমের সম্পর্ক গড়ে তোলার কারণে ফাস্ট ফুডের বিশ্ব বিখ্যাত চেইন ম্যাকডোনাল্ডস তাদের প্রধান নির্বাহী কর্মকর্তাকে  সিইও  বরখাস্ত করেছে  এ ব্যাপারে মার্কিন এই ফাস্ট ফুড জায়ান্ট জানিয়েছে  সম্পর্কটি দুজনের সম্মতিতে হলেও সিইও স্টিভ ইস্টারব্রুক  প্রতিষ্ঠানের নীতি ভঙ্গ  করেছেন এবং  সিদ্ধান্ত গ্রহণে অদক্ষতার  পরিচয় দিয়েছেন
# বিকল্প নেই বলে বলে খেলানোর ধান্দা     সুযোগ দিল তো পারফর্ম করবে সুযোগ না দিয়ে চিলাচিল্লি করলে কেমনে   আর এখানে তামিমের সাথে সাকিবের নাম জুড়ে দেয়ার কোন অর্থ নেই    তামিম পারফর্ম করছে না
# এরকম অভিযোগে বুধবার রাত টা থেকে বিশ্ববিদ্যালয় ক্যাম্পাস উত্তাল হয়ে উঠেছিল  এসময় ক্ষুব্ধ শিক্ষার্থীদের বিরুদ্ধে ছাত্রকল্যাণ পরিচালকের কার্যালয়ের জানালা এবং নেমপ্লেট ভাঙা  বিশ্ববিদ্যালয়ের বিভিন্ন বিভাগের তালায় সুপার গ্লো লাগিয়ে দেওয়ার অভিযোগ উঠেছে
# এই গত কয়েক মাসে যেভাবে কিছু খবর  কিছু ভিডিও চোখের সামনে আসতেসে  যেটা ক্রমান্বয়ে খারাপতর হচ্ছে  তা দেখে ব্যথিত হইসি   হচ্ছি
# নয় বছর যে অামার বলে জানতাম হঠাৎ একদিন অন্য কারোর হয়ে গেল         অঙ্গ যায়  জ্বলিয়া
# সহজলভ্যতা অনেক বড় কিছুকে ছোট বানিয়ে ফেলে  অপূর্ণতা মানুষের অপ্রাপ্তির ক্ষুধা মনে হয় বাড়িয়ে দেয়
# ভাই ক্যাপশনটা তা অনেক সুন্দর হইছে
# কক্সবাজারের চকরিয়া উপজেলার মাতামুহুরী নদীতে প্রতিমা বিসর্জন দেখতে গিয়ে পানিতে ডুবে মারা গেছে এক স্কুলশিক্ষার্থী  মঙ্গলবার রাত পৌনে আটটার দিকে তাঁর লাশ উদ্ধার করেন ফায়ার সার্ভিসের কর্মীরা  লাশ উদ্ধার হওয়া ওই ছাত্রের নাম আওরঙ্গজেব বিশাল     সে চকরিয়া উপজেলার ফাঁসিয়াখালী ইউনিয়ন পরিষদের সাবেক সদস্য আলমগীর কবিরের ছেলে
# ভারতের গল্পটাও অন্যান্য দেশের মতো  টানা কয়েক বছরের দ্রুত প্রবৃদ্ধির পর দেশটির অর্থনীতি গতি হারিয়েছে  সে জন্য অর্থনীতিবিদদের শঙ্কা  ভারতের অবস্থাও মেক্সিকো ও ব্রাজিলের মতো হতে যাচ্ছে কি না
# এ গুলো কারো দলে না
# বোকাচোদা নামে বন্ধুমহলের কোনো একজনের নাম  করছিলাম কিন্তু কে এই বোকাচোদা তা মনে করতে পারি না
# বিরক্ত  লাগে       দিলে   তাড়াতাড়ি  দিবেন  না  দিলে   পোস্ট  করে  বলবেন  না
# সংবর্ধনা দিলেই সব সর্বনাশ হয়  আর খেলল ওরা আর ফুল পেল কে   কোন দরকার নেই সংবর্ধনার
# দেখার মত একটা ছবি আমার কাছে সেই ভাল লাগে  আমি প্রায় দেখি দারুণ একটা মুভি  এবং পছন্দের একজন নায়ক জিৎ
# তার আচার আচরণে স্পষ্ট যে সেও পাহাড়ি সন্ত্রাসীদের একজন  এজন্য তাকে  পাহাড়ি সন্ত্রাসী  বলতে আপত্তি নাই
# অতিদারিদ্র্যের হার এ বছর এক অঙ্কের ঘরে নেমে এসেছে  গত জুন মাস শেষে অতিদারিদ্র্যের হার  দশমিক  শতাংশ হয়েছে বলে জানিয়েছে পরিকল্পনা কমিশনের সাধারণ অর্থনীতি বিভাগ  জিইডি   গত  বছরে প্রায় এক কোটি লোক নিজেদের হতদরিদ্র অবস্থা কাটানোর যুদ্ধে জয়ী হয়েছেন
# আমি তখন কিছুই বলতে পারি নি কারণ আব্বু আমার কোনো কথাই বিশ্বাস করবে না আব্বু উনাদের সামনেই আমাকে অনেক গুলা থাপ্পড় দিলেন খুব কষ্ট হচ্ছিল তখন তারা যাওয়ার পরেও আমাকে অনেক মারধর করে
# কেমন যেনো বিরক্ত হয়ে গেছি  জীবন কি শুধু গৌরবের পেছনে রাত দিন ছুটা ছুটি
# একজন ক্রেতা আলু–আটার দাম নিয়ে দোকানিকে প্রশ্ন তুলেছেন  দোকানি অনেকটা বিরক্ত হয়ে বললেন   আপনার না পোষালে মাল রেখে যান  অন্য দোকান থেকে কিনুন
# আমাদের এলাকায় রাতে চুরি করা লাগে নাই  দিনে ভোট ডাকাতি করেছে
# উত্তর সিটিতে টি ও দক্ষিণ সিটিতে টি সাধারণ ওয়ার্ড রয়েছে  এখন পর্যন্ত দুই সিটির চারটি ওয়ার্ডে বিএনপি প্রার্থীদের ওপর হামলার অভিযোগ পাওয়া গেছে  এ ছাড়া উত্তরে অন্তত টি ও দক্ষিণে টি ওয়ার্ডে বিএনপি প্রার্থীদের পোস্টার ছেঁড়া ও প্রচারণার কাজে বাধা দেওয়া হয়েছে
# এরকম আরো একজন বাবা আছেন এখন আমার বাসায় তিনি সম্পর্কে আমার মামা শশুর হন  তার অনেকগুলো ছেলে মেয়ে ও আছে ভাগ্যের নির্মম পরিহাস এখন কেও উনাকে রাকতে চায় না  বাসা থেকে বের করে দাওয়া হয়েছে
# যে ব্যক্তি সবচাইতে ভয়ঙ্কর সিনেমা দেখছিল সে কয়েকবার ভয়ে লাফিয়ে ওঠে
# পার্বতীপুর উপজেলার মধ্যপাড়া পুলিশ ফাঁড়ির ইনচার্জ সিরাজুল ইসলাম বলেন  ছেলে সাবলুরের মোটরসাইকেলে চড়ে মোস্তাফিজুর চিকিৎসার জন্য রংপুরে যাচ্ছিলেন  পার্বতীপুর মধ্যপাড়া বাজারে পৌঁছালে বিপরীত দিক থেকে আসা একটি বাস তাঁদের মোটরসাইকেলে ধাক্কা দেয়  এতে ঘটনাস্থলেই বাবা মোস্তাফিজুরের মৃত্যু হয়  হাসপাতালে নেওয়ার পথে সাবলুর মারা যান
# আমি আমার বিয়ের প্রথম জীবনে আমার ডাক্তার স্বামীর কাছে সময়  টাকা তেমন কিছুই পাইনি  যখন অন্যরা আনন্দ করতে ব্যস্ত  তখন আমরা বেঁচে থাকার লড়াইয়ে ব্যস্ত ছিলাম
# মাঝে মাঝে তোমার উপরে খুব রাগ হয়  সে রাগ গুলো জমে অভিমান হয় যায়  আর আমার অভিমান যদি তুমি বুঝতে না পারো তখন আর আমার ভালো লাগে
# তাদের সাথে গেলাম গিয়ে দেখি লিমনের লাশ টা পড়ে আছে  তার লাশটা দেখতে গত রাতের ভয়নকর ভুতটার মতো ছিলো
# তাড়িয়ে দেবার আগেই ক্যাম্পাসকে আপন করে নাও  জীবন আর জীবিকার তাগিদে ক্যাম্পাস ছেড়ে চলে যাবার পরে ভুলে যাবার ভান করে থাকতে হয়না যেন
# খেলা নিয়ে এত এত গান  আসিফের  সাবাশ বাংলাদেশ গানটা কেউ আজঅব্দি টপকাইতে পারল না আমার কাছে ওটাই সেরা
# ম্যাচের আগে অশ্বিনকে আটকে রেখেছিল প্রতিপক্ষ দলের তিন চার সমর্থক  তাঁর আঙুল ফেলে দেওয়ার হুমকিও দেওয়া হয়েছিল
# এগিয়ে চলো মিরাজ ও সাকিব
# ভাইয়া আপনি আমার জানের জান প্রানের প্রান ক্রিকেটার
# সেপ্টেম্বরে যুক্তরাষ্ট্র দুবার পাকিস্তানকে হামলার বিষয়ে সতর্কও করে  শেষ পর্যন্ত ইন্দিরা গান্ধী হামলার পরিকল্পনা থেকে সরে দাঁড়ান
# ভাই চিত্রগল্প আপনার   জানতাম ই না  অথচ কত আগের ভালবাসা চিত্রগল্প
# জয় ভোদাবান দেবীচুদা নম নম
# আমি ফোন কেটে দিয়ে আবিদকে ফোন দিই  কাঁদতে কাঁদতে বলি   কালকের মধ্যে তুমি আমার বাড়িতে তোমার বাবা মা কে পাঠাবা  তোমার সাথে বিয়ে না হলে আমি বিষ খাবো
# ...
# বাস হচ্ছে ভয়ানক ঘাতক  আমাদের সবার উচিৎ বাস থেকে  গজ দূর দিয়ে চলাফেরা করা
# দাদীতো মাজার ব্যাথায় দুইদিন ধরে ঠিকমতো দাঁড়াতেই পারে না  নিঃশব্দে উঠলো কি করে  তাহলে  একটু আগে দাদী রূপে কে ছিল সাথে  হাত পা ভয়ে ঠান্ডা হয়ে আসে
# ঢাকা আন্তর্জাতিক বাণিজ্য মেলার  ডিআইটিএফ  সময় আরও দুই দিন বাড়ল  মেলা শেষ হবে  ফেব্রুয়ারি বৃহস্পতিবার
# বাংলাদেশ থেকে বলছি আপনার ভিডিও গুলো অনেক ভালো লাগে আপনি সোজাসুজি সব কিছু বলতে পারেন কোন লুকোচুরি নেই৷  সত্যি গুলো খুব ক্লিয়ারলি বলতে পারেন
#
#  যেদিন আমার বোনম্যারো ট্রান্সপ্লান্ট হয়  তার আগের রাতে আমি ঘুমাতে পারি নি  কালকে ট্রান্সপ্লান্ট চলাকালীন আমি ফট করে মরে যেতে পারি ভেবে এক ধরণের গা শিরশিরে অনুভুতি হচ্ছিল
#    আমি      বিষয়ে ট্রেনিং এর জন্য নির্বাচিত হয়েছি  এই ট্রেনিং বাংলাদেশে এই প্রথম এবং এতে নির্বাচিত প্রত্যেকের পেছনে সরকারের খরচ হবে এক লক্ষ দশ হাজার টাকা  বিদেশি এক এর মাধ্যমে নেয়া এ ট্রেনিং এ পরীক্ষার মাধ্যমে নির্বাচিত সেরা  জনকে এই মডিউলে প্রশিক্ষণের সুযোগ দেয়া হয়েছে
# না আছে শহীদদের প্রতি শ্রদ্ধা  না আছে নিজস্ব সংস্কৃতি    বিবেকহীন শিক্ষক  তথাকথিত অভিভাবক
# হায়রে বাঙ্গালি    এত শুন্দর একটা ভিডিও   তবুও কতগুলা মাদারচুদে ডিসলাইক দিছে
# এক্সপো অ্যাকসেসরিজের এই শস্যদানা থেকে তৈরি ব্যাগ পরিবেশবান্ধব  নির্দিষ্ট সময়ের পর তা মাটিতে মিশে যায় এবং দেখতেও পলিথিনের মতো  কিন্তু তা তৈরি হচ্ছে শস্যদানা দিয়ে  এর আগে পাট দিয়ে পলিথিন তৈরি করা হয়েছে
# কইও কইও কইও রে ভ্রমর  কৃষ্ণরে বুঝাইয়া মুই রাধা মইরা যাইম  কৃষ্ণ হারা হইয়া রে  ভ্রমর  🥀
# এখানে বল লাগলে ম্যন অব দা ফ্লপ হতে হবে
# এখন আমুলীগ প্রমান করবে ওটা মানুষ নয় এলিয়েন ছিল
# এমন অবস্থা আপনার মনে হচ্ছে হুইল চেয়ারে বসেও বল করার আশা রাখেন  যত্তসব ফালতু একটা জায়গা জুড়ে বসে আছে নির্লজ্জের মতো  ছিঃ
# সাবাস আল্লাহ আপনার সহায় হোক
# সবাই সাবধানে থাকলো  একদিন সকালে ঐ মহিলা চিৎকার আরম্ভ করলো  সবাই তো ভয়ে শেষ
# লক্ষ করে দেখেছি আমি যখন কোন কাজে ব্যাস্ত থাকি ঠিক তখনই হয় কলিংবেল নয় ত টেলিফোন বাঁজতে থাকে সেই শব্দে কিন্ত আর কাউকে ব্যাস্ত হতে দেখা যায় না
# জনের পরিবর্তে জন ভারতিও মালাউনকে ঘন্টার ভিতর হত্যা করা হোউক  আর আমি জানি পাকিস্তান তোমরা সেটা পারবে এবং করবে
# বাংলাদেশে ক্রিকেট টিমে চান্স পেতে হলে একজন ছেলেকে কি পরিমান খড়কুটো পোড়াতে হয় সেটা ওই ছেলেটাই জানে  ওই মানুষগুলোকে শুধু শুধু গালি দিয়েন না
# আল্লাহ তাকে বেহেস্ত নসিফ করুন আমিন
# উত্তর সিটিতে টি ও দক্ষিণ সিটিতে টি সাধারণ ওয়ার্ড রয়েছে  এখন পর্যন্ত দুই সিটির চারটি ওয়ার্ডে বিএনপি প্রার্থীদের ওপর হামলার অভিযোগ পাওয়া গেছে  এ ছাড়া উত্তরে অন্তত টি ও দক্ষিণে টি ওয়ার্ডে বিএনপি প্রার্থীদের পোস্টার ছেঁড়া ও প্রচারণার কাজে বাধা দেওয়া হয়েছে
# আগামীকাল এইচ এস সি পরীক্ষার রেজাল্ট দিবে  কে জানে কপালে কি আছে  ভয় হচ্ছে খুব
# যে সমস্ত বস্তা পচা সিনেমা করা হয় তাতে হল বন্ধ হওয়াই উচিত
# বস আমিও তোমাকে স্যালুট জানালাম
# এক বিয়ে খাইছে বাপরে    তোমাদেরকে বিয়েতে দাওয়াত দেয় কে
# দূর সালা মুড টাই পুরা খারাপ করে দিল  ভাবছিলাম এইবার হয়তো সত্য প্রকাশ হবে কিন্তু কই কি হল গুরে ফিরে আবারও সেই পুরান নাটক
# পাকিস্তানের পাঞ্জাব প্রদেশের ডেরা গাজি খান শহরের পরিত্যক্ত এলাকায় ঘেরা কম্পাউন্ডে দেশটি গোপনে পরমাণু অস্ত্র বানাচ্ছে বলে দাবি করেছে ভারতের গোয়েন্দারা সম্প্রতি উপগ্রহের পাঠানো ছবিও তারই প্রমাণ দিয়েছে বলে দাবি ভারতের  তথ্যসূত্র বলছে  গত  মাসে ডেরা গাজি এলাকার ওই বিশাল কম্পাউন্ড অনেকটাই প্রশস্ত হয়েছে
# আমি মনে করি আমার হাসব্যান্ড এইরকম রোমান্টিক হবে  আমাকে ওর মতো করেই ভালবাসবে সেই অপেক্ষায় আছি আমি জানি না কখন শেষ হবে আমার অপেক্ষা
#      এই ভিডিও সেরা ক্লিপ হিসাবে নির্বাচিত  আর মিউজিক টা পুরাই আগুন
# কিন্তু পঞ্চাশ পেরুনো মোসাম্মৎ আনোয়ারা বেগমের বড়ই অভিমান হয় কেন ভুলে গেলো মেয়েটা তার কথা  তিনি তো সবার কথা মনে রাখেন
# বালের ফালতু মিডিয়া     আর কিছু পায় নাই বাল গুলারা নিয়ে প্রোগাম করে এই সব বাল ছাল বাদ দিয়ে ভাল কিছু করেন যেটা করলে মানুষ একটু হলেও উপকৃত হয়
# আঞ্চলিকতা মানেই সংকীর্ণতা নয়  অনাধুনিকতা নয়  আঞ্চলিক ভাষার মাঝেই আছে আত্মপরিচয়  এই ভাষাতেই কথা বলেন আমাদের মায়েরা  তাই  কথা বলায় যে আঞ্চলিকতার টানই থাক না কেন  তা তো মায়েরই ভাষা  নিজের শেকড়ের ভাষা  আসুন আলিঙ্গন করি নিজের মায়ের ভাষাকে  জোর গলায় বলি মায়ের ভাষায় কথা বলতে লজ্জা কিসের  চলুন ফিরে যাই শেকড়ের আহ্বানে  মায়ের কাছে  মায়ের ভাষার কাছে  ভাষার মাসে এই হোক আমাদের অঙ্গীকার
# ওমানের ভিসা অলরেডি বন্ধ হয়ে গেছে
# আমার পচন্দের প্রিয় অনুষ্টানটি ইত্যাদি
# এটা বিদ্যানন্দ এক টাকার আহার গ্রুপ অনেক অনেক ধন্যবাদ জানাই দীর্ঘ জীবী হোক আপনাদের এই মহত্ত্ব
# কেউ যদি চলে যেতে চায় তবে তাকে কোন মতেই আটকানো যায় না
# বর্তমান সরকার বিভিন্ন কৌশলে বিএনপিকে পরাজিত করতে চায় উল্লেখ করে বিএনপি মহাসচিব মির্জা ফখরুল ইসলাম আলমগীর বলেছেন  ঐক্যবদ্ধ হতে পারলে ক্ষমতাসীনদের তাঁরা পরাজিত করতে পারবেন
# অসাধারণ বক্তব্য   মন জয় করে নিল বাংলার জনগনের   অনেক অনেক ধন্যবাদ আপনাকে
# হাই রাজশাহীর আপু অনেক কিউট লাগছে
# আমি পাগলের মতো হাটতে থাকি  কোথায় যাচ্ছি জানি না  এই গলি থেকে সেই গলি  প্রেতের মতো ঘুম আমার চোখ অন্ধ করে দিতে চায়  যেন হাটতে হাটতেই ঘুমিয়ে যাব  কোথায় যাচ্ছি জানি না
# এই বিশ্বকাপে মিস ফিল্ডিংয়ে বেশ কিছু রান হজম করেছে বাংলাদেশ  মিস ফিল্ডিংয়ে রান দেওয়াতে বাংলাদেশের চেয়ে এগিয়ে কেবল আফগানিস্তান  শেষ পর্যন্ত এই রানগুলোই বাংলাদেশের স্বপ্নের পথে বাধা হয়ে দাঁড়াবে
# এরকম পরিষ্কার ছবি দেখার মজাই আলাদা  এমন মুভি উপহার দেয়া জিৎ এর পক্ষেই সম্ভব
# কাপা হাতে দ্রুত দরজায় কড়া নাড়তে লাগলাম  আমার শরীরও কাপতে ছিল  পেছনে তাকাতে ভয় পাচ্ছিলাম  মনে হচ্ছিল কেউ একজন আমার পেছনে দাড়িয়ে আছে  জীবনে এমন অভিজ্ঞতা খখনো হয়নি আর  তাই বেশ অস্বস্তিতে ছিলাম
# আমি এটির একটি অন্যায় প্রতিক্রিয়া জানি কিন্তু আমি কীভাবে কাঁপছি তা বোধ করার উপায় ছাড়াই আমি এখনই সামনে আসতে পারিনি
# সৌদি থেকে আরিফ আপু তুমি আমার অনেক প্রিয়ো
# ও এসব জালিয়াতির টাকা নিবে না  ভালো মানুষ  তোর আমার মত ক্রিমিনাল নাকি
# বাংলাদেশ হারাচ্ছে তার সর্বকালের সেরা অধিনায়ককে সত্যি অনেক কষ্ট লাগতেছে প্রিয় ক্রিকেটার মাশরাফি বিন মুর্তজা বাংলাদেশে ক্রিকেট থেকে অবসর নেওয়াটা
# করো উন্নতি হউক বা না হউক মেডামের শরীরের ভালো উন্নতি হয়ছে
# আমার মনে হয় এরা স্বর্গে গেলেও পায়খানা করতে চাইবে যদিওবা এই ব্যবস্থা নাই   আমার ঘৃনা যে লিখসে তার জন্য   সিসি টিভি তে ফোটেজ থাকতে পারে
# বরাবরের মত সবাই কাঠের চশমা পরে নিছে  লাভ নাই ভাই কিছু করতে পারবেন না  ভুইলা যান  হলে গিয়ে ঘুম দেন
# আজকে তোরা চুপ থাকস কারণ এইগুলা তোদের স্পর্শ করে নাই  আজকে তোদের কিছু যায় আসে না কারণ তোদের ঘরে আগুন লাগে নাই  কিন্তু বেশি দিন লাগবে না টের পাবি  তোরাও টের পাবি
# তুমি এই দিনে পৃথিবীতে এসেছ   শুভেচ্ছা তোমায় তাই অনাগত ক্ষণ হোক আরো সুন্দর উচ্ছল দিন কামনায়  আজ জন্মদিন তোমার
# বলদের ঘরের বলদ  চাকরির ইন্টারভিউ দিতে গেলে লাথি মেরে বের করে দিবে  এসব আবালগিরি এপিসোড বানিয়ে বেটাগিরি দেখাইসনা  জেহেতু ভাল জায়গায় সেহেতু ভাল কাজে নিজের ব্রেন টাকে কাজে লাগা
# যে মানুষটার জন্য তোমার মনের ভেতর মায়া জন্মে গেছে  সেই মায়ার জাল ছিড়ে বেড়িয়ে আসা খুব কঠিন
# সেদিন পরিক্ষা হওয়ার কারণে আমাদের মধ্যে অনেকেই পরিক্ষায় অংশগ্রহণ করে এবং আমাদের মতো অনেকেই এই জিনিসটা নিতে না পেরে আবার আমাদেরই মধ্যে কয়েকজনের সাথে খুব ন্যাক্কারজনক ব্যবহার করি
# সত্যিকারের পুরুষ হয়ে ওঠার জন্য সমাজ যে মিথ তৈরি করে রেখেছে  সেখানে পুরুষের আবেগের প্রকাশ বড্ড বেমানান  পুরুষ নারীর সামনে সমস্যা নয়  বরং সমস্যা সমাধানের নায়ক হিসেবে নিজেকে উপস্থাপন করতেই ভালোবাসেন
# আধা স্বায়ত্তশাসিত শহরটির ওপর চীনা শাসনের বিরোধিতা করে জনগণ বিক্ষোভে ফেটে পড়েছে  প্রায় চার মাস ধরে চলমান আন্দোলন শেষ হওয়ার কোনো লক্ষণ দেখা যাচ্ছে না  পুলিশের ছোড়া কাঁদানে গ্যাস এবং প্রজেক্টাইল থেকে বাঁচতে বিক্ষোভকারীরা হলুদ হেলমেট  কালো বা রঙিন চশমা এবং কৃত্রিম শ্বাসপ্রশ্বাসের ব্যবস্থাসম্পন্ন মুখোশ পরছেন  তাঁদের যেন শনাক্ত করা না যায়  এ জন্য তাঁরা ফেস মাস্ক বা মুখোশ ব্যবহার করছেন
# আমার সামি বিদেশে থাকে আমি তাকে খুব ভালবাসি তার কাছে সুধু চাই সময় ও খুব বিরক্ত হয় আমার উপর
# প্রায়ই দেখা যাচ্ছে মায়ের হাতে সন্তান খুন  স্ত্রীর হাতে স্বামী খুন  প্রেমিকের সাথে পালিয়ে গেছে নবজাতকের মা  কিংবা  মায়ের আত্মহত্যা  আমরা তখন কী করি  কথা ছাড়া মেয়ের দোষ দিয়ে হাত ধুয়ে ফেলি
# অথচ ওই মানুষ টা নাই আমার  কেউ আমারে মেনশন দিয়া কয়না ওইদিন একটু তারাতাড়ি অফিস ম্যানেজ কইরা বের হইবা  বকুল তলায় বইয়া কোলে মাথা রাইখা গান শুনতাম
# সবাই এতো সুন্দর সুন্দর কমেন্ট করেছেন  আমি কি বলবো বুঝতে পারছি না  শুধু এইটুকু বলবো সুরজিৎ দার সব গানের মধ্যে এটা একটা অদ্ভুত সুন্দর গান
# খালের ওপাড়েই শ্মশান  সেদিকে তাকাতেই কেমন গা ছমছমে অনুভূতিতে আপ্লুত হলাম
# সামনে এখন আরেকটা বাড়ি  রক্তাক্ত ধারালো ছুড়িটা নিয়ে এগিয়ে যাচ্ছে সেদিকে  হাসিমুখে  নতুন শিকারের খোঁজে
# এত কস্ট পেলাম  বুক টা ভেঙে যাচ্ছে  আহারে সন্তান কত কষ্ট করেই না ওদের কে মানুষ করলো
# আওয়ামী লীগ ও বিএনপির চার মেয়র পদপ্রার্থী প্রতিদিনই নির্বাচনী প্রচারে নামছেন কয়েক শ কর্মী–সমর্থক নিয়ে  আনুষ্ঠানিক পথসভা না করলেও তাঁরা মিছিল স্লোগানে মাতিয়ে রাখছেন  প্রার্থীরা যেখানেই যাচ্ছেন  সেখানেই সড়কে চলাচলে বিঘ্ন ঘটছে
# দুঃখ না হয় তুমি পেলে সীমাহীন  তবুও তুমি ভালবেসো আমায়
# আমি শিউরে উঠি
# কেননা  জমাট রক্ত তাড়া করে আমায়
# চাইতে দেখি এই এর বেশি  জাদু করছ আমারে একটু বল
# দক্ষিণ আফ্রিকার কেপটাউনে পানি নেই  ভারতের অনেক শহরেও পানির তীব্র অভাব  আমরাও ঠিক এই পরিণতির দিকে এগিয়ে যাচ্ছি  পানি থাকবে না  ছায়া থাকবে না  সবুজ থাকবে না
# প্রায়  মিনিট পর আমি আমার উপস্থিতিকে এক বিশাল খোলা নদীর তীরে আবিষ্কার করলাম  শো শো করে প্রচুর বাতাস বইছে সাথে উড়ে আসছে বালি এবার কিছুটা ভয় পেয়ে গেছি
# বুধবার সকালে আমি বাবার সঙ্গে দেখা করতে থানায় আসি কিন্তু আমাকে দেখা করতে না দিয়ে ওসি আবুল বাশার ও পরিদর্শক  তদন্ত  মনোরঞ্জন মিস্ত্রি গালাগাল করে তাড়িয়ে দেয়  সারা দিনে আমাকে বাবার সঙ্গে দেখা করতে দেয়নি  ওসি বলেন টাকা নিয়ে আস তারপর দেখা করতে দেব
# কেন যে মানুষ এই রায়হানের জন্য এতো পাগল বুঝলাম না
# বাবা খায়া লাইভে আইসা পাগলের মতো নাচে  অশ্লীল অঙ্গভঙ্গি করে এগুলাই নাকি মানুষ পছন্দ করে ভাইরাল করে
# কতোটা বিকৃত রুচির হয়ে যাচ্ছি আমরা দিন দিন
# আমি এসএসসি তে   পাইনি   পাইছি আম্মু বকা দেয়নি একটু  শান্তনা দিছে সামনে এক্সামে ভালো করবি সত্যি মায়ের উৎসাহ পেয়ে এইচএসসি তে   পেয়েছি
# আসল কথা হচ্ছে  এরা বুঝতেই পারছে না ভাইরাস টা কি জিনিস  আর আমার মনে হয় এদেরকে কেউ বোঝাতেও পারবে না পুলিশের ডান্ডা ছাড়া
# কোথাও কোনও জন মনিষ্যি নেই কোথাও একটা ডাহুক ডেকে উঠলো  দাদুর গা টা একটু ছমছম করে উঠলো
#  মার্চ ভারতীয় সিনেমা  ডিকশনারি র শুটিং শুরু করবেন এই অভিনয়শিল্পী  এমনটাই নিশ্চিত করেছেন মোশাররফ করিমের স্ত্রী রোবেনা রেজা জুঁই
# কি সুন্দর পানি নামছে উপর থেকে  প্রথম দুইটা একটু ছোট ছোট ঝর্ণা  কিন্তু পরের দুইটা একটু বড়  অনেক উপর থেকে পানি পড়ছে  দেখতে কি ভালো লাগে
# সবচেয়ে বড় মুনাফিক সে বলেছিল সৌদিয়া নতুন ইউরোপ জুয়া এখন বৈধ বোরকা ছাড়া নারী চলাফেরা বৈধ
#
# বি এন পি কে মারার দিকে এগিয়ে যাচ্ছে দেশ
# কিরে বৃষ্টি নিয়া তোমাগো স্টেটাস টিকটক গান নাচ হাগা মুতা কই
# ঘুম থেকে উঠে এভাবে হতাশ হয়ে যাবো ভাবিনাই
# ভয়ের  সময় কিছু হয় আমার  যার মধ্যে গলা শুকিয়ে যাওয়া অন্যতম
# এই ছাগলের বাচ্চাগুলো যেনো ধর্ম নিয়ে কোনো কথা না বলে
# ভয়ে শরীরের পশমগুলো দাঁড়িয়ে গেছে  এবার আমি স্পষ্ট শুনতে পেয়েছি  অনেকটা বাতাসে ভর করে যেনও আসছিলো কথাগুলো   মিম    মিম
# আজকে  টেম্পু  তে  এক  মাদারচোদ  আমার  সামনে  আমার  দিকে কাঁশতেছিলো   মনে  হচ্ছিলো  মারি  দি  ইতারে
# পুলিশটা সেই লাশটাকে কোলের উপর রেখে কামরিয়ে কামরিয়ে খাচ্ছে পুলিশটার মুখে লাল টকটকে রক্ত লেগে আছে সে তখনি রিকসা টা থামিয়ে জোরে একটা দৌড় দিল এবং কিছুদূর গিয়ে অজ্ঞান হয়ে পড়লো
# শালার শোক প্রকাশ করার লোকের অভাব হয় না কিন্তু জীবন্ত মানুষ বাঁচার জন্য পাগল হয়ে গেলেও কানে সবাই  যারা কিছু করার ক্ষমতা রাখে  তুলা দিয়ে রাখে
#
# বাংলাদেশের এম্পি মুন্ত্রিদের কথা শুনে  করনো ভাইরাস মনে হয় নিজেই কনফিউজড   নিজেদের মধ্যে বলাবলি করতেছে এ কোন বাইঞ্চুদ্দের দেশে আসলাম রে বাবা   কোনো দামই দিচ্ছে না বাল
# শুভ অষ্টমী পূজার শুভেচ্ছা বিদ্যা মেডাম ও সবাইকে
# ভাইরে এক্কেবারে ফাটাইয়া দিছেন
# এই ওয়েদারে হালকা বৃষ্টির সাথে ইন্ডিয়ার টপাটপ উইকেট বৃষ্টি  মন ভাল হইতে কিইবা লাগে আর
#  তিন বছর রিলেশনশিপে কখনো দ্বীপ এমন অশ্লীল ভাষায় কথা বলেনি আর কিস করতে হলেও অনুমতি নিয়েই করতো সেটাও ফোন থেকে
# তৃতীয় সন্তান জন্মের পর থেকেই তাঁর মানসিক ভারসাম্য নষ্ট হয়ে যেতে থাকে  নিজের সন্তানদের যাতে ক্ষতি না করতে পারেন  সেজন্য তিনি আত্মহত্যা করতে চাইলেন দুইবার   দুইবারই তিনি ব্যর্থ হলেন
# ইয়াসির আজমান আরও বলেন  তাঁদের দিনে প্রায়  হাজার নতুন সিম দরকার  হাতে থাকা সিম ফুরিয়ে যাওয়ার পর প্রায় চার লাখ খুচরা বিক্রেতার কাছে থাকা সিম বিক্রি হবে  সিমের দাম বেড়ে যেতে পারে  সব মিলিয়ে একটা খারাপ পরিস্থিতি আসছে
# তাতে আপনার এত মাথা বেথা ক্যান   ও পারে বলেই এইসব করে আর আপনারা পারেননা তাই কুতস্যা রটাইতে জানেন  এইটা তার ক্রেডিট    আর খাইয়া কাজ নাই তাই মানুষের নামে বাজে নিউজ ছাপাইতে চান যত্তসব ফালতু
# দাদাভালো জবাব দিয়েছোঠান্ডা মাথায় এমন জবাব দেবার দরকার ছিল      বাঁদর নাচের উত্তরটা সেরা ছিল
# আগামী একটা প্রজন্ম হয়তো এ কারণে হীনমন্যতায় ভুগবে যে   জীবদ্দশায় তাদের বাপ দাদারা বইমেলা পেয়েও কয়েকটা বই প্রকাশ করতে পারেনি
# অরুন্ধতী রায় মনে করেন  এনপিআর এনআরসি সিএএ নামের আইনগুলোর মূল লক্ষ্য হচ্ছে সাধারণ জনগণকে বিভক্ত করা ও তাদের মধ্যে অস্থিতিশীলতা ছড়িয়ে দেওয়া
# তাতে আমরা ধন্য হয়ে গেছি  নায়ক নায়িকারা পাদ মারলেও নিউজ করতে হবে  ভোদাই এডমিন আমার
# আমি অনেকগুলা জিনিস প্রসেস করতে পারতেসিনা  এর মধ্যে একটা হচ্ছে সাউথ  নম্বর রুমটাতে আর তাহমিদকে দেখা যাবে না  তাহমিদকে আর দেখা যাবে না  আমি এই ব্যাপারটাই প্রসেস করতে পারতেসি না  নিজের রুমের চাইতে বেশি সময় এই রুমটাতে থাকা হইত  ঐ রুমে আর কিভাবে যাব
# মাশরাফির জারজগুলা এতো মূর্খ ক্যান    চটি পেজের নিউজ নিয়া লাফায়
# গান টা অতিব ভালো  তবে যে গান টা গেয়েছে তাকে বলি একেবার যা বিচ্ছিরি গানের গলা তেমনই বিচ্ছিরি গান টা গেয়েছে  হেঁড়ে গলা
# মুরলমানদেরকে বৌদ্বরা যেভাবে ধর্ষণ ও পুরিয়ে হত্যা করছে জারজ ওদেরকেও সেভাবে করা উচিত তাহলে ওরা বুঝতো ধর্ষণ আর পুরিয়ে হত্যা কি জিনিষ
# আওয়ামী লীগ সরকারের টানা  বছর অর্থমন্ত্রীর দায়িত্ব পালন করেছেন আবুল মাল আবদুল মুহিত  জাতীয় সংসদে টি বাজেট উপস্থাপন করেছেন তিনি  শেয়ারবাজার  বেসিক ব্যাংক  একাধিক আর্থিক কেলেঙ্কারিসহ নানা বিষয়ে সমালোচনাও ছিল তাঁর আমলে
# হঠাৎ মনে হলো ভয় তাড়া করছে আমাকে  হাঁটছি তো হাঁটছি
#
# মুখটা যেনও কেউ এসিডদিয়ে ঝলসে দিয়েছে   ওটা দেখে নুরু ভাই ভয়ে কাপাকাপি শুরু করে দিল
# এরকম সন্তান থাকার চেয়ে বন্ধ্যা থাকা অনেক ভালো কি দরকার এমন ছেলে রেখে যে মা বাবার খবর নেই না
# তুমি আমি কেন দূরে দূরে  খুজে বেড়াই ঘুরে ঘুরে  মন কি যে চায়  কাটে শুধু বেদনায়
# আজকের জামানায় যদি আবু জাহেল বেঁচে থাকত তাহলে তোর কাছে হার মেনে যেত সেই সাথে তোকে লিডার মেনে নিত
# সুফিয়া আপুর একটা ফুটফুটে পুত্র সন্তার হয়েছে  মা ও ছেলে সুস্থ আছে  যারা রক্ত দিয়েছে এবং দিতে চেয়েছে তাদের অনেক ধন্যবাদ  আল্লাহ তাদেরও এমন ফুটফুটে বাচ্চা দিক
# স্যার অসম্ভব দামি কিছু কথা
# সচরাচর কেউ বলে না তাই আপনাকে হৃদয়ের অন্তস্থ থেকে সাধুবাদ
# সালা    টে রিমেক বই করে  আললু অরজুনের সাথে তুলোনা  করছে সোন   আললু অরজুনের বালের  যগো নোশ তোর বালের  বই    টাকা দিয়ে দেখার  চে    আর পানু দেখা অনেক ভালো
# যে কোন এক্সপেরিয়েন্স হলেই খুশী হবি  ভাববি জ্ঞানের পাল্লা ভারী হচ্ছে
# আনিসুল হক স্যারের অভাব পূরন হবার নয়
# প্রিতমের সাথে তোমার এতো ঘেষাঘেষি কিসের
#
# বাংলাদেশ যেভাবে উন্নয়ন হচ্ছে শেখ হাসিনাকে আরো দশ বছর থাকা উচিত
# খেলা নিয়ে এত এত গান  আসিফের  সাবাশ বাংলাদেশ গানটা কেউ আজঅব্দি টপকাইতে পারল না আমার কাছে ওটাই সেরা
# দক্ষিণখানে দুই শিশুসহ মা খুন  লাশ উদ্ধারের পর থেকে শিশুদের বাবা নিখোঁজ  পুলিশের সন্দেহ  ডায়েরির লেখা তাঁর হতে পারে  খুনের ঘটনায় তিনি জড়িত
# আপনাদের গালিই প্রমাণ করে আমিই রাইট
# যারা মরে যায় তারা সব কিছুর পাট চুকিয়ে চলে যায়  আমরা যারা থেকে যাই শরীর ও স্মৃতির অসহায়ত্ব নিয়ে  দীর্ঘশ্বাস ও না বলা কথার যন্ত্রণা নিয়ে  তারাও এক রকম মরি  আমাদের পাট চুকে না
# আমি প্রচন্ড ভয় পেলাম  হাত পা কাঁপতে শুরু করলো আমার  আমি কোনোমতে মোবাইলটা বের করে ফেসবুকে ঢুকলাম  দেখলাম তামান্না এক্টিভ
# আপনের কুতু কুতু প্রেমের গুললি মারেন  মজা পাইলাম  সব রাইখা গুল্লি মারেন  খাস বাংলা
# অতিদারিদ্র্যের হার এ বছর এক অঙ্কের ঘরে নেমে এসেছে  গত জুন মাস শেষে অতিদারিদ্র্যের হার  দশমিক  শতাংশ হয়েছে বলে জানিয়েছে পরিকল্পনা কমিশনের সাধারণ অর্থনীতি বিভাগ  জিইডি   গত  বছরে প্রায় এক কোটি লোক নিজেদের হতদরিদ্র অবস্থা কাটানোর যুদ্ধে জয়ী হয়েছেন
# বান্দরবানের লামায় বন্যহাতির পায়ে পিষ্ট হয়ে নুরুল ইসলাম    নামে এক শ্রমিকের মৃত্যু হয়েছে  বৃহস্পতিবার সন্ধ্যায় লামা উপজেলার ফাসিয়াখালী ইউনিয়নের বড় ছনখোলা এলাকায় এ ঘটনা ঘটে
# এক ভদ্রমহিলা মুখ বাঁকিয়ে বললো চেহারা দেখেই বুঝা যায় বদমাইশ টাইপ  এইসব কুলাঙ্গারদের জন্য মেয়েদের রাস্তাঘাটে চলাচলই এখন দায় হয়ে পড়েছে
# ফুল গুলি সব ঝরে গেছে বাগান আজ শুন্য  তোমার কথা মনে হলে লাগে যে বিষন্ন  হঠাৎ করে হারিয়ে গেলে অজনা এক দেশে  কেমন করে চলে গেলে হাওয়ার সাথে মিশে
# এই লাশটার চোখ বন্ধ করা  লাশটার শরীর যেন অনেকটা পঁচে গেছে  লাশটা থেকে তিব্র পঁচা গন্ধ ভেসে আসছে  লাশটাকে চিনতে রহিমের অসুবিধে হয়নি  এটা সেই মাঝির লাশ যে মাঝি এতক্ষণ ধরে নৌকা চালাচ্ছিল  নৌকায় এখন রহিম শুধু একা  নৌকার বৈঠা কেউ বাইছে না  তবুও নৌকা ভেসে চলেছে
# এমন একটা সুখের ঘর যদি প্রতিটি নারীর জীবনে আশে তহলে তদের জীবনটা ধন্য
# এই  পার্লার  এর  মহিলা  গুলা  নং   ডাকাত  কারণ  এরা  সব  সেবার  এতো   প্রাইস  রাখে  তা  বলার  মতো  না  উচিত  হয় নি   এই  মহিলাকে  রোডে  এই  ভাবে  অপমান  করা
# আজ ও মেয়েরা সস্তা মাল
# গুরুতর পরিস্থিতিতে ভয় পাবেন এটাই স্বাভাবিক  কিন্তু যদি অহেতুক ভয়ভীতি পেয়ে যাই
# সব শ্রেণি ও পেশার মানুষ সরকারের শুদ্ধি অভিযানকে স্বাগত জানিয়েছে  আওয়ামী লীগের যেসব পোড় খাওয়া নেতা অনুপ্রবেশকারী ও সুযোগসন্ধানীদের কনুইয়ের গুঁতোয় টিকতে পারছিলেন না  তাঁরাও মনেপ্রাণে চাইছিলেন এ রকম একটি অভিযান চলুক
# সরকারের বিবিন বাহিমনিই এক মাএ ভরসা
# আমি ছিড়ে ফেলেছি ডায়রীর পাতা  যেখানে লিখা ছিলো হাজারো স্বপ্নের কথা   শুধু ছিড়তে পারিনি আমার মনের পাতা  যেখানে জমা আছে অনেক ব্যাথা

# %%
print(training_data2)
print("\n split\n")
print(training_data2)
# Out:
#                                                    text reaction  label  \
# 0     মামা ভয়ে ভয়ে লুকিং গ্লাসের কাপড় সরিয়ে দিয়...     fear      4
# 1     এই বয়সে নাতি নাতনিদের সঙ্গে আনন্দে মেতে থাকার ...  disgust      3
# 2                         আপু আপনাকে খুব সুন্দর লাগছে      happy      0
# 3     তোমার শহরের কোণে কেউ মায়া জমায় কি  আমি এখনো ভা...      sad      1
# 4     এর মাথা পুরোটাই নষ্ট  পশ্চিম বঙ্গবাসী একে ভোট ...    angry      2
# ...                                                 ...      ...    ...
# 3715  আমি কষ্টের স্মৃতি নিয়ে করি বসবাস আমায় নিয়ে কখন...      sad      1
# 3716  আজ থেকে অফিসে এবং বাসায় প্রথম আলো পত্রিকা  বাদ...    angry      2
# 3717  এই নোয়াখাইল্লা বাইনচুদেরে বেধে লেংটা করে রোদে ...    angry      2
# 3718  হিরু আলম জায়েদ খান  ওরা ও  নায়েক আর নোবেল ও এক...  disgust      3
# 3719  সত্যি সাকিব ভাই আজ আপনি আবার প্রমান করলেন কেন ...    happy      0
#
#       num_of_words
# 0               16
# 1               15
# 2                5
# 3               15
# 4               12
# ...            ...
# 3715            22
# 3716            31
# 3717            18
# 3718            14
# 3719            13
#
# [3720 rows x 4 columns]
#
#  split
#
#                                                    text reaction  label  \
# 0     মামা ভয়ে ভয়ে লুকিং গ্লাসের কাপড় সরিয়ে দিয়...     fear      4
# 1     এই বয়সে নাতি নাতনিদের সঙ্গে আনন্দে মেতে থাকার ...  disgust      3
# 2                         আপু আপনাকে খুব সুন্দর লাগছে      happy      0
# 3     তোমার শহরের কোণে কেউ মায়া জমায় কি  আমি এখনো ভা...      sad      1
# 4     এর মাথা পুরোটাই নষ্ট  পশ্চিম বঙ্গবাসী একে ভোট ...    angry      2
# ...                                                 ...      ...    ...
# 3715  আমি কষ্টের স্মৃতি নিয়ে করি বসবাস আমায় নিয়ে কখন...      sad      1
# 3716  আজ থেকে অফিসে এবং বাসায় প্রথম আলো পত্রিকা  বাদ...    angry      2
# 3717  এই নোয়াখাইল্লা বাইনচুদেরে বেধে লেংটা করে রোদে ...    angry      2
# 3718  হিরু আলম জায়েদ খান  ওরা ও  নায়েক আর নোবেল ও এক...  disgust      3
# 3719  সত্যি সাকিব ভাই আজ আপনি আবার প্রমান করলেন কেন ...    happy      0
#
#       num_of_words
# 0               16
# 1               15
# 2                5
# 3               15
# 4               12
# ...            ...
# 3715            22
# 3716            31
# 3717            18
# 3718            14
# 3719            13
#
# [3720 rows x 4 columns]

# %%
print(f"training dataset 2 = \n{training_data2['reaction'].value_counts()}")
print(f"testing dataset 2 = \n{testing_data2['reaction'].value_counts()}")
# Out:
# training dataset 2 =
# happy      883
# sad        810
# disgust    799
# angry      629
# fear       599
# Name: reaction, dtype: int64
# testing dataset 2 =
# happy      311
# disgust    289
# sad        275
# angry      208
# fear       182
# Name: reaction, dtype: int64

# %% [markdown]
# **debug**

# %%
# debug
max_text_len = training_data1["num_of_words"].max()
print(max_text_len)
x = training_data1["text"]
y = 0
for i in x:
    if i == "":
        y+=1
print(y)
print(x)
# Out:
# 522
# 0
# 0       অপরাদি যে হোক যে কোন বয়সের হোক না কেন বিচারের ...
# 1       হাইরে মূর্খ বাঙালি ডিজিটাল শব্দের অর্থ না বুঝি...
# 2                  নিশ্চিন্তে ভেঙে যাও কেউ বলার নেই......
# 3                           কেয়ামতের মাঠে তোমাদের ছাড়া নট
# 4       জনাব ইউসুফ এর মত কেউ অসহায় মানুষদের পাশে থাকলে...
#                               ...
# 3091                                              ধন্যবাদ
# 3092    এগুলো মানব রচিত  বেদায়াত । ১লা বৈশাখ থেকে মুসল...
# 3093    আপনি সঠিক ও সৎ পথে রয়েছেন বিজয় সব সময় সততার হয়...
# 3094                                   স্যালুট ইউ স্যার "
# 3095                                                 রাইট
# Name: text, Length: 3096, dtype: object

# %% [markdown]
# **spliting ds1**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(training_data1["text"].tolist(),\
                                                   training_data1["label"].tolist(),\
                                                   test_size = 0.2,\
                                                   stratify = training_data1["label"].tolist(),\
                                                   random_state = 0)
print(f"Xtrain = {len(X_train)}")
print(f"Xtest = {len(X_test)}")
print(f"Ytrain = {len(Y_train)}")
print(f"Ytest = {len(Y_test)}")

train_set = list(zip(Y_train,X_train))
test_set = list(zip(Y_test,X_test))
# Out:
# Xtrain = 2476
# Xtest = 620
# Ytrain = 2476
# Ytest = 620

# %% [markdown]
# Torch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(torch.cuda.is_available())
# Out:
# True

# %%
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator

tokenizer = get_tokenizer('basic_english')
def yield_tokens(train_set):
    for _, text in train_Set:
        yield tokenizer(text)

vocab = build_vocab_from_iterator(yield_tokens(train_set), specials=[""])
vocab.set_default_index(vocab[""])
print(len(vocab.get_stoi()))
print(vocab.get_stoi())
# Out:
# 11031
# {'উপাসক': 2632, 'আন্দোলন': 477, 'কি': 7, 'রেকর্ড': 2246, 'শুনবো': 10094, '': 0, 'হত্যাকান্ডের': 2319, 'পেলো': 8044, 'উচিত': 162, 'তবে': 119, 'লোল': 3684, 'উচিততবে': 4940, 'মধ্য': 3502, 'তৌরি': 3010, 'তুই': 140, 'পরেননি': 7775, 'টার': 2952, '।': 36, 'বোঝা': 1066, 'উচিত।': 1397, 'বৃথা': 8814, 'ভাল': 30, 'তাও': 1985, 'বাধ্য।': 8570, 'bin': 4022, 'করে': 6, 'ইয়তো': 4916, 'লুটে': 3674, 'গুনা': 2830, 'বেশকিছু': 8857, 'জন্য': 12, 'আনুক': 4645, 'পথে': 498, 'ভুতে': 9123, 'great': 4089, 'ওর': 645, '?': 1, 'বাতিল': 465, 'রোড': 9831, 'গান': 1464, 'পাল্টে': 7920, 'র': 290, 'এটা': 50, 'এমনভাবে': 5166, 'সাফল্য': 3778, 'হয়নি': 476, 'চাচ্ছেন।': 6209, 'ফিল': 8295, 'দল': 322, 'হয়েই': 2332, 'থেকে': 37, 'পেরেছি': 8036, 'লাকি': 3665, 'দিছে': 2011, 'যেততাহলে': 9655, 'মাধ্যম': 9294, 'ইংলিশ': 1810, 'পয়সা': 3297, 'সব': 31, 'দালালদের': 3042, '.': 2, 'অন্যায়কারীদের': 4364, 'কলেজসহ': 5498, 'দরা': 3033, 'মুফতী': 1079, 'ফিরা': 1581, 'সত্যি': 437, 'তোলার': 6903, 'সমস্ত': 1104, '!': 3, 'লাগবে': 943, 'জিডি': 6566, 'মামলা': 928, 'দরত': 6963, 'দুষ্ট': 3062, 'ভিজিট': 2185, 'আকড়ে': 4559, 'arabia': 1737, 'এই': 5, 'পাঠার': 7837, 'তার': 47, 'না': 4, 'মুসলিমবৌদ্দখৃষ্টান': 9449, 'নাস্তিকতার': 7472, 'হওয়ার': 408, 'এতটা': 5137, 'আপনার': 9, 'অকাজের/কূকাজের': 4282, 'কাজই': 1440, 'আর': 8, 'আরো': 131, 'পশুপাখিও': 7789, 'হয়েছে': 138, 'are': 1738, 'মাদারচুদেদের': 9287, 'মাঝেসেটার': 9273, 'জানার': 1490, 'খুজে': 864, 'somalia': 2433, 'রসালো': 9710, 'বলবোথাকবো': 8436, 'কারীদে\u200cর': 5594, 'শয়তানটাকে': 10143, 'হিন্দুদের': 571, 'ভাই': 10, 'নন': 1232, 'অসন্তোষ': 4473, 'দমে': 6957, 'খুমাতে': 5862, 'আছে': 33, 'সৌভাগ্যবান।': 3822, 'লিখে': 2256, 'নি': 371, '১২': 3880, 'ও': 11, 'ইমিগ্রেশন': 2600, 'আপনি': 32, 'কে': 13, 'থেইকা': 6939, 'অস্বীকার': 1780, 'কাজ': 25, 'জালিমদের': 6551, 'নগ্নো': 7362, 'সেদিন': 711, 'যাবে': 141, 'চোটোতো': 6315, 'ব্যানারে': 8930, 'বড়': 59, 'অন্ধভাবে': 4356, 'স্যার': 103, 'পরেছে': 7774, 'বুদ্বির': 8806, 'করা': 14, 'কয়': 1898, 'এল': 5187, 'যশোরের': 9568, 'নিরাপত্তার': 2052, 'অসুবিধা': 1776, 'বাড়ান': 8631, 'পর্বও': 3185, 'স্বরূপ': 10605, 'একটা': 49, 'হিংসাত্মক': 10816, 'ঘটনা': 458, 'দেইখা': 7165, 'এদেশের': 1839, 'কারে': 5597, 'শফিক': 99, 'হবে': 15, 'কাধেঁ': 5555, 'সিনা': 10437, 'রামগঞ্জ': 9757, 'প্রকৃত': 550, 'গেল': 457, 'ফ্লাইট': 3312, 'ম্যাসেজ': 9545, 'পারনাই': 7872, 'প্রবেশাধিকার': 8152, 'like': 2411, 'জনগনের': 365, 'আললাহ': 4765, 'বাটপারদের': 1601, 'তনুসহ': 2988, 'এ': 41, 'ঢাকার': 1203, 'আমি': 16, 'পরা': 3174, '৯': 3895, 'হকিন্নীর': 3840, 'তত': 1501, '😂😂': 3900, 'আপসোস': 2554, 'প্রাউড': 8182, 'যাবত।': 9607, 'কেউ': 126, 'তথ্য': 235, 'মুফতি': 9433, 'আসলে': 184, 'রক্ষাকর্তা।': 9688, 'খুব': 117, 'প্রকৃতির': 8088, 'মানহুশনেইমানহুশনেই': 9307, 'ছাগল': 871, 'চাচা': 1193, 'কাপুষ': 5565, 'right': 4197, 'ধন্যবাদ': 17, 'সবারই': 3749, 'ভাবে': 173, 'মুসলীম': 9453, 'দূর্নীতি': 3064, 'মানুষের': 104, 'যে': 18, 'প্রশাসন': 8167, 'এক': 62, 'করেছিল।কিন্তু': 5444, 'airports': 575, 'its': 4111, 'পারো': 7901, '//cashbkash': 3940, 'অনুভব': 2469, 'আমাদের': 19, 'কোন': 20, 'ফেলল': 8319, 'যদিও': 1656, 'প্রতিটা': 2104, 'খালাস': 5843, 'তে': 265, 'কথা': 21, 'কম': 210, 'রঙ': 9696, 'হেদায়েত': 3863, 'এবং': 58, 'বৈশাখে': 2168, 'পুলিশ': 55, 'vকতো': 4252, 'এর': 22, 'অস্ত্র': 1779, 'দিছিলাম': 3048, 'বিদেশে': 692, 'আমরা।': 2560, 'পাইবো': 7797, 'দৃশ্যমান': 2021, 'হয়': 23, 'সিরিয়াসলি': 3797, 'হাসালেন': 10798, 'দুর্সাহস': 7139, 'তিনটি': 1016, 'প্রিন্স': 8200, 'ভয়': 189, '=d': 3982, 'করতে': 24, 'এনে': 644, 'দেখেও': 7200, 'পতিতালয়ে': 7697, 'তক্কে': 2981, 'আমরা': 28, 'কুসি': 5679, 'কিছুই': 244, 'এয়ারপোর্টস': 5208, 'আমার': 26, 'কারিদের': 1880, 'টেলেন্ট': 6688, 'নাই।।।': 7398, 'বড়বড়': 8962, 'g2g': 4086, 'নাতাছাড়া': 7430, 'তো': 27, 'পায়': 499, 'কাপড়': 1876, 'sayed': 4202, 'বদলে': 1048, 'গেছে': 211, 'এদেরকে': 1410, 'কর্মচারীর': 5475, 'বানরকে': 8572, 'কেবলমাত্র': 1886, '/\u200cঅ\u200cনেক': 3960, 'মানুষ': 29, 'ডি': 2971, 'দালালরা': 7014, 'তাদের': 54, 'আগ্রহ': 4568, 'দেখতে': 367, 'নেশায়': 3156, 'সভ্য': 3750, 'নাম': 248, 'ঠীক': 6715, 'লেখনশৈলী': 9953, 'বেরাম': 8852, 'রাখতে': 1092, 'পাবে': 329, 'আপনাদের': 34, 'নবীকে ...

# %%
text_pipeline = lambda x:vocab(tokenizer(x))
label_pipeline = lambda x:int(x)

# %%
text_pipeline("চরম চাটাঁ লাথি চাই টুপি")
# Out:
# [747, 6212, 1672, 77, 0]

# %%
def collate_batch(batch):
    label_list, text_list, offsets = [], [], [0]
    for (_label, _text) in batch:
         label_list.append(label_pipeline(_label))
         processed_text = torch.tensor(text_pipeline(_text), dtype=torch.int64)
         text_list.append(processed_text)
         offsets.append(processed_text.size(0))
        
    label_list = torch.tensor(label_list, dtype=torch.int64)
    offsets = torch.tensor(offsets[:-1]).cumsum(dim=0)
    text_list = torch.cat(text_list)
    
    return label_list.to(device), text_list.to(device), offsets.to(device)

# %%
num_training_data = len(train_set)
num_classes = len(training_data1['reaction'].value_counts())
vocab_size = len(vocab)
embeding_size = int(min(500,vocab_size/2))

print(f"training_Data = {num_training_data}")
print(f"classes = {num_classes}")
print(f"vocab = {vocab_size}")
print(f"embeding = {embeding_size}")
# Out:
# training_Data = 2476
# classes = 5
# vocab = 11031
# embeding = 500

# %% [markdown]
# Model

# %% [markdown]
# **TextClassificationModel #1**

# %%
#fc1, fc2, fc3
class TextClassificationModel1(nn.Module):

    def __init__(self, vocab_size, embed_dim, num_class):
        super(TextClassificationModel1, self).__init__()
        self.embedding = nn.EmbeddingBag(vocab_size, embed_dim, sparse=True)
        self.fc1 = nn.Linear(embed_dim,100)
        self.fc2 = nn.Linear(100,50)
        self.fc3 = nn.Linear(50, num_class)
        self.init_weights()

    def init_weights(self):
        initrange = 0.5
        self.embedding.weight.data.uniform_(-initrange, initrange)
        self.fc1.weight.data.uniform_(-initrange, initrange)
        self.fc1.bias.data.zero_()
        self.fc2.weight.data.uniform_(-initrange, initrange)
        self.fc2.bias.data.zero_()
        self.fc3.weight.data.uniform_(-initrange, initrange)
        self.fc3.bias.data.zero_()

    def forward(self, text, offsets):
        embedded = self.embedding(text, offsets)
        x = fnc.relu(self.fc1(embedded))
        x = fnc.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# **TextClassificationModel #2**

# %%
#fc1, fc2, fc3, fc4, fc5
class TextClassificationModel2(nn.Module):

    def __init__(self, vocab_size, embed_dim, num_class):
        super(TextClassificationModel2, self).__init__()
        self.embedding = nn.EmbeddingBag(vocab_size, embed_dim, sparse=True)
        self.fc1 = nn.Linear(embed_dim,250)
        self.fc2 = nn.Linear(250,170)
        self.fc3 = nn.Linear(170,85)
        self.fc4 = nn.Linear(85,40)
        self.fc5 = nn.Linear(40, num_class)
        self.init_weights()

    def init_weights(self):
        initrange = 0.5
        self.embedding.weight.data.uniform_(-initrange, initrange)
        self.fc1.weight.data.uniform_(-initrange, initrange)
        self.fc1.bias.data.zero_()
        self.fc2.weight.data.uniform_(-initrange, initrange)
        self.fc2.bias.data.zero_()
        self.fc3.weight.data.uniform_(-initrange, initrange)
        self.fc3.bias.data.zero_()
        self.fc4.weight.data.uniform_(-initrange, initrange)
        self.fc4.bias.data.zero_()
        self.fc5.weight.data.uniform_(-initrange, initrange)
        self.fc5.bias.data.zero_()

    def forward(self, text, offsets):
        embedded = self.embedding(text, offsets)
        x = fnc.relu(self.fc1(embedded))
        x = fnc.relu(self.fc2(x))
        x = fnc.relu(self.fc3(x))
        x = fnc.relu(self.fc4(x))
        x = self.fc5(x)
        return x

# %%
model1 = TextClassificationModel1(vocab_size, embeding_size, num_classes).to(device)
model2 = TextClassificationModel2(vocab_size, embeding_size, num_classes).to(device)

# %% [markdown]
# **Train Test 1**

# %%
import time

def train1(dataloader):
    model1.train()
    total_acc, total_count = 0, 0
    log_interval = 500
    start_time = time.time()

    for idx, (label, text, offsets) in enumerate(dataloader):
        optimizer.zero_grad()
        predited_label = model1(text, offsets)
        loss = criterion(predited_label, label)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model1.parameters(), 0.1)
        optimizer.step()
        total_acc += (predited_label.argmax(1) == label).sum().item()
        total_count += label.size(0)
        if idx % log_interval == 0 and idx > 0:
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches '
                  '| accuracy {:8.3f}'.format(epoch, idx, len(dataloader),
                                              total_acc/total_count))
            total_acc, total_count = 0, 0
            start_time = time.time()

def test1(dataloader):
    model1.eval()
    total_acc, total_count = 0, 0

    with torch.no_grad():
        for idx, (label, text, offsets) in enumerate(dataloader):
            predited_label = model1(text, offsets)
            loss = criterion(predited_label, label)
            total_acc += (predited_label.argmax(1) == label).sum().item()
            total_count += label.size(0)
    return total_acc/total_count

# %% [markdown]
# **Train Test 2**

# %%
import time

def train2(dataloader):
    model2.train()
    total_acc, total_count = 0, 0
    log_interval = 500
    start_time = time.time()

    for idx, (label, text, offsets) in enumerate(dataloader):
        optimizer.zero_grad()
        predited_label = model2(text, offsets)
        loss = criterion(predited_label, label)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model2.parameters(), 0.1)
        optimizer.step()
        total_acc += (predited_label.argmax(1) == label).sum().item()
        total_count += label.size(0)
        if idx % log_interval == 0 and idx > 0:
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches '
                  '| accuracy {:8.3f}'.format(epoch, idx, len(dataloader),
                                              total_acc/total_count))
            total_acc, total_count = 0, 0
            start_time = time.time()

def test2(dataloader):
    model2.eval()
    total_acc, total_count = 0, 0

    with torch.no_grad():
        for idx, (label, text, offsets) in enumerate(dataloader):
            predited_label = model2(text, offsets)
            loss = criterion(predited_label, label)
            total_acc += (predited_label.argmax(1) == label).sum().item()
            total_count += label.size(0)
    return total_acc/total_count

# %% [markdown]
# **run on train test #1 model #1**

# %%
from torch.utils.data.dataset import random_split
from torchtext.data.functional import to_map_style_dataset
# Hyperparameters
EPOCHS = 10 # epoch
LR = 2  # learning rate
BATCH_SIZE = 150 # batch size for training

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model1.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.1)
total_accu = None

train_iter2 = train_set
print(type(train_set))
# test_iter2 =test_dat 
test_iter2 = test_set



train_dataloader = DataLoader(train_iter2, batch_size=BATCH_SIZE,
                              shuffle=True, collate_fn=collate_batch)
print(type(train_dataloader))
test_dataloader = DataLoader(test_iter2, batch_size=BATCH_SIZE,
                              shuffle=True, collate_fn=collate_batch)
# test_dataloader = DataLoader(test_iter2, batch_size=BATCH_SIZE,
#                              shuffle=True, collate_fn=collate_batch)

for epoch in range(1, EPOCHS + 1):
    epoch_start_time = time.time()
    train1(train_dataloader)
    accu_test = test1(test_dataloader)
    if total_accu is not None and total_accu > accu_test:
        scheduler.step()
    else:
        total_accu = accu_test
    print('-' * 59)
    print('| end of epoch {:3d} | time: {:5.2f}s | '
          'valid accuracy {:8.3f} '.format(epoch,
                                           time.time() - epoch_start_time,
                                           accu_test))
    print('-' * 59)
    print(f"total accu = {total_accu}")
# Out:
# <class 'list'>
# <class 'torch.utils.data.dataloader.DataLoader'>
# -----------------------------------------------------------
# | end of epoch   1 | time:  0.41s | valid accuracy    0.374
# -----------------------------------------------------------
# total accu = 0.3741935483870968
# -----------------------------------------------------------
# | end of epoch   2 | time:  0.37s | valid accuracy    0.408
# -----------------------------------------------------------
# total accu = 0.4080645161290323
# -----------------------------------------------------------
# | end of epoch   3 | time:  0.32s | valid accuracy    0.421
# -----------------------------------------------------------
# total accu = 0.42096774193548386
# -----------------------------------------------------------
# | end of epoch   4 | time:  0.26s | valid accuracy    0.398
# -----------------------------------------------------------
# total accu = 0.42096774193548386
# -----------------------------------------------------------
# | end of epoch   5 | time:  0.27s | valid accuracy    0.418
# -----------------------------------------------------------
# total accu = 0.42096774193548386
# -----------------------------------------------------------
# | end of epoch   6 | time:  0.32s | valid accuracy    0.418
# -----------------------------------------------------------
# total accu = 0.42096774193548386
# -----------------------------------------------------------
# | end of epoch   7 | time:  0.30s | valid accuracy    0.418
# -----------------------------------------------------------
# total accu = 0.42096774193548386
# -----------------------------------------------------------
# | end of epoch   8 | time:  0.27s | valid accuracy    0.418
# -----------------------------------------------------------
# total accu = 0.42096774193548386
# -----------------------------------------------------------
# | end of epoch   9 | time:  0.26s | valid accuracy    0.418
# -----------------------------------------------------------
# total accu = 0.42096774193548386
# -----------------------------------------------------------
# | end of epoch  10 | time:  0.30s | valid accuracy    0.418
# -----------------------------------------------------------
# total accu = 0.42096774193548386

# %% [markdown]
# **run on train test #2 model #2**

# %%
from torch.utils.data.dataset import random_split
from torchtext.data.functional import to_map_style_dataset
# Hyperparameters
EPOCHS = 10 # epoch
LR = 2  # learning rate
BATCH_SIZE = 150 # batch size for training

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model2.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.1)
total_accu = None

train_iter2 = train_set
print(type(train_set))
# test_iter2 =test_dat 
test_iter2 = test_set



train_dataloader = DataLoader(train_iter2, batch_size=BATCH_SIZE,
                              shuffle=True, collate_fn=collate_batch)
print(type(train_dataloader))
test_dataloader = DataLoader(test_iter2, batch_size=BATCH_SIZE,
                              shuffle=True, collate_fn=collate_batch)
# test_dataloader = DataLoader(test_iter2, batch_size=BATCH_SIZE,
#                              shuffle=True, collate_fn=collate_batch)

for epoch in range(1, EPOCHS + 1):
    epoch_start_time = time.time()
    train2(train_dataloader)
    accu_test = test2(test_dataloader)
    if total_accu is not None and total_accu > accu_test:
        scheduler.step()
    else:
        total_accu = accu_test
    print('-' * 59)
    print('| end of epoch {:3d} | time: {:5.2f}s | '
          'valid accuracy {:8.3f} '.format(epoch,
                                           time.time() - epoch_start_time,
                                           accu_test))
    print('-' * 59)
    print(f"total accu = {total_accu}")
# Out:
# <class 'list'>
# <class 'torch.utils.data.dataloader.DataLoader'>
# -----------------------------------------------------------
# | end of epoch   1 | time:  0.66s | valid accuracy    0.350
# -----------------------------------------------------------
# total accu = 0.35
# -----------------------------------------------------------
# | end of epoch   2 | time:  0.32s | valid accuracy    0.352
# -----------------------------------------------------------
# total accu = 0.35161290322580646
# -----------------------------------------------------------
# | end of epoch   3 | time:  0.34s | valid accuracy    0.345
# -----------------------------------------------------------
# total accu = 0.35161290322580646
# -----------------------------------------------------------
# | end of epoch   4 | time:  0.31s | valid accuracy    0.369
# -----------------------------------------------------------
# total accu = 0.36935483870967745
# -----------------------------------------------------------
# | end of epoch   5 | time:  0.32s | valid accuracy    0.361
# -----------------------------------------------------------
# total accu = 0.36935483870967745
# -----------------------------------------------------------
# | end of epoch   6 | time:  0.32s | valid accuracy    0.365
# -----------------------------------------------------------
# total accu = 0.36935483870967745
# -----------------------------------------------------------
# | end of epoch   7 | time:  0.32s | valid accuracy    0.365
# -----------------------------------------------------------
# total accu = 0.36935483870967745
# -----------------------------------------------------------
# | end of epoch   8 | time:  0.32s | valid accuracy    0.365
# -----------------------------------------------------------
# total accu = 0.36935483870967745
# -----------------------------------------------------------
# | end of epoch   9 | time:  0.31s | valid accuracy    0.365
# -----------------------------------------------------------
# total accu = 0.36935483870967745
# -----------------------------------------------------------
# | end of epoch  10 | time:  0.32s | valid accuracy    0.365
# -----------------------------------------------------------
# total accu = 0.36935483870967745
